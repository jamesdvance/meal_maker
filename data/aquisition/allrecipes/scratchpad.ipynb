# %%
import pandas as pd 
import requests
import json
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import urllib.request
import time

# %% [markdown]
# ## AllRecipes.com
# * Easily scrapeable
# * Has good images
# * Has nutrition

# %%
recipe_page = "https://www.allrecipes.com/saucy-vegetable-pinwheels-recipe-7568002"

# %%
food_pages_soup = BeautifulSoup(requests.get(recipe_page).text, 'html.parser')

# %% [markdown]
# ### Details

# %%
food_pages_soup.find("div",attrs={"id":"recipe-details_1-0"}).findAll("div",attrs={"class":"mntl-recipe-details__item"})
# Out:
# [<div class="mntl-recipe-details__item">
#  <div class="mntl-recipe-details__label">Prep Time:</div>
#  <div class="mntl-recipe-details__value">10 mins</div>
#  </div>,
#  <div class="mntl-recipe-details__item">
#  <div class="mntl-recipe-details__label">Cook Time:</div>
#  <div class="mntl-recipe-details__value">1 mins</div>
#  </div>,
#  <div class="mntl-recipe-details__item">
#  <div class="mntl-recipe-details__label">Total Time:</div>
#  <div class="mntl-recipe-details__value">11 mins</div>
#  </div>,
#  <div class="mntl-recipe-details__item">
#  <div class="mntl-recipe-details__label">Servings:</div>
#  <div class="mntl-recipe-details__value">2 </div>
#  </div>,
#  <div class="mntl-recipe-details__item">
#  <div class="mntl-recipe-details__label">Yield:</div>
#  <div class="mntl-recipe-details__value">2 wraps</div>
#  </div>]

# %%
def get_details(page):
    return {itm.find("div",attrs={"class":"mntl-recipe-details__label"}).text : itm.find("div",attrs={"class":"mntl-recipe-details__value"}).text \
        for itm in page.findAll("div",attrs={"class":"mntl-recipe-details__item"}) }

# %% [markdown]
# ### Ingredients

# %%
ingredient_itms = food_pages_soup.find("ul",attrs={"class":"mntl-structured-ingredients__list"})\
    .findAll("li",attrs={"class":"mntl-structured-ingredients__list-item"})

# %%
def parse_ingred(ingredient_itm):
    ingred_obj = {}
    qty = ingredient_itm.find("span",attrs={"data-ingredient-quantity":"true"})
    ingred_obj["amt"] = qty.text if qty else 1 
    unit = ingredient_itm.find("span",attrs={"data-ingredient-unit":"true"})
    ingred_obj["unit"] =unit.text if unit else "item"
    ingred_obj["ingred"] = ingredient_itm.find("span",attrs={"data-ingredient-name":"true"}).text
    return ingred_obj

# %% [markdown]
# ### Instructions

# %%
instructions = [p.text.replace("\n"," ").strip() for p in food_pages_soup.find("div",attrs={"id":"recipe__steps-content_1-0"}).findAll("p")]

# %%
def scrape_all_recipes_page(url):
    page = requests.get(url)

    food_pages_soup = BeautifulSoup(page.text, 'html.parser')
    time.sleep(0.5)
    img_link = food_pages_soup.find("img",attrs={"sizes":"750px"})["src"]
    steps = [p.text.replace("\n"," ").strip() for p in food_pages_soup.find("div",attrs={"id":"recipe__steps-content_1-0"}).findAll("p")]
    ingredient = [parse_ingred(obj) for obj in food_pages_soup.find("ul",attrs={"class":"mntl-structured-ingredients__list"})\
        .findAll("li",attrs={"class":"mntl-structured-ingredients__list-item"})]
    name = food_pages_soup.find("h1",attrs={"id":"article-heading_1-0"}).text.replace("\n","").strip()
    details = get_details(food_pages_soup)
    ret_obj = {"name":name,
        "steps":steps,
        "ingredients":ingredient,
        "img":img_link}
    ret_obj.update(details)
    return ret_obj

# %%
scrape_all_recipes_page("https://www.allrecipes.com/saucy-vegetable-pinwheels-recipe-7568002")
# Out:
# {'name': 'Saucy Vegetable Pinwheels',
#  'steps': ['For sauce, process roasted red peppers, yogurt, orange zest (or other CITRUS ZEST), orange juice (or other CITRUS JUICE), chopped parsley (or other FRESH HERB), salt, and black pepper in a food processor until smooth.',
#   'Spread tortillas evenly with sauce and top with arugula and carrots (or other 2 VEGETABLES). Roll up and wrap tightly in plastic wrap. Chill at least 1 hour or up to 12 hours. To serve, unwrap tortillas and trim ends. Cut rolls into slices.',
#   '8 cups arugula and/or spring mix',
#   '4 cups shredded red cabbage',
#   '2 red bell peppers, julienned (2 cups)',
#   '2 zucchini, sliced (4 cups)',
#   '2 large carrots, julienned (2 cups)',
#   '4 ounces radishes, sliced (1 cup)',
#   'LIME-CABBAGE',
#   'lime zest + lime juice + cilantro + red cabbage + red bell pepper',
#   'LEMON-ZUCCHINI',
#   'lemon zest + lemon juice + chives + zucchini +radishes'],
#  'ingredients': [{'amt': '1', 'unit': 'cup', 'ingred': 'roasted red peppers'},
#   {'amt': '1/4', 'unit': 'cup', 'ingred': 'yogurt'},
#   {'amt': '1 ', 'unit': 'teaspoon ', 'ingred': 'orange zest'},
#   {'amt': '1',
#    'unit': 'tablespoons orange ',
#    'ingred': 'juice (or other CITRUS JUICE)'},
#   {'amt': '2', 'unit': 'tablespoons', 'ingred': 'chopped fresh parsley '},
#   {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'salt'},
#   {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'black pepper'},
#   {'amt': '4',
#    'unit': ' (12-inch) ',
#    'ingred': 'plain, spinach, and/or roasted red pepper tortillas'},
#   {'amt': '8', 'unit': 'cups', 'ingred': 'arugula (or other VEGETABLE)'},
#   {'amt': '2',
#    'unit': 'cups',
#    'ingred': 'julienned carrots (or other VEGETABLE)'}],
#  'img': 'https://www.allrecipes.com/thmb/9udnholrcOw2WTtsDACWoahamqw=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568002-vegetable-pinwheels-GOLDMAN-4x3-3184-f5bf34b04f064617a0991d341e7fa4d0.jpg',
#  'Prep Time:': '15 mins',
#  'Chill Time:': ' 1 hr',
#  'Total Time:': ' 1 hr 15 mins'}

# %% [markdown]
# ### Crawl Pages

# %%
root_url = "https://www.allrecipes.com/recipes/"

# %%
recipe_objs = []
nav_links = ["https://www.allrecipes.com/" ]
recipe_links = []
scraped = set()
while (nav_links or recipe_links) and len(recipe_objs) <1000:
    if recipe_links:
        link = recipe_links.pop()
    else:
        link = nav_links.pop()
    print(f"Parsing {link}")
    scraped.add(link)
    page = BeautifulSoup(requests.get(link).text, 'html.parser')
    if page.find("h1",attrs={"id":"article-heading_1-0"}) and page.find("img",attrs={"sizes":"750px"}):
        print("adding recipe")
        try:
            recipe_objs.append(scrape_all_recipes_page(link))
        except AttributeError:
            print(f"Error scraping {link}. Skipping")
    
    else:
        possible_nav_links = [itm["href"] for itm in root_soup.findAll("a") if "https://www.allrecipes.com/recipes/" in itm["href"]]
        possible_recipe_links = [itm["href"] for itm in root_soup.findAll("a") \
                if "https://www.allrecipes.com/" in itm["href"] and "https://www.allrecipes.com/recipes/" not in itm["href"]\
                    and "authentication" not in itm["href"]]
        for recipe_link in possible_recipe_links:
            if recipe_link not in scraped:
                recipe_links.append(recipe_link)

        for new_link in possible_nav_links:
            if new_link not in scraped:
                nav_links.append(new_link)
# Out:
# Parsing https://www.allrecipes.com/
# Parsing https://www.allrecipes.com/food-news-trends/
# Parsing https://www.allrecipes.com/kitchen-tips/
# Parsing https://www.allrecipes.com/grilled-ribeye-steaks-recipe-7552430
# adding recipe
# Parsing https://www.allrecipes.com/skillet-chicken-breasts-with-cherry-tomatoes-recipe-7553999
# adding recipe
# Parsing https://www.allrecipes.com/dill-ranch-chicken-wraps-recipe-7552440
# adding recipe
# Parsing https://www.allrecipes.com/air-fryer-zucchini-fries-recipe-7554904
# adding recipe
# Parsing https://www.allrecipes.com/simple-homemade-dreamsicles-recipe-7550349
# Parsing https://www.allrecipes.com/copycat-wendy-s-ranch-sauce-recipe-7556719
# adding recipe
# Parsing https://www.allrecipes.com/copycat-chick-fil-a-honey-mustard-recipe-7556788
# adding recipe
# Parsing https://www.allrecipes.com/chipotle-citrus-marinated-chicken-tacos-recipe-7553405
# adding recipe
# Parsing https://www.allrecipes.com/pitmaster-potato-salad-recipe-7556905
# adding recipe
# Parsing https://www.allrecipes.com/copycat-waffle-house-hash-browns-recipe-7556710
# adding recipe
# Parsing https://www.allrecipes.com/mint-oreo-icebox-cake-recipe-7550324
# adding recipe
# Parsing https://www.allrecipes.com/copycat-panda-express-chow-mein-recipe-7556785
# adding recipe
# Parsing https://www.allrecipes.com/bacon-egg-and-cheese-sandwich-recipe-7557506
# adding recipe
# Parsing https://www.allrecipes.com/puff-pastry-cherry-crostata-recipe-7558586
# adding recipe
# Parsing https://www.allrecipes.com/barbecued-butter-chicken-recipe-7560707
# adding recipe
# Parsing https://www.allrecipes.com/peach-crumble-recipe-7559227
# adding recipe
# Parsing https://www.allrecipes.com/sparkling-mango-pineapple-sangria-recipe-7560880
# adding recipe
# Parsing https://www.allrecipes.com/grilled-pizza-bianca-recipe-7559340
# adding recipe
# Parsing https://www.allrecipes.com/agua-fresca-de-fresas-con-crema-strawberries-and-cream-recipe-7560919
# adding recipe
# Parsing https://www.allrecipes.com/spicy-canned-salmon-salad-rice-bowl-recipe-7558696
# adding recipe
# Parsing https://www.allrecipes.com/copycat-chick-fil-a-frosted-lemonade-recipe-7550375
# adding recipe
# Parsing https://www.allrecipes.com/basic-no-soak-beans-recipe-7555578
# adding recipe
# Parsing https://www.allrecipes.com/cornflake-corn-cake-recipe-7562367
# adding recipe
# Parsing https://www.allrecipes.com/air-fryer-cheesy-bacon-ranch-french-fries-recipe-7560981
# adding recipe
# Parsing https://www.allrecipes.com/sparkling-peach-sangria-recipe-7559189
# adding recipe
# Parsing https://www.allrecipes.com/gold-rush-recipe-7562213
# adding recipe
# Parsing https://www.allrecipes.com/perfect-fried-shrimp-recipe-7556606
# adding recipe
# Parsing https://www.allrecipes.com/rotisserie-chicken-wrap-with-strawberries-recipe-7559150
# adding recipe
# Parsing https://www.allrecipes.com/lazy-hazy-beef-chili-recipe-7562950
# adding recipe
# Parsing https://www.allrecipes.com/salmon-couscous-salad-recipe-7561932
# adding recipe
# Parsing https://www.allrecipes.com/southern-baked-beans-recipe-7554356
# adding recipe
# Parsing https://www.allrecipes.com/zucchini-coffee-cake-recipe-7554364
# adding recipe
# Parsing https://www.allrecipes.com/blueberry-shortcake-recipe-7552490
# adding recipe
# Parsing https://www.allrecipes.com/cheesy-zucchini-rice-recipe-7552502
# adding recipe
# Parsing https://www.allrecipes.com/churro-cheesecake-bars-recipe-7554374
# adding recipe
# Parsing https://www.allrecipes.com/jalapeno-popper-pig-shots-recipe-7563404
# adding recipe
# Parsing https://www.allrecipes.com/peach-cake-with-brown-sugar-icing-recipe-7564806
# adding recipe
# Parsing https://www.allrecipes.com/edamame-and-radish-salad-recipe-7564426
# adding recipe
# Parsing https://www.allrecipes.com/strawberry-biscuits-recipe-7564428
# adding recipe
# Parsing https://www.allrecipes.com/easy-chicken-street-tacos-recipe-7564448
# adding recipe
# Parsing https://www.allrecipes.com/almond-oatmeal-cookies-with-black-raspberries-recipe-7564453
# adding recipe
# Parsing https://www.allrecipes.com/loaded-steak-fries-recipe-7564469
# adding recipe
# Parsing https://www.allrecipes.com/pizza-bianca-with-prosciutto-recipe-7559275
# adding recipe
# Parsing https://www.allrecipes.com/peach-fritters-recipe-7564661
# adding recipe
# Parsing https://www.allrecipes.com/skillet-shrimp-fajitas-with-cilantro-lime-cream-recipe-7561267
# adding recipe
# Parsing https://www.allrecipes.com/fried-egg-tortilla-recipe-7561904
# adding recipe
# Parsing https://www.allrecipes.com/green-no-bean-hummus-recipe-7566683
# adding recipe
# Parsing https://www.allrecipes.com/tortilla-scrambled-egg-and-cheese-recipe-7563309
# adding recipe
# Parsing https://www.allrecipes.com/tex-mex-pork-chops-and-rice-skillet-recipe-7567945
# adding recipe
# Parsing https://www.allrecipes.com/herb-tomato-olive-and-caper-sauce-7567843
# adding recipe
# Parsing https://www.allrecipes.com/apple-fall-spritz-recipe-7567970
# adding recipe
# Parsing https://www.allrecipes.com/skillet-green-tomatoes-with-crunchy-remoulade-recipe-7568010
# adding recipe
# Parsing https://www.allrecipes.com/chopped-salad-with-figs-and-blue-cheese-recipe-7568016
# adding recipe
# Parsing https://www.allrecipes.com/peanut-butter-snickers-bites-recipe-7566967
# Parsing https://www.allrecipes.com/charred-lemon-paper-plane-recipe-7567985
# adding recipe
# Parsing https://www.allrecipes.com/hash-brown-and-bacon-omelet-cups-recipe-7567917
# adding recipe
# Parsing https://www.allrecipes.com/sweet-potato-and-black-bean-taco-cups-recipe-7567956
# adding recipe
# Parsing https://www.allrecipes.com/perfect-pancakes-recipe-7568285
# adding recipe
# Parsing https://www.allrecipes.com/saucy-vegetable-pinwheels-recipe-7568002
# adding recipe
# Parsing https://www.allrecipes.com/apple-smoothie-recipe-7568869
# adding recipe
# Parsing https://www.allrecipes.com/chicken-broccoli-rice-skillet-recipe-7568422
# adding recipe
# Parsing https://www.allrecipes.com/elote-pizza-recipe-7568835
# adding recipe
# Parsing https://www.allrecipes.com/charcoal-grilled-ribeye-steak-recipe-7567649
# adding recipe
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/article/baking-ingredient-conversions/
# adding recipe
# Error scraping https://www.allrecipes.com/article/baking-ingredient-conversions/. Skipping
# Parsing https://www.allrecipes.com/recipe/21014/good-old-fashioned-pancakes/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/143069/super-delicious-zuppa-toscana/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/23600/worlds-best-lasagna/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/20144/banana-banana-bread/
# adding recipe
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/article/baking-ingredient-conversions/
# adding recipe
# Error scraping https://www.allrecipes.com/article/baking-ingredient-conversions/. Skipping
# Parsing https://www.allrecipes.com/recipe/21014/good-old-fashioned-pancakes/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/143069/super-delicious-zuppa-toscana/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/23600/worlds-best-lasagna/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/20144/banana-banana-bread/
# adding recipe
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/article/baking-ingredient-conversions/
# adding recipe
# Error scraping https://www.allrecipes.com/article/baking-ingredient-conversions/. Skipping
# Parsing https://www.allrecipes.com/recipe/21014/good-old-fashioned-pancakes/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/143069/super-delicious-zuppa-toscana/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/23600/worlds-best-lasagna/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/20144/banana-banana-bread/
# adding recipe
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/charred-lemon-paper-plane-recipe-7567985
# adding recipe
# Parsing https://www.allrecipes.com/hash-brown-and-bacon-omelet-cups-recipe-7567917
# adding recipe
# Parsing https://www.allrecipes.com/sweet-potato-and-black-bean-taco-cups-recipe-7567956
# adding recipe
# Parsing https://www.allrecipes.com/perfect-pancakes-recipe-7568285
# adding recipe
# Parsing https://www.allrecipes.com/saucy-vegetable-pinwheels-recipe-7568002
# adding recipe
# Parsing https://www.allrecipes.com/apple-smoothie-recipe-7568869
# adding recipe
# Parsing https://www.allrecipes.com/chicken-broccoli-rice-skillet-recipe-7568422
# adding recipe
# Parsing https://www.allrecipes.com/elote-pizza-recipe-7568835
# adding recipe
# Parsing https://www.allrecipes.com/charcoal-grilled-ribeye-steak-recipe-7567649
# adding recipe
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/article/baking-ingredient-conversions/
# adding recipe
# Error scraping https://www.allrecipes.com/article/baking-ingredient-conversions/. Skipping
# Parsing https://www.allrecipes.com/recipe/21014/good-old-fashioned-pancakes/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/143069/super-delicious-zuppa-toscana/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/23600/worlds-best-lasagna/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/20144/banana-banana-bread/
# adding recipe
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/copycat-wendy-s-ranch-sauce-recipe-7556719
# adding recipe
# Parsing https://www.allrecipes.com/copycat-chick-fil-a-honey-mustard-recipe-7556788
# adding recipe
# Parsing https://www.allrecipes.com/chipotle-citrus-marinated-chicken-tacos-recipe-7553405
# adding recipe
# Parsing https://www.allrecipes.com/pitmaster-potato-salad-recipe-7556905
# adding recipe
# Parsing https://www.allrecipes.com/copycat-waffle-house-hash-browns-recipe-7556710
# adding recipe
# Parsing https://www.allrecipes.com/mint-oreo-icebox-cake-recipe-7550324
# adding recipe
# Parsing https://www.allrecipes.com/copycat-panda-express-chow-mein-recipe-7556785
# adding recipe
# Parsing https://www.allrecipes.com/bacon-egg-and-cheese-sandwich-recipe-7557506
# adding recipe
# Parsing https://www.allrecipes.com/puff-pastry-cherry-crostata-recipe-7558586
# adding recipe
# Parsing https://www.allrecipes.com/barbecued-butter-chicken-recipe-7560707
# adding recipe
# Parsing https://www.allrecipes.com/peach-crumble-recipe-7559227
# adding recipe
# Parsing https://www.allrecipes.com/sparkling-mango-pineapple-sangria-recipe-7560880
# adding recipe
# Parsing https://www.allrecipes.com/grilled-pizza-bianca-recipe-7559340
# adding recipe
# Parsing https://www.allrecipes.com/agua-fresca-de-fresas-con-crema-strawberries-and-cream-recipe-7560919
# adding recipe
# Parsing https://www.allrecipes.com/spicy-canned-salmon-salad-rice-bowl-recipe-7558696
# adding recipe
# Parsing https://www.allrecipes.com/copycat-chick-fil-a-frosted-lemonade-recipe-7550375
# adding recipe
# Parsing https://www.allrecipes.com/basic-no-soak-beans-recipe-7555578
# adding recipe
# Parsing https://www.allrecipes.com/cornflake-corn-cake-recipe-7562367
# adding recipe
# Parsing https://www.allrecipes.com/air-fryer-cheesy-bacon-ranch-french-fries-recipe-7560981
# adding recipe
# Parsing https://www.allrecipes.com/sparkling-peach-sangria-recipe-7559189
# adding recipe
# Parsing https://www.allrecipes.com/gold-rush-recipe-7562213
# adding recipe
# Parsing https://www.allrecipes.com/perfect-fried-shrimp-recipe-7556606
# adding recipe
# Parsing https://www.allrecipes.com/rotisserie-chicken-wrap-with-strawberries-recipe-7559150
# adding recipe
# Parsing https://www.allrecipes.com/lazy-hazy-beef-chili-recipe-7562950
# adding recipe
# Parsing https://www.allrecipes.com/salmon-couscous-salad-recipe-7561932
# adding recipe
# Parsing https://www.allrecipes.com/southern-baked-beans-recipe-7554356
# adding recipe
# Parsing https://www.allrecipes.com/zucchini-coffee-cake-recipe-7554364
# adding recipe
# Parsing https://www.allrecipes.com/blueberry-shortcake-recipe-7552490
# adding recipe
# Parsing https://www.allrecipes.com/cheesy-zucchini-rice-recipe-7552502
# adding recipe
# Parsing https://www.allrecipes.com/churro-cheesecake-bars-recipe-7554374
# adding recipe
# Parsing https://www.allrecipes.com/jalapeno-popper-pig-shots-recipe-7563404
# adding recipe
# Parsing https://www.allrecipes.com/peach-cake-with-brown-sugar-icing-recipe-7564806
# adding recipe
# Parsing https://www.allrecipes.com/edamame-and-radish-salad-recipe-7564426
# adding recipe
# Parsing https://www.allrecipes.com/strawberry-biscuits-recipe-7564428
# adding recipe
# Parsing https://www.allrecipes.com/easy-chicken-street-tacos-recipe-7564448
# adding recipe
# Parsing https://www.allrecipes.com/almond-oatmeal-cookies-with-black-raspberries-recipe-7564453
# adding recipe
# Parsing https://www.allrecipes.com/loaded-steak-fries-recipe-7564469
# adding recipe
# Parsing https://www.allrecipes.com/pizza-bianca-with-prosciutto-recipe-7559275
# adding recipe
# Parsing https://www.allrecipes.com/peach-fritters-recipe-7564661
# adding recipe
# Parsing https://www.allrecipes.com/skillet-shrimp-fajitas-with-cilantro-lime-cream-recipe-7561267
# adding recipe
# Parsing https://www.allrecipes.com/fried-egg-tortilla-recipe-7561904
# adding recipe
# Parsing https://www.allrecipes.com/green-no-bean-hummus-recipe-7566683
# adding recipe
# Parsing https://www.allrecipes.com/tortilla-scrambled-egg-and-cheese-recipe-7563309
# adding recipe
# Parsing https://www.allrecipes.com/tex-mex-pork-chops-and-rice-skillet-recipe-7567945
# adding recipe
# Parsing https://www.allrecipes.com/herb-tomato-olive-and-caper-sauce-7567843
# adding recipe
# Parsing https://www.allrecipes.com/apple-fall-spritz-recipe-7567970
# adding recipe
# Parsing https://www.allrecipes.com/skillet-green-tomatoes-with-crunchy-remoulade-recipe-7568010
# adding recipe
# Parsing https://www.allrecipes.com/chopped-salad-with-figs-and-blue-cheese-recipe-7568016
# adding recipe
# Parsing https://www.allrecipes.com/peanut-butter-snickers-bites-recipe-7566967
# Parsing https://www.allrecipes.com/charred-lemon-paper-plane-recipe-7567985
# adding recipe
# Parsing https://www.allrecipes.com/hash-brown-and-bacon-omelet-cups-recipe-7567917
# adding recipe
# Parsing https://www.allrecipes.com/sweet-potato-and-black-bean-taco-cups-recipe-7567956
# adding recipe
# Parsing https://www.allrecipes.com/perfect-pancakes-recipe-7568285
# adding recipe
# Parsing https://www.allrecipes.com/saucy-vegetable-pinwheels-recipe-7568002
# adding recipe
# Parsing https://www.allrecipes.com/apple-smoothie-recipe-7568869
# adding recipe
# Parsing https://www.allrecipes.com/chicken-broccoli-rice-skillet-recipe-7568422
# adding recipe
# Parsing https://www.allrecipes.com/elote-pizza-recipe-7568835
# adding recipe
# Parsing https://www.allrecipes.com/charcoal-grilled-ribeye-steak-recipe-7567649
# adding recipe
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/article/baking-ingredient-conversions/
# adding recipe
# Error scraping https://www.allrecipes.com/article/baking-ingredient-conversions/. Skipping
# Parsing https://www.allrecipes.com/recipe/21014/good-old-fashioned-pancakes/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/143069/super-delicious-zuppa-toscana/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/23600/worlds-best-lasagna/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/20144/banana-banana-bread/
# adding recipe
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/about-us-6648102
# adding recipe
# Error scraping https://www.allrecipes.com/about-us-6648102. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/food-news-trends/product-reviews/
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/cuisine-a-z-6740455
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/ingredients-a-z-6740416
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/sweepstakes/
# Parsing https://www.allrecipes.com/grilled-ribeye-steaks-recipe-7552430
# adding recipe
# Parsing https://www.allrecipes.com/skillet-chicken-breasts-with-cherry-tomatoes-recipe-7553999
# adding recipe
# Parsing https://www.allrecipes.com/dill-ranch-chicken-wraps-recipe-7552440
# adding recipe
# Parsing https://www.allrecipes.com/air-fryer-zucchini-fries-recipe-7554904
# adding recipe
# Parsing https://www.allrecipes.com/simple-homemade-dreamsicles-recipe-7550349
# Parsing https://www.allrecipes.com/copycat-wendy-s-ranch-sauce-recipe-7556719
# adding recipe
# Parsing https://www.allrecipes.com/copycat-chick-fil-a-honey-mustard-recipe-7556788
# adding recipe
# Parsing https://www.allrecipes.com/chipotle-citrus-marinated-chicken-tacos-recipe-7553405
# adding recipe
# Parsing https://www.allrecipes.com/pitmaster-potato-salad-recipe-7556905
# adding recipe
# Parsing https://www.allrecipes.com/copycat-waffle-house-hash-browns-recipe-7556710
# adding recipe
# Parsing https://www.allrecipes.com/mint-oreo-icebox-cake-recipe-7550324
# adding recipe
# Parsing https://www.allrecipes.com/copycat-panda-express-chow-mein-recipe-7556785
# adding recipe
# Parsing https://www.allrecipes.com/bacon-egg-and-cheese-sandwich-recipe-7557506
# adding recipe
# Parsing https://www.allrecipes.com/puff-pastry-cherry-crostata-recipe-7558586
# adding recipe
# Parsing https://www.allrecipes.com/barbecued-butter-chicken-recipe-7560707
# adding recipe
# Parsing https://www.allrecipes.com/peach-crumble-recipe-7559227
# adding recipe
# Parsing https://www.allrecipes.com/sparkling-mango-pineapple-sangria-recipe-7560880
# adding recipe
# Parsing https://www.allrecipes.com/grilled-pizza-bianca-recipe-7559340
# adding recipe
# Parsing https://www.allrecipes.com/agua-fresca-de-fresas-con-crema-strawberries-and-cream-recipe-7560919
# adding recipe
# Parsing https://www.allrecipes.com/spicy-canned-salmon-salad-rice-bowl-recipe-7558696
# adding recipe
# Parsing https://www.allrecipes.com/copycat-chick-fil-a-frosted-lemonade-recipe-7550375
# adding recipe
# Parsing https://www.allrecipes.com/basic-no-soak-beans-recipe-7555578
# adding recipe
# Parsing https://www.allrecipes.com/cornflake-corn-cake-recipe-7562367
# adding recipe
# Parsing https://www.allrecipes.com/air-fryer-cheesy-bacon-ranch-french-fries-recipe-7560981
# adding recipe
# Parsing https://www.allrecipes.com/sparkling-peach-sangria-recipe-7559189
# adding recipe
# Parsing https://www.allrecipes.com/gold-rush-recipe-7562213
# adding recipe
# Parsing https://www.allrecipes.com/perfect-fried-shrimp-recipe-7556606
# adding recipe
# Parsing https://www.allrecipes.com/rotisserie-chicken-wrap-with-strawberries-recipe-7559150
# adding recipe
# Parsing https://www.allrecipes.com/lazy-hazy-beef-chili-recipe-7562950
# adding recipe
# Parsing https://www.allrecipes.com/salmon-couscous-salad-recipe-7561932
# adding recipe
# Parsing https://www.allrecipes.com/southern-baked-beans-recipe-7554356
# adding recipe
# Parsing https://www.allrecipes.com/zucchini-coffee-cake-recipe-7554364
# adding recipe
# Parsing https://www.allrecipes.com/blueberry-shortcake-recipe-7552490
# adding recipe
# Parsing https://www.allrecipes.com/cheesy-zucchini-rice-recipe-7552502
# adding recipe
# Parsing https://www.allrecipes.com/churro-cheesecake-bars-recipe-7554374
# adding recipe
# Parsing https://www.allrecipes.com/jalapeno-popper-pig-shots-recipe-7563404
# adding recipe
# Parsing https://www.allrecipes.com/peach-cake-with-brown-sugar-icing-recipe-7564806
# adding recipe
# Parsing https://www.allrecipes.com/edamame-and-radish-salad-recipe-7564426
# adding recipe
# Parsing https://www.allrecipes.com/strawberry-biscuits-recipe-7564428
# adding recipe
# Parsing https://www.allrecipes.com/easy-chicken-street-tacos-recipe-7564448
# adding recipe
# Parsing https://www.allrecipes.com/almond-oatmeal-cookies-with-black-raspberries-recipe-7564453
# adding recipe
# Parsing https://www.allrecipes.com/loaded-steak-fries-recipe-7564469
# adding recipe
# Parsing https://www.allrecipes.com/pizza-bianca-with-prosciutto-recipe-7559275
# adding recipe
# Parsing https://www.allrecipes.com/peach-fritters-recipe-7564661
# adding recipe
# Parsing https://www.allrecipes.com/skillet-shrimp-fajitas-with-cilantro-lime-cream-recipe-7561267
# adding recipe
# Parsing https://www.allrecipes.com/fried-egg-tortilla-recipe-7561904
# adding recipe
# Parsing https://www.allrecipes.com/green-no-bean-hummus-recipe-7566683
# adding recipe
# Parsing https://www.allrecipes.com/tortilla-scrambled-egg-and-cheese-recipe-7563309
# adding recipe
# Parsing https://www.allrecipes.com/tex-mex-pork-chops-and-rice-skillet-recipe-7567945
# adding recipe
# Parsing https://www.allrecipes.com/herb-tomato-olive-and-caper-sauce-7567843
# adding recipe
# Parsing https://www.allrecipes.com/apple-fall-spritz-recipe-7567970
# adding recipe
# Parsing https://www.allrecipes.com/skillet-green-tomatoes-with-crunchy-remoulade-recipe-7568010
# adding recipe
# Parsing https://www.allrecipes.com/chopped-salad-with-figs-and-blue-cheese-recipe-7568016
# adding recipe
# Parsing https://www.allrecipes.com/peanut-butter-snickers-bites-recipe-7566967
# Parsing https://www.allrecipes.com/charred-lemon-paper-plane-recipe-7567985
# adding recipe
# Parsing https://www.allrecipes.com/hash-brown-and-bacon-omelet-cups-recipe-7567917
# adding recipe
# Parsing https://www.allrecipes.com/sweet-potato-and-black-bean-taco-cups-recipe-7567956
# adding recipe
# Parsing https://www.allrecipes.com/perfect-pancakes-recipe-7568285
# adding recipe
# Parsing https://www.allrecipes.com/saucy-vegetable-pinwheels-recipe-7568002
# adding recipe
# Parsing https://www.allrecipes.com/apple-smoothie-recipe-7568869
# adding recipe
# Parsing https://www.allrecipes.com/chicken-broccoli-rice-skillet-recipe-7568422
# adding recipe
# Parsing https://www.allrecipes.com/elote-pizza-recipe-7568835
# adding recipe
# Parsing https://www.allrecipes.com/charcoal-grilled-ribeye-steak-recipe-7567649
# adding recipe
# Parsing https://www.allrecipes.com/kitchen-tips/all-about-ingredients/substitutions/
# Parsing https://www.allrecipes.com/recipes-a-z-6735880
# Parsing https://www.allrecipes.com/article/baking-ingredient-conversions/
# adding recipe
# Error scraping https://www.allrecipes.com/article/baking-ingredient-conversions/. Skipping
# Parsing https://www.allrecipes.com/recipe/21014/good-old-fashioned-pancakes/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/143069/super-delicious-zuppa-toscana/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/23600/worlds-best-lasagna/
# adding recipe
# Parsing https://www.allrecipes.com/recipe/20144/banana-banana-bread/
# adding recipe
# Parsing https://www.allrecipes.com/article/how-to-submit-recipes/
# adding recipe
# Error scraping https://www.allrecipes.com/article/how-to-submit-recipes/. Skipping
# Parsing https://www.allrecipes.com/allstars-6666204
# adding recipe
# Error scraping https://www.allrecipes.com/allstars-6666204. Skipping
# Parsing https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# Parsing https://www.allrecipes.com/food-news-trends/celebrity-entertainment/
# Parsing https://www.allrecipes.com/food-news-trends/trends/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/buying/
# Parsing https://www.allrecipes.com/kitchen-tips/how-to/we-tried-it/
# Parsing https://www.allrecipes.com/food-news-trends/recalls/
# Parsing https://www.allrecipes.com/kitchen-tips/
# ...
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/201/meat-and-poultry/chicken/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/201/meat-and-poultry/chicken/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/200/meat-and-poultry/beef/
# Parsing https://www.allrecipes.com/recipes/201/meat-and-poultry/chicken/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/200/meat-and-poultry/beef/
# Parsing https://www.allrecipes.com/recipes/201/meat-and-poultry/chicken/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/205/meat-and-poultry/pork/
# Parsing https://www.allrecipes.com/recipes/200/meat-and-poultry/beef/
# Parsing https://www.allrecipes.com/recipes/201/meat-and-poultry/chicken/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/205/meat-and-poultry/pork/
# Parsing https://www.allrecipes.com/recipes/200/meat-and-poultry/beef/
# Parsing https://www.allrecipes.com/recipes/201/meat-and-poultry/chicken/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/1058/fruits-and-vegetables/fruits/
# Parsing https://www.allrecipes.com/recipes/205/meat-and-poultry/pork/
# Parsing https://www.allrecipes.com/recipes/200/meat-and-poultry/beef/
# Parsing https://www.allrecipes.com/recipes/201/meat-and-poultry/chicken/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# Parsing https://www.allrecipes.com/recipes/455/everyday-cooking/more-meal-ideas/30-minute-meals/
# Parsing https://www.allrecipes.com/recipes/1947/everyday-cooking/quick-and-easy/
# Parsing https://www.allrecipes.com/recipes/15436/everyday-cooking/one-pot-meals/
# Parsing https://www.allrecipes.com/recipes/17057/everyday-cooking/more-meal-ideas/5-ingredients/main-dishes/
# Parsing https://www.allrecipes.com/recipes/1058/fruits-and-vegetables/fruits/
# Parsing https://www.allrecipes.com/recipes/205/meat-and-poultry/pork/
# Parsing https://www.allrecipes.com/recipes/200/meat-and-poultry/beef/
# Parsing https://www.allrecipes.com/recipes/201/meat-and-poultry/chicken/
# Parsing https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# Parsing https://www.allrecipes.com/recipes/22992/everyday-cooking/sheet-pan-dinners/
# Parsing https://www.allrecipes.com/recipes/16099/everyday-cooking/comfort-food/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[153], line 12
#      10 print(f"Parsing {link}")
#      11 scraped.add(link)
# ---> 12 page = BeautifulSoup(requests.get(link).text, 'html.parser')
#      13 if page.find("h1",attrs={"id":"article-heading_1-0"}) and page.find("img",attrs={"sizes":"750px"}):
#      14     print("adding recipe")
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/hackathon_env/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
with open("/mnt/c/Users/james/OneDrive/Desktop/all_recipes.json","w") as f:
    json.dump({"recipes":recipe_objs},f)

# %%
recipe_objs[0].keys()
# Out:
# dict_keys(['name', 'steps', 'ingredients', 'img', 'Prep Time:', 'Cook Time:', 'Marinate Time:', 'Stand Time:', 'Rest Time:', 'Total Time:', 'Servings:'])

# %%
recipe_objs
# Out:
# [{'name': 'These Grilled Ribeye Steaks Are Juicy and Flavorful',
#   'steps': ['Combine lime juice, carne asada seasoning, and oil in a resealable plastic bag. Add ribeye steak, reseal the bag, and marinate in the refrigerator for 30 to 45 minutes.',
#    'Drain marinade and allow steak to come to room temperature, about 30 minutes. Blot any excess moisture off the steak.',
#    'Preheat the grill to 500 degrees F (260 degrees C), and lightly oil the grate.',
#    'Place steak on the grill over direct heat. For rare: cook steaks until browned on the outside and red in the center, about 3 minutes per side. An instant-read thermometer inserted into the center should read 125 degrees F (52 degrees C).',
#    'Remove steak from grill; rest 5 minutes before serving.',
#    'Additional internal temperatures for cooking steak: Rare: 125-130 degrees F (52-54 degrees C); Medium rare: 130-140 degrees F (54-60 degrees C); Medium:\xa0 140-150 degrees F (54-65 degrees C); Medium well: 150-160 degrees F (65-70 degrees C);\xa0 Well done: 160 degrees F (70 degrees C).'],
#   'ingredients': [{'amt': '1/2', 'unit': 'lime', 'ingred': ', juiced'},
#    {'amt': '2', 'unit': 'teaspoons', 'ingred': 'seasoning'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'olive oil'},
#    {'amt': '1 (8', 'unit': 'ounce)', 'ingred': 'ribeye steak'}],
#   'img': 'https://www.allrecipes.com/thmb/2tQKTk9vGg_v9HrdXYVfDd0CH7E=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7552430_Grilled-Ribeye-Steaks_TheDailyGourmet_4x3-62178245a22845b2a4478e815cd8969f.jpg'},
#  {'name': 'Skillet Chicken Breasts with Cherry Tomatoes',
#   'steps': ['Pat chicken breasts dry with paper towels, and season both sides with smoked paprika, salt, and pepper.',
#    'In a large, non-stick skillet, heat herb-infused olive oil and butter over medium heat. When the butter is foamy, add chicken breasts and cook until browned on both sides, 4 to 5 minutes per side. Remove chicken to a plate and keep warm.',
#    'To the same skillet, add red onion slices and cook until tender, 3 to 4 minutes. If the skillet seems dry, add a bit more olive oil. Stir in garlic; cook until fragrant, about 30 seconds.',
#    'Add white wine; cook and stir for about 1 minute, then add cherry tomatoes and red pepper flakes.',
#    'Stir in cream and cook until sauce is bubble. Return chicken and any accumulated juices to the skillet. Cover, reduce heat to low, and cook until chicken is no longer pink in the center and juices run clear, about 10 minutes. An instant-read thermometer inserted near the center should read at least 165 degrees F (74 degrees C).',
#    'Sprinkle minced fresh basil and grated Parmesan over all. Garnish with additional basil, if desired.'],
#   'ingredients': [{'amt': '1 1/2',
#     'unit': 'pounds',
#     'ingred': 'boneless, skinless chicken breasts'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'smoked paprika'},
#    {'amt': 1,
#     'unit': 'item',
#     'ingred': 'salt and freshly ground black pepper to taste'},
#    {'amt': '2 ', 'unit': 'tablespoons', 'ingred': 'herb-infused olive oil'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'unsalted butter'},
#    {'amt': '1/2', 'unit': 'item', 'ingred': 'red onion, thinly sliced'},
#    {'amt': '3', 'unit': 'cloves', 'ingred': 'garlic, minced'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'white wine'},
#    {'amt': '3', 'unit': 'cups', 'ingred': 'cherry tomatoes, halved'},
#    {'amt': '1/4',
#     'unit': 'teaspoon',
#     'ingred': 'red pepper flakes, or to taste'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'cream, or to taste'},
#    {'amt': '1',
#     'unit': 'tablespoon',
#     'ingred': 'fresh basil, plus more for garnish (optional)'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'grated Parmesan cheese'}],
#   'img': 'https://www.allrecipes.com/thmb/zGTj_99OYuEcelC0USKg7gUYDVQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7553999_Skillet-Chicken-Breasts-with-Cherry-Tomaotes_Bibi_4x3-4a90ae5c8bfd459d87be2cc5d2ab17ac.jpg'},
#  {'name': 'These Dill Ranch Chicken Wraps Are Easy to Make With Rotisserie Chicken',
#   'steps': ['Stir mayonnaise, ranch dressing, dill pickle juice, and dill together in a small bowl.',
#    'Warm tortillas in the microwave on High until warm and pliable, about 30 seconds.',
#    'Spread half of the mayonnaise mixture down the center of each tortilla. In each tortilla, place 2 slices of sharp Cheddar cheese, 1/2 cup lettuce, 2 kosher pickle slices, and 1/2 cup of cooked chicken.',
#    'Fold opposing edges of tortilla to overlap the filling. Roll 1 of the opposing edges around the filling into a wrap.'],
#   'ingredients': [{'amt': '2', 'unit': 'tablespoons', 'ingred': 'mayonnaise'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'ranch dressing'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'pickle juice'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'dried dill'},
#    {'amt': '2', 'unit': '10 inch)', 'ingred': 'flour tortillas'},
#    {'amt': '4', 'unit': 'slices', 'ingred': 'sharp Cheddar cheese'},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'shredded lettuce'},
#    {'amt': '4', 'unit': 'slices', 'ingred': ' dill pickle sandwich '},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'cooked rotisserie chicken'}],
#   'img': 'https://www.allrecipes.com/thmb/0pdpT_zle50ltPpLtgf1Do-wJ70=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7552440_Quick-Dill-Ranch-Chicken-Wrap_Chef-Mo_4x3-e9e235101da346a98925edd9e2cab7cc.jpg'},
#  {'name': 'The Secret to These Crispy Zucchini Fries? Your Air Fryer',
#   'steps': ['Place zucchini fries in a colander. Sprinkle with salt and let sit for 5 minutes. Blot dry with paper towels.',
#    'Place beaten egg in a shallow bowl. Stir bread crumbs and Parmesan cheese together in a separate shallow bowl.',
#    'Dip each fry in beaten egg, then dip in breadcrumb mixture to coat. Place fries on a plate.',
#    'Preheat the air fryer to 400 degrees F (200 degrees C) for 2 minutes.',
#    'Place fries in the basket of the air fryer in a single layer, working in batches if necessary. Lightly spray the tops with nonstick cooking spray.',
#    'Cook until browned to your taste, about 8 minutes. Transfer to a plate and repeat with remaining fries.'],
#   'ingredients': [{'amt': '2 ', 'unit': '(8 ounce)', 'ingred': 'zucchini'},
#    {'amt': 1, 'unit': 'item', 'ingred': 'salt as needed'},
#    {'amt': '1', 'unit': 'large', 'ingred': 'egg, beaten'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'seasoned bread crumbs'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'grated Parmesan cheese'},
#    {'amt': 1, 'unit': 'item', 'ingred': 'nonstick cooking spray'},
#    {'amt': '1/2',
#     'unit': 'cup',
#     'ingred': 'marinara sauce for dipping (optional)'}],
#   'img': 'https://www.allrecipes.com/thmb/h7JgF5oJLWi0e_o5rp6IPU6Baro=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7554904_Air-Fryer-Zucchini-Fries_SoupLovingNicole_4x3-bb0c057fd713474cb6cb3b620769610d.jpg'},
#  {'name': 'Copycat Wendy’s Ranch Sauce',
#   'steps': ['Whisk together mayonnaise, buttermilk, sour cream, vinegar, sugar, onion powder, dill,\xa0parsley, black pepper, salt, and garlic powder in a bowl until well blended. Chill until ready to serve. Store in an airtight container in the refrigerator for up to 3 days.'],
#   'ingredients': [{'amt': '1/2', 'unit': 'cup', 'ingred': 'mayonnaise'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'whole buttermilk'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'sour cream'},
#    {'amt': '3/4', 'unit': 'teaspoon', 'ingred': 'white vinegar'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'white sugar'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'onion powder'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'dried dill'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'dried parsley'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'ground black pepper'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'kosher salt'},
#    {'amt': '1/8', 'unit': 'teaspoon', 'ingred': 'garlic powder'}],
#   'img': 'https://www.allrecipes.com/thmb/mUGNIIZ8Gx8O1rCgUTtUOvuC-LY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556719CopycatWendysRanchSauce2x1-82042801e6074086b88ff93861c3e22c.jpg'},
#  {'name': 'Copycat Chick-Fil-A Honey Mustard',
#   'steps': ['Whisk together mustard, honey, corn syrup, molasses, tamarind paste, and salt\xa0 in a bowl until well blended. Chill until ready to serve.\xa0 Store in an airtight container in the refrigerator up to 2 weeks.'],
#   'ingredients': [{'amt': '1/2', 'unit': 'cup', 'ingred': 'yellow mustard'},
#    {'amt': '1/3', 'unit': 'cup', 'ingred': 'honey'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'corn syrup'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'molasses'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'tamarind'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'kosher salt'}],
#   'img': 'https://www.allrecipes.com/thmb/loCUASLKESxqCrFrjRzC_0kMIps=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556788CopycatChikFilAHoneyMustard2x1-d4f45edef75947e7857aa199ff82bbc9.jpg'},
#  {'name': 'Chipotle-Citrus Marinated Chicken Tacos',
#   'steps': ['Combine lime juice, orange juice, olive oil, chipotle pepper, garlic, cumin, coriander, salt, and black pepper in a blender. Blend on high until smooth.',
#    'Pour marinade mixture into a resealable plastic bag. Add chicken breasts to the bag; marinate in the refrigerator for 3 hours.',
#    'Preheat a grill to 375 degrees F (190 degrees C).',
#    'Place marinated chicken breasts on the grill; close the lid. Discard the marinade. Grill, turning once, until chicken is no longer pink in the center and the juices run clear, 6 to 8 minutes per side. An instant-read thermometer inserted into the center should read at least 165 degrees F (74 degrees C).',
#    'Remove chicken from grill. Let stand for 5 minutes; slice into strips.',
#    'Heat tortillas over a griddle on medium heat until tortillas are soft and pliable. Stack tortillas in pairs; divide chicken, onion, and cilantro onto each pair of tortillas.'],
#   'ingredients': [{'amt': '2', 'unit': 'item', 'ingred': 'limes, juiced'},
#    {'amt': '1', 'unit': 'item', 'ingred': 'orange, juiced'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'olive oil'},
#    {'amt': '1', 'unit': 'item', 'ingred': 'chipotle pepper in adobo'},
#    {'amt': '3', 'unit': 'cloves', 'ingred': 'garlic'},
#    {'amt': '2', 'unit': 'teaspoons', 'ingred': 'ground cumin'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'ground coriander'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'salt'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'ground black pepper'},
#    {'amt': '1',
#     'unit': 'pound',
#     'ingred': 'boneless skinless chicken breasts'},
#    {'amt': '24 ', 'unit': 'item', 'ingred': 'corn tortilla'},
#    {'amt': '1', 'unit': 'small', 'ingred': 'onion, diced'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'chopped cilantro'}],
#   'img': 'https://www.allrecipes.com/thmb/HglpDgXpXi9O8LhegA2YBNqX4-A=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7553405_Chicken-Street-Tacos_TheDailyGourmet_4x3-96f0d6026e5945b9a942a677a1e284e0.jpg'},
#  {'name': 'Pitmaster Potato Salad',
#   'steps': ['Nest potatoes directly in hot coals in a charcoal grill. Surround potatoes with coals for even roasting. Roast until charred, 6 to 7 minutes. Turn potatoes and continue to roast until deeply charred outside and tender inside, 6 to 7 minutes more.',
#    'Remove potatoes to a bowl, cover with foil, and let cool to room temperature, about 30 minutes. Refrigerate until chilled, at least 1 hour, or preferably overnight.',
#    'Combine Dijon mustard, cider vinegar, rice wine vinegar, vegetable oil, salt, black pepper, and cayenne pepper in a bowl for the dressing and whisk thoroughly.',
#    'Scrape, peel, or cut off any fully charred surface of potato, leaving some dark brown bits for a deeper flavor. Cut potatoes into 1/4-inch to 1/2-inch size pieces.',
#    'Add potatoes to dressing, along with red onion, celery, dill pickles, and red peppers. Toss well with a spatula until evenly mixed. Cover; refrigerate for at least 3 hours before serving, or up to overnight.',
#    'Add chives, mix well, and season to taste with salt and pepper before serving.',
#    'Chef John'],
#   'ingredients': [{'amt': '2 1/4',
#     'unit': 'pounds',
#     'ingred': 'ukon gold potatoes'}],
#   'img': 'https://www.allrecipes.com/thmb/HvttjQVnuPN_8N8qSMH_-7Cz2P0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/IMG_1224-4x3-5ad9a674196a41d28b5bbcdd7d14eaca.JPG'},
#  {'name': 'Copycat Waffle House Hash Browns',
#   'steps': ['Whisk together butter and oil in a small bowl. Reserve 2 teaspoons of butter mixture for later. Heat remaining butter mixture on 1 side of a large nonstick skillet over medium-high heat. Place hash browns on buttered side of skillet in a round shape about 5 inches wide. Cook, undisturbed, until browned and crisp around edges, about 5 minutes.',
#    'Flip hash browns, and cook, undisturbed, until other side is browned and crispy, 4 to 5 more minutes. Meanwhile, add reserved butter mixture to other side of skillet; add onion. Cook, stirring often, for 2 minutes. Add ham to onion, and cook 2 minutes. Add onions and ham to top of cooked hash browns. Top with cheese slice; turn off heat. Let stand until cheese is melted; serve immediately.',
#    'Meredith Food Studios'],
#   'ingredients': [{'amt': '1', 'unit': 'tablespoon', 'ingred': 'butter'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'canola oil'},
#    {'amt': '1 1/2', 'unit': 'cup', 'ingred': 'hash browns, partially thawed'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'onion'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'ham'},
#    {'amt': '1', 'unit': 'slice', 'ingred': 'merican cheese'}],
#   'img': 'https://www.allrecipes.com/thmb/a4jNrKrlv9tBAQyZoaV-o6KWdlM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556710_Copycat-Waffle-House-Hash-Browns_Meredith-Food-Studios_4x3-35c2581092a04b2d9f81b03b2ff865d8.jpg'},
#  {'name': 'Mint Oreo Icebox Cake',
#   'steps': ['Beat heavy cream in the bowl of a stand mixer fitted with whisk attachment on medium-high speed for 2 minutes. Add powdered sugar, and beat until stiff peaks form. Place 3/4 cup whipped cream, covered, in the refrigerator to use later for topping. Stir chopped mint into remaining whipped cream.',
#    'Line an 8 1/2 x 4 1/2-inch loaf pan with plastic wrap. Remove tops of the 7 Oreo Cookies, and discard tops. Shingle cookies, green filling side down, along the center of the prepared pan. Spread half of the mint whipped cream in an even layer over the cookies.',
#    'Roughly chop 12 of the Oreo Thins, and sprinkle evenly over whipped cream. Spread remaining mint whipped cream evenly over chopped cookies.',
#    'Cut remaining 6 Oreo Thins in half; place cookie halves on top of mint whipped cream, aligning straight cut edges of cookies with edges of the pan. Fold plastic wrap over cake, and freeze for at least 8 hours.',
#    'To serve, peel plastic wrap from top of cake; invert cake onto a serving plate, remove and discard plastic wrap. Drizzle with chocolate syrup, and top with reserved whipped cream. Garnish with fresh mint, and more cookies if desired.',
#    'Dotdash Meredith Food Studios'],
#   'ingredients': [{'amt': '2 1/2', 'unit': 'cups', 'ingred': 'heavy cream'},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'confectioners sugar'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'fresh mint'},
#    {'amt': '7', 'unit': 'cookie', 'ingred': 'OREO'},
#    {'amt': '18', 'unit': 'cookie', 'ingred': 'OREO Thin'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'chocolate syrup'}],
#   'img': 'https://www.allrecipes.com/thmb/nGoXpC4l1NeBgHe3kHthVGcfx7c=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7550324_Mint-Oreo-Icebox-Cake_Dotdash-Meredith-Food-Studios_4x3-5665e82e6b5a46719926cbfd4b536aa2.jpg'},
#  {'name': 'Copycat Panda Express Chow Mein',
#   'steps': ['Heat canola oil and sesame oil in a wok over high heat. Add onion, celery, and ginger; cook, stirring often, 1 minute. Add coleslaw mix and sprouts; cook, stirring constantly, 2 minutes. Add noodles, and cook, stirring constantly, 1 minute. Add tamari and mirin; cook, stirring occasionally, 2 minutes.',
#    'Dotdash Meredith Video Studios'],
#   'ingredients': [{'amt': '3', 'unit': 'tablespoons', 'ingred': 'canola oil'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'sesame oil'},
#    {'amt': '1/2', 'unit': 'item', 'ingred': 'white onion, finely chopped'},
#    {'amt': '2', 'unit': 'stalks', 'ingred': 'celery, sliced'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'fresh ginger'},
#    {'amt': '3', 'unit': 'cups', 'ingred': 'coleslaw mix'},
#    {'amt': '5', 'unit': 'ounces', 'ingred': 'bean sprouts'},
#    {'amt': '7.1 ', 'unit': 'ounce', 'ingred': 'stir-fry noodles'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'tamari'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'mirin'}],
#   'img': 'https://www.allrecipes.com/thmb/trt4060Dq1A_yKdi7bk1GH5woyQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556785_Copycat-Panda-Express-Chow-Mein_4x3-b38b7bd9af114fe1ac1c8cccc1ccf4a2.jpg'},
#  {'name': 'Bacon, Egg, and Cheese Sandwich',
#   'steps': ['Place bacon in a nonstick skillet and cook over medium-high heat, turning occasionally, until evenly browned, about 7 minutes. Drain bacon slices on paper towels. Remove bacon to a drip line tray. Drain off bacon grease for another use. Wash out the skillet.',
#    'Whisk eggs with salt and pepper in a small bowl until frothy.',
#    'Melt 2 teaspoons butter in the nonstick skillet over medium heat. Pour in beaten eggs; let cook for 30 seconds. Lift the edges of the omelet so that the uncooked egg runs under the cooked edges and comes into contact with the hot skillet. Shake and tilt the skillet to move the uncooked egg. Repeat until the top is set, about 3 minutes; reduce heat to low.',
#    'Meanwhile, chop bacon roughly; sprinkle over omelet. Sprinkle with cheese; allow cheese to melt, 1 to 2 minutes.',
#    'Meanwhile, butter 2 slices of bread with 1/2 teaspoon butter each. Lay bread, buttered side up, side-by-side over omelet, leaving about 1 inch between slices. The melted cheese will help the bread adhere.',
#    'Run a spatula around the entire omelet to loosen from the skillet. Carefully turn the omelet over so buttered side of bread is in contact with the skillet. Cook until bread is toasted and golden, about 2 minutes.',
#    'Using the spatula, fold in edges of omelet to align with sides of the bread. Cut omelet along center with the spatula to form 2 sandwiches. Butter 2 remaining bread slices with remaining butter; place butter side up on each sandwich. Turn sandwiches; cook until golden, about 2 minutes more. Serve and enjoy immediately!'],
#   'ingredients': [{'amt': '2', 'unit': 'slices', 'ingred': 'bacon'},
#    {'amt': '4', 'unit': 'teaspoons', 'ingred': 'butter, divided'},
#    {'amt': '3', 'unit': 'large', 'ingred': 'eggs'},
#    {'amt': '1', 'unit': 'pinch', 'ingred': 'black pepper'},
#    {'amt': '1', 'unit': 'pinch', 'ingred': 'salt'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'shredded Cheddar cheese'},
#    {'amt': '4', 'unit': 'slices', 'ingred': 'bread'}],
#   'img': 'https://www.allrecipes.com/thmb/GHGcqSRe4ty-qTwYj47DAj31Lf0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7557506_Bacon-Egg-and-Cheese-Sandwich_Thedailygourmet_4x3-96273724754c4b59985d2e5b75355f23.jpg'},
#  {'name': 'Puff Pastry Cherry Crostata',
#   'steps': ['Preheat the oven to 400 degrees F (200 degrees C). Line a baking sheet with parchment paper.',
#    'On a lightly floured surface, roll a well-chilled puff pastry sheet into an approximate 11 to 12-inch round. Trim edges into a circle shape, and transfer to the lined baking sheet.',
#    'Stir cherries, brown sugar, cornstarch, cinnamon, almond extract, and salt together in a bowl until cherries are well coated. Spoon cherry mixture into the center of the pastry, leaving a 2-inch border. Lift up edges of the crust, and fold around, overlapping the cherry mixture.',
#    'Whisk egg and water into an egg wash, brush edges of the pastry, and sprinkle with turbinado.',
#    'Bake in the preheated oven until cherries are tender and crust is golden brown, 23 to 30 minutes. Warm marmalade in the microwave until melted, 15 to 20 seconds, and drizzle over the cherries to glaze.',
#    'Allow to cool for about 15 minutes before cutting into wedges to serve.'],
#   'ingredients': [{'amt': '1/2 (17.3',
#     'unit': 'ounce) package',
#     'ingred': 'puff pastry sheets, thawed'},
#    {'amt': '1', 'unit': 'pound', 'ingred': 'cherries, pitted and halved'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'brown sugar'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'cornstarch'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'cinnamon'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'almond extract'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'salt'},
#    {'amt': '1', 'unit': 'large', 'ingred': 'egg, beaten'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'water'},
#    {'amt': '1',
#     'unit': 'tablespoon',
#     'ingred': 'turbinado sugar, or to taste'},
#    {'amt': '1',
#     'unit': 'tablespoon',
#     'ingred': 'orange marmalade (optional)'}],
#   'img': 'https://www.allrecipes.com/thmb/xcaCmzheejvXWZNUkUpalonmQAs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7558586_Puff-Pastry-Cherry-Crostata_lutzflcat_4x3-51270368fa904f199d4021ed270a98b6.jpg'},
#  {'name': 'Barbecued Butter Chicken',
#   'steps': ['Add water, vinegar, Worcestershire sauce, salt, pepper, paprika, garlic powder, poultry seasoning, onion powder, cayenne pepper, and butter to a saucepan. Place over medium heat until butter is halfway melted; turn off heat, and whisk until butter disappears. Let marinade cool to room temperature, about 10 minutes.',
#    'Cut chicken into halves or quarters and place in a resealable plastic bag. Whisk cooled marinade thoroughly and pour into the bag. Squeeze out air and seal tightly.',
#    'Marinate in the refrigerator for at least 4 hours and up to overnight, turning the bag occasionally. (At this point, chicken is ready to be roasted or grilled. What follows are instructions for partially baking chicken, then finishing on the grill.)',
#    'Preheat the oven to 325 degrees F (165 degrees C). Place chicken pieces, skin side up, in a baking dish; pour in all of the marinade.',
#    'Bake in the preheated oven for 35 minutes. (At this point, the partially baked chicken can be transferred to a plate and refrigerated until ready to finish cooking on a grill, or you can proceed immediately with grilling.)',
#    'Prepare an outdoor grill with charcoal. Coals should be hot and white, without active flame. Alternately, preheat a gas grill for medium heat.',
#    'Pour marinade into a saucepan, and bring to a boil over medium heat. Set aside to use as a basting sauce and finishing sauce.',
#    'Place the chicken on the grill, skin side down. Cook over hot coals with the cover on, adjusting the vents to keep the heat down, until skin has a little color, about 4 minutes. Turn and continue to cook, turning occasionally, basting with sauce each time, 10 to 20 minutes more. The majority of the cooking takes place with the chicken skin side up.',
#    'For perfectly cooked breasts, pull breasts off the grill when the internal temperature, measured with an instant-read thermometer, reaches at least 150 degrees F (66 degrees C). For perfectly cooked leg sections, pull off the grill at 175 degrees F (80 degrees C). Tent chicken with foil; rest for 5 to 10 minutes. The internal temperature will continue to rise.',
#    'Chef John',
#    'For chicken halves, it will be difficult if not impossible to attain the perfect cooking temperature for breast and leg portions at the same time. You will likely have to pull the chicken off the grill when the breast meat is slightly overcooked, and the leg meat is slightly undercooked. For all the meat to be perfectly cooked, you will need to separate the pieces.',
#    'You can use the same basic vinegar and butter marinade, but change the spices to create different flavor profiles.'],
#   'ingredients': [{'amt': '1/2', 'unit': 'cup', 'ingred': 'water'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'apple cider vinegar'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'orcestershire sauce'},
#    {'amt': '2',
#     'unit': 'teaspoons',
#     'ingred': 'kosher salt, or about 1 teaspoon per pound of chicken'},
#    {'amt': '2', 'unit': 'teaspoons', 'ingred': 'ground black pepper'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'paprika'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'garlic powder'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'poultry seasoning'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'onion powder'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'cayenne pepper'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'unsalted butter'},
#    {'amt': '1',
#     'unit': 'item',
#     'ingred': 'whole chicken, halved or quartered'}],
#   'img': 'https://www.allrecipes.com/thmb/mJNbiYJK_SWUHq1jrKSfMdmPji8=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560707_Barbecued-Butter-Chicken_Chef-John_4x3-80385d63fec64f70a92301e4d7203594.jpg'},
#  {'name': 'Sweeten Your Summer With Homemade Peach Crumble',
#   'steps': ['Preheat the oven to 375 degrees F (190 degrees C). Lightly grease a 2-1/2 quart baking dish.',
#    'Place peaches in the prepared baking dish. Combine brown sugar, 3 tablespoons flour, lemon juice, lemon zest, and cinnamon; sprinkle over peaches.',
#    'Combine 1 cup flour, sugar, baking powder, salt, and nutmeg. Stir in egg and mix until mixture has pea-sized crumbles. Sprinkle mixture over peaches. Pour butter evenly over crumbles.',
#    'Bake in the preheated oven until the top is lightly browned, 37 to 40 minutes.'],
#   'ingredients': [{'amt': '6', 'unit': 'cups', 'ingred': 'fresh peaches'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'brown sugar'},
#    {'amt': '3', 'unit': 'tablespoons', 'ingred': 'flour'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'lemon juice'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'lemon zest'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'cinnamon'}],
#   'img': 'https://www.allrecipes.com/thmb/0UV0p5llzoQQXWiWLfRHwYMlI58=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559227_Peach-Crumble_Yoly_4x3-7e149ba49cc547208734322a9b588b46.jpg'},
#  {'name': 'Sparkling Mango Pineapple Sangria',
#   'steps': ['Stir pineapple juice, mango juice, pineapple rum, mango rum, chunked pineapple, and mango slices together in a large pitcher. Chill for 2 to 4 hours.',
#    'Add Prosecco before serving. Stir and serve cold.'],
#   'ingredients': [{'amt': '1/2', 'unit': 'cup', 'ingred': 'pineapple juice'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'mango juice'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'rum'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'rum'},
#    {'amt': '1/2',
#     'unit': 'item',
#     'ingred': 'fresh pineapple - peeled, cored, and cut into chunks'},
#    {'amt': '2',
#     'unit': 'item',
#     'ingred': 'mangos - peeled, seeded, and sliced'},
#    {'amt': '750mL', 'unit': 'item', 'ingred': 'Prosecco'}],
#   'img': 'https://www.allrecipes.com/thmb/ocxqtbdponuhPnoajOjjRfW7MKs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560880_Sparkling-Mango-Pineapple-Sangria_Chef-Mo_4x3-003cb883544a47cfbf2cee1e2a552935.jpg'},
#  {'name': 'Grilled Pizza Bianca',
#   'steps': ['Melt butter in a small saucepan over medium-high heat. Add garlic and cook until fragrant, about 30 seconds; stir in cream. Add 2/3 cup Parmesan cheese, and stir until smooth. Let Alfredo sauce cool to room temperature, about 15 minutes.',
#    'Meanwhile, preheat a gas grill with all burners on High for 10 to 15 minutes.',
#    'Divide pizza dough in half. Shape each portion of the pizza dough into an 8 to 10-inch disc. Reduce the flame on half the grill burners to Low, to create areas of direct and indirect heat.',
#    'Carefully place discs of dough, one at a time, onto the grill over direct heat. Close the cover. Let dough grill until the bottom is just barely cooked and shows char marks, 1 to 3 minutes.',
#    'Turn crust ninety degrees (do not flip dough over). Grill until crust shows light grill marks, 1 to 3 minutes.',
#    'Move pizza dough to indirect heat. Spoon Alfredo sauce over dough. Top each crust with four slices mozzarella cheese. Sprinkle remaining 1/3 cup Parmesan cheese evenly over pizzas.',
#    'Grill until cheese is melted, about 3 minutes. Carefully remove pizza from the grill.',
#    'Preheat the oven’s broiler. Broil pizza until cheese is golden, about 5 minutes. Allow pizza to rest a few minutes before cutting into wedges.'],
#   'ingredients': [{'amt': '1', 'unit': 'tablespoon', 'ingred': 'butter'},
#    {'amt': '1', 'unit': 'clove', 'ingred': 'garlic, minced'},
#    {'amt': '1/3', 'unit': 'cup', 'ingred': 'heavy cream'},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'grated Parmesan cheese, divided'},
#    {'amt': '1', 'unit': 'pound', 'ingred': 'pizza dough'},
#    {'amt': '8', 'unit': 'slices', 'ingred': 'mozzarella cheese'}],
#   'img': 'https://www.allrecipes.com/thmb/6Ow2IAYsBXPOsoMyBA9mW2sKt_o=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559340_Grilled-Pizza-Bianca_TheDailyGourmet_4x3-6bf713dd816848518d21ce59f4303098.jpg'},
#  {'name': 'Agua Fresca de Fresas con Crema (Strawberries and Cream)',
#   'steps': ['Place 2 pounds of the strawberries and water in a blender cup and blend until smooth.',
#    'Pour strawberry puree into a large pitcher. Add sweetened condensed milk, evaporated milk, and vanilla. Stir until well incorporated. Taste; add sugar, a little at a time, as needed.',
#    'Add ice cubes and stir. Gently stir in remaining 1/2 pound diced strawberries. Chill until ready to serve.'],
#   'ingredients': [{'amt': '2 1/2',
#     'unit': 'pounds',
#     'ingred': 'strawberries, hulled and diced, divided'},
#    {'amt': '2', 'unit': 'cups', 'ingred': 'water'},
#    {'amt': '1 (14 1/2',
#     'unit': 'ounce) can',
#     'ingred': 'sweetened condensed milk'},
#    {'amt': '1 (12', 'unit': 'ounce) can e', 'ingred': 'vaporated milk'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'vanilla'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'sugar, or as needed'},
#    {'amt': '3', 'unit': 'cups', 'ingred': 'ice cubes, or as needed'}],
#   'img': 'https://www.allrecipes.com/thmb/uC3iX9Lmlu5B3Q37w5qFAnbLzhM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560919_Agua-Fresca-de-Fresas-con-Crema-Strawberries-and-Cream_Yoly_4x3-330b05ace24443dd90caa0c426153198.jpg'},
#  {'name': 'Spicy Canned Salmon Salad Rice Bowl',
#   'steps': ['Combine chopped cucumbers and soy sauce in a small bowl and set aside.',
#    'In a small bowl, combine the salmon, Sriracha®, mayonnaise, and rice vinegar.',
#    'In a bowl place cooked rice and top it with the salmon mixture, sliced avocado, and chopped cucumber mixture. Sprinkle with sesame seeds. Top with extra Sriracha and green onions if desired.'],
#   'ingredients': [{'amt': '1', 'unit': 'cup', 'ingred': 'nglish cucumber'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'low-sodium soy sauce'},
#    {'amt': '1 (14 3/4',
#     'unit': 'ounce) can pink',
#     'ingred': 'salmon, skin and bone removed, drained and flaked'},
#    {'amt': '2 ½', 'unit': ' tablespoons', 'ingred': 'Sriracha'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'light mayonnaise'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'rice vinegar'},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'cooked white rice'},
#    {'amt': '1', 'unit': 'item', 'ingred': 'avocado '},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'sesame seeds'},
#    {'amt': '1',
#     'unit': 'tablespoon',
#     'ingred': 'green onion for garnish (optional)'}],
#   'img': 'https://www.allrecipes.com/thmb/wwoULX6PkbIKFnwR-Iea2mIhuhc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7558696_Spicy-Canned-Salmon-Salad-Rice-Bowl_Chef-Mo_4x3-6efacad1958d41d892d0b30ec8a7d3a7.jpg'},
#  {'name': 'Copycat Chick-fil-A Frosted Lemonade',
#   'steps': ['Place ice cream, frozen lemonade concentrate, and lemon zest in the jar of a blender, and blend until smooth. Divide into 4 glasses, and serve immediately.',
#    'Dotdash Meredith Video Studios',
#    'Put your own spin on this frosted lemonade by using a different flavor of ice cream–strawberry would be delicious–or adding another cooling kick of flavor with fresh mint leaves. You can also give this frozen drink the “grown-up” treatment by adding a splash of vodka.'],
#   'ingredients': [{'amt': '4', 'unit': 'cups', 'ingred': 'vanilla ice cream'},
#    {'amt': '12', 'unit': 'ounces', 'ingred': 'frozen lemonade concentrate'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'lemon zest'}],
#   'img': 'https://www.allrecipes.com/thmb/Q5XBarWwOV37i5Pniydf-nVWLy4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7550375_Copycat-Chick-Fil-A-Frosted-Lemonade_Dotdash-Meredith-Video-Studios_4x3-aadc1c4be9bd4da68e0981b1d18a9f25.jpg'},
#  {'name': 'Basic No-Soak Beans',
#   'steps': ['Preheat the oven to 300 degrees F (150 degrees C).',
#    'Bring cold water to a boil in a heavy-bottomed Dutch oven over high heat. Add beans and salt, and return to a simmer; cover.',
#    'Bake beans in the preheated oven until tender, about 1 hour and 10 minutes, checking after 30 minutes to ensure beans are still covered with water. If necessary, add just enough water to cover.',
#    'Dotdash Meredith Video Studios'],
#   'ingredients': [{'amt': '6', 'unit': 'cups', 'ingred': 'water'},
#    {'amt': '1', 'unit': 'pound', 'ingred': 'dried bean'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'kosher salt'}],
#   'img': 'https://www.allrecipes.com/thmb/jDpU9g6MczG7PhMbC4ed271gaOs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7555578_Basic-No-Soak-Beans_Dotdash-Meredith-Video-Studios_4x3-1eac7c57575147ffb69e4a2bcd5f19a6.jpg'},
#  {'name': 'Cornflake Corn Cake',
#   'steps': ['Preheat the oven to 400 degrees F (200 degrees C). Grease a 9-inch round cake pan generously with 1 teaspoon butter, and place a circle of parchment in the bottom.',
#    'Whisk egg and sugar together in a bowl until light and fluffy, about 1 minute. Whisk in melted butter, yogurt, and milk until combined.',
#    'Add cornmeal, flour, salt, baking powder, and baking soda to egg mixture; whisk until dry ingredients are moistened. Fold in 2 cups of the cornflakes with a spatula. Transfer batter to the prepared pan, and smooth the top.',
#    'Scatter remaining 1/2 cup cornflakes evenly over the top; press in lightly with your fingers.',
#    'Bake in the preheated oven until a skewer inserted near the center comes out clean, about 25 minutes.',
#    'Cool cake in the pan for 15 to 20 minutes before removing to a plate. Cool completely before serving with fresh fruit or a fruit sauce.',
#    'Chef John'],
#   'ingredients': [{'amt': '1',
#     'unit': 'teaspoon',
#     'ingred': 'butter to grease pan'},
#    {'amt': '1', 'unit': 'large ', 'ingred': 'egg'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'white sugar'},
#    {'amt': '6', 'unit': 'tablespoons', 'ingred': 'unsalted butter, melted'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'plain yogurt'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'milk'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'cornmeal'},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'all-purpose flour'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'salt'},
#    {'amt': '1 1/2', 'unit': 'teaspoons', 'ingred': 'baking powder'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'baking soda'},
#    {'amt': '2 1/2', 'unit': 'cups', 'ingred': 'cornflakes, divided'}],
#   'img': 'https://www.allrecipes.com/thmb/ir7I-bEPOA_-3NBwqM0tZSEJmDg=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7562367_Cornflake-Corn-Cake_Chef-John_4x3-f5adebd77a2643e4b10ef9b4125966cf.jpg'},
#  {'name': 'Air Fryer Cheesy Bacon Ranch French Fries',
#   'steps': ['Preheat an air fryer to 400 degrees Fahrenheit (200 degrees C). Place frozen French fries in a large bowl.',
#    'Whisk olive oil and dry ranch salad mix in a separate small bowl until smooth. Pour olive oil mixture over the fries and toss to coat. Add bacon bits and salt. Toss again.',
#    'Place seasoned fries in the basket of the air fryer. Cook for 7 minutes. Shake the basket and cook 5 minutes more.',
#    'Sprinkle shredded cheese over the fries. Cook 2 minutes. Using a spatula, transfer to a serving platter and serve immediately.'],
#   'ingredients': [{'amt': '4',
#     'unit': 'cups',
#     'ingred': 'frozen French fries'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'olive oil'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'ranch salad dressing mix'},
#    {'amt': '2', 'unit': 'teaspoons', 'ingred': 'bacon bits'},
#    {'amt': '1', 'unit': 'pinch', 'ingred': 'salt'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'shredded Cheddar cheese'}],
#   'img': 'https://www.allrecipes.com/thmb/rRqByx76RLk27s9-YYKfloAp_ng=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560981_Air-Fryer-Cheesy-Bacon-Ranch-Fries-Soup-Loving-Nicole_4x3-3db3470e8a3d4bdb8523989590c2ca52.jpg'},
#  {'name': 'Sparkling Peach Sangria',
#   'steps': ['Early in the day, refrigerate prosecco. Combine peach slices, Cointreau, half of lime slices, mint leaves, and grated ginger in a container with a lid. Refrigerate at least 6 hours, making sure peaches are submerged in liquid.',
#    'When ready to serve, pour peach mixture into a large serving pitcher and add prosecco. Stir briefly to combine.',
#    'Place some of the fruit in each glass, add sangria, and top with 2 ounces sparkling water, or to taste. Garnish with reserved lime slices and additional mint leaves, if desired.'],
#   'ingredients': [{'amt': '1 (750',
#     'unit': 'ml) bottle',
#     'ingred': 'rosecco, well chilled'},
#    {'amt': '2', 'unit': 'item', 'ingred': 'peaches, thinly sliced'},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'ointreau liqueur'},
#    {'amt': '2',
#     'unit': 'limes, thinly sliced, divided',
#     'ingred': 'limes, thinly sliced, divided'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'mint leaves'},
#    {'amt': '1',
#     'unit': '(1-inch) piece fresh',
#     'ingred': 'ginger, finely grated'},
#    {'amt': '12', 'unit': 'ounces', 'ingred': 'sparkling water, or to taste'},
#    {'amt': '2',
#     'unit': 'tablespoons',
#     'ingred': 'mint leaves for garnish (optional)'}],
#   'img': 'https://www.allrecipes.com/thmb/uCCR_7BRVqGpaIlHLhpHUh2rc8A=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559189_Sparkling-Peach-Sangria_Bibi_4x3-3d110afa6a3042c98a94ea8997aaa64e.jpg'},
#  {'name': 'Gold Rush',
#   'steps': ['In a small saucepan, combine honey and water over medium heat. Bring to a simmer, stirring, until honey is dissolved. Remove from heat and cool completely. To account for evaporation, add a splash of water to bring the total volume of syrup up to 3 fluid ounces, if necessary.',
#    'Add 1 cup of ice to a cocktail shaker. Add bourbon, honey syrup and lemon juice. Cover and shake until chilled, 15 to 20 seconds. Fill a rocks glass with remaining ice cubes or 1 large ice sphere and strain cocktail over the ice. Garnish with lemon twist.',
#    'Honey syrup recipe makes enough syrup for 4 cocktails.',
#    'Nutrition data for this recipe includes the full amount of honey syrup; the actual amount consumed will vary.'],
#   'ingredients': [{'amt': '1/4', 'unit': 'cup', 'ingred': 'honey'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'water'}],
#   'img': 'https://www.allrecipes.com/thmb/MIeZi_ZYZ02B9J6GYs9OAF8-lTU=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7562213_GoldRush_France-C_4x3-74ad4dc4d4f740c08398f71f144eab98.jpg'},
#  {'name': 'Perfect Fried Shrimp',
#   'steps': ['Pour oil to a depth of 2 inches in a large deep skillet; heat over medium-high to 370 degrees F (185 degrees C).',
#    'Whisk together eggs, milk, and hot sauce in a shallow dish; add shrimp to mixture, and toss to coat. Whisk together flour, cornmeal, salt, black pepper, and cayenne pepper in a separate shallow dish.',
#    'Remove 6 to 8 shrimp from egg mixture, shaking excess off; dredge in flour mixture. Place dredged shrimp in hot oil; fry until coating is golden and crisp, about 2 minutes. Remove with a slotted spoon to a baking sheet lined with paper towels. Repeat with remaining shrimp, bringing oil back to 370 degrees F(185 degrees C) over medium-high heat before adding each batch of shrimp.',
#    'Dotdash Meredith Video Studios',
#    'If you like, you can easily dress up the flavors by adding your favorite spices, such as paprika, cumin, or more cayenne. Depending on the size of your shrimp, you may have to adjust your cooking time.',
#    'Nutrition data for this recipe includes the full amount of breading ingredients. The actual amount of breading consumed will vary. We have determined the nutritional value of oil for frying based on a retention value of 10% after cooking. The exact amount will vary depending on cooking time and temperature, ingredient density, and specific type of oil used.'],
#   'ingredients': [{'amt': '3',
#     'unit': 'cups',
#     'ingred': 'canola oil, or as needed'},
#    {'amt': '2', 'unit': 'large', 'ingred': ' eggs, beaten'},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'whole milk'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'hot sauce'},
#    {'amt': '2', 'unit': 'pounds', 'ingred': 'raw shrimp'},
#    {'amt': '3/4', 'unit': 'cup', 'ingred': 'all-purpose flour'},
#    {'amt': '2/3', 'unit': 'cup', 'ingred': 'cornmeal'},
#    {'amt': '1 1/2', 'unit': 'teaspoons', 'ingred': 'kosher salt'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'black pepper'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'cayenne pepper'}],
#   'img': 'https://www.allrecipes.com/thmb/WpM69EEVN8p41sHEOUpDmgqsLHI=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556606_Perfect-Fried-Shrimp_Dotdash-Meredith-Video-Studios_4x3-37c5e7cb6a0e40a1b71862f4b037dcec.jpg'},
#  {'name': 'Rotisserie Chicken Wrap with Strawberries',
#   'steps': ['For the dressing, add maple syrup, olive oil, red wine vinegar, mustard, poppy seeds, and salt to a jar with a tight-fitting lid. Seal jar and shake vigorously to blend.',
#    'Toss spinach, chicken, strawberries, pecans, and feta cheese together in a bowl. Drizzle 2 tablespoons dressing into salad; toss to combine.',
#    'Microwave tortillas until pliable, 10 to 20 seconds. Lay tortillas on a clean surface, and spoon an equal portion of chicken salad in the center of each tortilla.',
#    'Fold in sides of tortillas, almost to the center. Bring the bottom of the tortilla over the folded sides, tuck tightly over filling and roll until the sandwich is secured. Slice sandwich wrap in half on the diagonal, if desired. Serve with remaining salad dressing.'],
#   'ingredients': [{'amt': '2', 'unit': 'tablespoons', 'ingred': 'maple syrup'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'olive oil'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'red wine vinegar'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'Dijon mustard'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'poppy seeds'},
#    {'amt': '1', 'unit': 'pinch', 'ingred': 'salt'}],
#   'img': 'https://www.allrecipes.com/thmb/l67h0CqMT6JmmoHs9ythIK_D_b4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559150_Rotisserie-Chicken-Wrap-With-Strawberries_TheDailyGourmet_4x3-1a44c1c5ddcf486d916db6b2bddb10bc.jpg'},
#  {'name': 'Lazy Hazy Beef Chili',
#   'steps': ['Add beef to a dry cold pot, and turn heat to high.',
#    'When beef begins to sizzle, break up into small pieces with a potato masher or spatula. Meat can be broken up into very fine crumbles, or into larger chunks, depending on the desired texture. Continue to cook and break up beef until no longer pink, about 7 minutes.',
#    'Add chili powder, chipotle, black pepper, salt, and cinnamon to the pot. Cook, stirring, for 1 minute, then pour in beer.',
#    'Stir, scraping the browned bits from the bottom of the pot as you do. Let mixture boil until liquid is reduced by about half, 2 to 3 minutes.',
#    'Add sugar, oregano, garlic powder, diced tomatoes and jarred salsa. Stir in; return mixture to a simmer.',
#    'Stir in beans, reduce heat to medium-low, and cook, stirring occasionally, until chili is thickened and flavor is developed to your liking, about 1 hour.',
#    'Taste, adjust the seasoning. Top with sour cream, green onions, Cheddar cheese, and cilantro as desired.',
#    'Chef John'],
#   'ingredients': [{'amt': '2', 'unit': 'pounds', 'ingred': 'ground beef'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'chili powder, or to taste'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'chipotle'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'ground black pepper'},
#    {'amt': '2',
#     'unit': 'teaspoons',
#     'ingred': 'kosher salt, plus more to taste'},
#    {'amt': '1/8', 'unit': 'teaspoon', 'ingred': 'cinnamon'},
#    {'amt': '12', 'unit': 'ounces', 'ingred': ' beer'},
#    {'amt': '2', 'unit': 'teaspoons', 'ingred': 'white sugar'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'dried oregano'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'garlic powder'},
#    {'amt': '1',
#     'unit': '(14.5 ounce)',
#     'ingred': 'tomatoes with green chilies'},
#    {'amt': '2 (16 ounce jars) extra chunky',
#     'unit': 'item',
#     'ingred': 'salsa'},
#    {'amt': '2', 'unit': '15 ounce) cans', 'ingred': 'pinto beans, drained'}],
#   'img': 'https://www.allrecipes.com/thmb/5mKdJQNx76GujI5vKxRRvzNd8A8=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7562950_Lazy-Hazy-Beef-Chili_Chef-John_4x3-e931f35d91b44e9d93f99ec5c8bd7e2a.jpg'},
#  {'name': 'Salmon Couscous Salad',
#   'steps': ['Add mayonnaise, buttermilk, pesto, lemon juice, and garlic to the bowl of a food processor. Blend until smooth. Season to taste with black pepper. Set dressing aside.',
#    'Meanwhile, heat a skillet over medium-high heat. Season salmon with Greek seasoning. Cut salmon into two filets. Melt butter in a skillet over medium heat and add olive oil. Place salmon, skin side down, in the hot skillet. Cook until salmon flakes easily with a fork, about 8 minutes.',
#    'Bring water to a boil in a saucepan; remove from heat and stir couscous into the water. Cover saucepan and let stand until water is absorbed completely, about 10 minutes.',
#    'To assemble, place salad mixture into 2 dinner bowls, and sprinkle chopped tomatoes over the salad. Fluff couscous with a fork. Mound couscous in the center of each bowl. Sprinkle Parmesan cheese around couscous. Place a salmon filet to the side of the couscous. Pour 1 to 2 tablespoons pesto dressing on top of dish. Sprinkle with pepitas. Serve immediately.',
#    'Nutrition data for this recipe includes the full amount of dressing ingredients. The actual amount of dressing consumed will vary.'],
#   'ingredients': [{'amt': '1/2', 'unit': 'cup', 'ingred': 'mayonnaise'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'buttermilk'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'pesto'},
#    {'amt': '1', 'unit': 'lemon, ', 'ingred': 'juiced'},
#    {'amt': '1', 'unit': 'clove', 'ingred': 'garlic'},
#    {'amt': 1, 'unit': ' ground', 'ingred': 'black pepper to taste'}],
#   'img': 'https://www.allrecipes.com/thmb/NDzo_xlg1ew7z-wXN1KmO7ge9ks=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7561932_Salmon-Couscous-Salad_TheDailyGourmet_4x3-e770324e8ab44d2097bbbc9c48be0122.jpg'},
#  {'name': 'Southern Baked Beans',
#   'steps': ['Gather all ingredients.',
#    'Dotdash Meredith Food Studios',
#    'Preheat oven to 350 degrees F (175 degrees C). Cook ground beef on a large skillet over medium-high heat until browned, 5 to 8 minutes. Remove from skillet and reserve.',
#    'Dotdash Meredith Food Studios',
#    'Cook bacon in the same skillet 5 minutes.',
#    'Dotdash Meredith Food Studios',
#    'Add onion and green pepper to skillet. Cook, stirring frequently, until bacon is crisp and onion is translucent, about 5 minutes.',
#    'Dotdash Meredith Food Studios',
#    'Add ground beef, brown sugar, ketchup, Worcestershire sauce, and mustard to the bacon mixture; stir until combined.',
#    'Dotdash Meredith Food Studios',
#    'Add ground beef mixture and beans to a 13x9-inch baking dish, stir to combine.',
#    'Dotdash Meredith Food Studios',
# ...
#  {'name': 'Saucy Vegetable Pinwheels',
#   'steps': ['For sauce, process roasted red peppers, yogurt, orange zest (or other CITRUS ZEST), orange juice (or other CITRUS JUICE), chopped parsley (or other FRESH HERB), salt, and black pepper in a food processor until smooth.',
#    'Spread tortillas evenly with sauce and top with arugula and carrots (or other 2 VEGETABLES). Roll up and wrap tightly in plastic wrap. Chill at least 1 hour or up to 12 hours. To serve, unwrap tortillas and trim ends. Cut rolls into slices.',
#    '8 cups arugula and/or spring mix',
#    '4 cups shredded red cabbage',
#    '2 red bell peppers, julienned (2 cups)',
#    '2 zucchini, sliced (4 cups)',
#    '2 large carrots, julienned (2 cups)',
#    '4 ounces radishes, sliced (1 cup)',
#    'LIME-CABBAGE',
#    'lime zest + lime juice + cilantro + red cabbage + red bell pepper',
#    'LEMON-ZUCCHINI',
#    'lemon zest + lemon juice + chives + zucchini +radishes'],
#   'ingredients': [{'amt': '1', 'unit': 'cup', 'ingred': 'roasted red peppers'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'yogurt'},
#    {'amt': '1 ', 'unit': 'teaspoon ', 'ingred': 'orange zest'},
#    {'amt': '1',
#     'unit': 'tablespoons orange ',
#     'ingred': 'juice (or other CITRUS JUICE)'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'chopped fresh parsley '},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'salt'},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'black pepper'},
#    {'amt': '4',
#     'unit': ' (12-inch) ',
#     'ingred': 'plain, spinach, and/or roasted red pepper tortillas'},
#    {'amt': '8', 'unit': 'cups', 'ingred': 'arugula (or other VEGETABLE)'},
#    {'amt': '2',
#     'unit': 'cups',
#     'ingred': 'julienned carrots (or other VEGETABLE)'}],
#   'img': 'https://www.allrecipes.com/thmb/9udnholrcOw2WTtsDACWoahamqw=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568002-vegetable-pinwheels-GOLDMAN-4x3-3184-f5bf34b04f064617a0991d341e7fa4d0.jpg'},
#  {'name': 'Apple Smoothie',
#   'steps': ['Place banana, apple, yogurt, apple juice, oats, almond butter, maple syrup, cinnamon, nutmeg, and cloves into the cup of a high speed blender, and blend until smooth. If desired, add ice for a thicker smoothie, or add milk for a thinner consistency.'],
#   'ingredients': [{'amt': '1',
#     'unit': 'small',
#     'ingred': 'banana, peeled and frozen'},
#    {'amt': '1', 'unit': 'large', 'ingred': 'uji apple, cored and sliced'},
#    {'amt': '3/4', 'unit': 'cup', 'ingred': 'whole milk plain Greek yogurt'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'unsweetened apple juice'},
#    {'amt': '3', 'unit': 'tablespoons', 'ingred': 'rolled oats'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'almond butter'},
#    {'amt': '2', 'unit': 'teaspoons', 'ingred': 'maple syrup, or to taste'},
#    {'amt': '1', 'unit': 'pinch', 'ingred': 'ground cinnamon'},
#    {'amt': '1', 'unit': 'pinch', 'ingred': 'ground nutmeg'},
#    {'amt': '1', 'unit': 'pinch', 'ingred': 'ground cloves'}],
#   'img': 'https://www.allrecipes.com/thmb/gvn7lJddUFx2SE4vJPAqskjqBAE=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568869_Apple-Smoothie_Kim_4x3-c282869bfeff49d8a01b5b82c089805f.jpg'},
#  {'name': 'Chicken Broccoli Rice Skillet',
#   'steps': ['Melt butter in a large nonstick skillet over medium heat, and cook and stir onions until softened and translucent, about 5 minutes.',
#    'Meanwhile, cut chicken breast into bite-sized pieces. Add chicken to the skillet; cook and stir until golden, about 5 minutes.',
#    'Add orzo and rice with seasoning packet to skillet. In a medium bowl, stir together chicken broth, milk, cream of chicken soup, oregano, and garlic; pour mixture into skillet. Stir to combine; add broccoli florets',
#    'Reduce heat to low, cover, and cook until rice and orzo are tender with a bite and liquid is absorbed, about 25 minutes',
#    'Turn on the oven’s broiler and set a rack 6 inches below the heating element. Sprinkle cheese over the skillet, and broil until cheese is golden and melted, about 3 minutes. Serve immediately.'],
#   'ingredients': [{'amt': '1', 'unit': 'tablespoon', 'ingred': 'butter'},
#    {'amt': '1', 'unit': 'small', 'ingred': 'onion, diced'},
#    {'amt': '1', 'unit': 'item', 'ingred': 'boneless skinless chicken breast'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'orzo (optional)'},
#    {'amt': '1 (6.3',
#     'unit': 'ounce) box',
#     'ingred': 'garlic and herb rice mix'},
#    {'amt': '1 3/4', 'unit': 'cups', 'ingred': 'chicken broth'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'milk'},
#    {'amt': '1 (10.5', 'unit': 'ounce)', 'ingred': 'cream of chicken soup'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'oregano'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'garlic'},
#    {'amt': '12', 'unit': 'ounces', 'ingred': 'broccoli florets'},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'sharp Cheddar cheese'}],
#   'img': 'https://www.allrecipes.com/thmb/0y_CZ02WTkpqiV2zjOoRGqCoEaQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568422_Chicken-Broccoli-Rice-Skillet_TheDailyGourmet_4x3-87d917cc76304331a5c5a99fcd9366e9.jpg'},
#  {'name': 'Elote Pizza',
#   'steps': ['Preheat a gas grill with all burners on High for 10 to 15 minutes. Shape pizza dough and brush with olive oil.',
#    'Reduce the flame on half of the grill burners to Low, to create areas of direct and indirect heat.',
#    'Carefully place dough (olive oil side facing down) onto the grill over direct heat Close the cover. Let dough grill until the bottom is just barely cooked and shows char marks, 1 to 3 minutes.',
#    'Use tongs to move dough to the indirect heat; do not flip dough over! Cook 2 to 3 more minutes. Remove dough to a baking sheet.',
#    'Stir together 2 tablespoons sour cream, mayonnaise, and 1 1/2 teaspoons Tajin seasoning. Spread sour cream mixture over dough. Mix remaining Tajin, cotija, quesadilla cheese, corn, and red onions. Distribute topping mixture over dough.',
#    'Return pizza to grill. Grill until cheese is melted, about 3 minutes. Carefully remove pizza from the grill. Scatter cilantro and jalapeños over pizza, and drizzle with additional sour cream. Mix melted butter with remaining 1/2 teaspoon Tajin seasoning and brush crust with Tajin butter. Cut into wedges and serve.'],
#   'ingredients': [{'amt': '1', 'unit': 'pound', 'ingred': 'pizza dough'},
#    {'amt': '2', 'unit': 'teaspoons', 'ingred': 'olive oil, or as needed'},
#    {'amt': '2',
#     'unit': 'tablespoons',
#     'ingred': 'sour cream, plus more for drizzling'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'mayonnaise'},
#    {'amt': '2', 'unit': 'teaspoons', 'ingred': 'chili lime seasoning'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'cotija cheese'},
#    {'amt': '1/4', 'unit': 'cup', 'ingred': 'shredded quesadilla cheese'},
#    {'amt': '1/2', 'unit': 'cup', 'ingred': 'corn kernels'},
#    {'amt': '1/4', 'unit': 'item', 'ingred': 'red onion, very thinly sliced'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'chopped cilantro'},
#    {'amt': '1',
#     'unit': 'item',
#     'ingred': 'jalapeno, very thinly sliced, or more to taste'},
#    {'amt': '2', 'unit': 'teaspoons', 'ingred': 'butter'}],
#   'img': 'https://www.allrecipes.com/thmb/_CoEztIYgUuHw6CoUsJVGivHmBo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568835_Elote-Pizza_TheDailyGourmet_4x3-4f3478a9be554319804f91099b8a3c31.jpg'},
#  {'name': 'Charcoal-Grilled Ribeye Steak',
#   'steps': ['Season steak evenly, using 1/4 teaspoon seasoned salt and 1/8 teaspoon black pepper on each side. Set aside.',
#    'Light charcoal briquettes. Once they are red hot, place steak on the grates. Grill for 4 to 5 minutes. Turn steak over and grill an additional 2 to 3 minutes.',
#    'Tent steak with aluminum foil and let rest 4 to 5 minutes before serving.'],
#   'ingredients': [{'amt': '1 (12', 'unit': 'ounce)', 'ingred': 'ribeye steak'},
#    {'amt': '1/2', 'unit': 'teaspoon', 'ingred': 'seasoned salt, '},
#    {'amt': '1/4', 'unit': 'teaspoon', 'ingred': 'black pepper, or to taste'}],
#   'img': 'https://www.allrecipes.com/thmb/wlDedoifywf-dxApaISbgiaK1Ts=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7567649_Briquette-Grilled-Ribeye-Steak_Yoly_4x3-7c200441d55e4eeda1f90c7902a0e147.jpg'},
#  {'name': 'Good Old-Fashioned Pancakes',
#   'steps': ['Sift flour, baking powder, sugar, and salt together in a large bowl. Make a well in the center and add milk, melted butter, and egg; mix until smooth.',
#    'Heat a lightly oiled griddle or pan over medium-high heat. Pour or scoop the batter onto the griddle, using approximately 1/4 cup for each pancake; cook until bubbles form and the edges are dry, about 2 to 3 minutes. Flip and cook until browned on the other side. Repeat with remaining batter.',
#    'The salt amount has been reduced based on review feedback. The original recipe called for 1 teaspoon.'],
#   'ingredients': [{'amt': '1 ½',
#     'unit': 'cups',
#     'ingred': 'all-purpose flour'},
#    {'amt': '3 ½', 'unit': 'teaspoons', 'ingred': 'baking powder'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'white sugar'},
#    {'amt': '¼', 'unit': 'teaspoon', 'ingred': 'salt, or more to taste '},
#    {'amt': '1 ¼', 'unit': 'cups', 'ingred': 'milk'},
#    {'amt': '3', 'unit': 'tablespoons', 'ingred': 'butter, melted'},
#    {'amt': '1', 'unit': '', 'ingred': 'egg'}],
#   'img': 'https://www.allrecipes.com/thmb/WqWggh6NwG-r8PoeA3OfW908FUY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/21014-Good-old-Fashioned-Pancakes-mfs_001-1fa26bcdedc345f182537d95b6cf92d8.jpg'},
#  {'name': 'Super-Delicious Zuppa Toscana',
#   'steps': ['Cook Italian sausage and red pepper flakes in a Dutch oven over medium-high heat until crumbly, browned, and no longer pink, 10 to 15 minutes. Drain and set aside.',
#    'Cook bacon in the same Dutch oven over medium heat until crisp, about 10 minutes. Drain, leaving a few tablespoons of drippings with the bacon in the bottom of the Dutch oven. Stir in onions and garlic; cook until onions are soft and translucent, about 5 minutes.',
#    'Stir in chicken broth and bring to a boil over high heat. Add potatoes and simmer until fork tender, about 20 minutes. Reduce heat to medium; stir in cream, cooked sausage, and spinach. Cook and stir until spinach has wilted and sausage is warmed through; serve.',
#    'Please note the differences in serving size and the substitution of lacinato kale for spinach when using the magazine version of this recipe.'],
#   'ingredients': [{'amt': '1',
#     'unit': 'pound',
#     'ingred': 'bulk mild Italian sausage'},
#    {'amt': '1 ¼', 'unit': 'teaspoons', 'ingred': 'crushed red pepper flakes'},
#    {'amt': '4', 'unit': 'slices', 'ingred': 'bacon, cut into 1/2 inch pieces'},
#    {'amt': '1', 'unit': 'large', 'ingred': 'onion, diced'},
#    {'amt': '1', 'unit': 'tablespoon', 'ingred': 'minced garlic'},
#    {'amt': '5', 'unit': '(13.75 ounce) cans', 'ingred': 'chicken broth'},
#    {'amt': '6', 'unit': 'medium', 'ingred': 'potatoes, thinly sliced '},
#    {'amt': '1', 'unit': 'cup', 'ingred': 'heavy cream'},
#    {'amt': '¼',
#     'unit': 'bunch',
#     'ingred': 'fresh spinach, tough stems removed'}],
#   'img': 'https://www.allrecipes.com/thmb/b4ortB6V9Av5yQm9A0xjLCwFpm4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Super-Delicious-Zuppa-Toscana-e0ecd2a124674b84b63570320d20ca9b.jpeg'},
#  {'name': "World's Best Lasagna",
#   'steps': ['Gather all your ingredients.',
#    'Dotdash Meredith Food Studios',
#    'Cook sausage, ground beef, onion, and garlic in a Dutch oven over medium heat until well browned.',
#    'Dotdash Meredith Food Studios',
#    'Stir in crushed tomatoes, tomato sauce, tomato paste, and water. Season with sugar, 2 tablespoons parsley, basil, 1 teaspoon salt, Italian seasoning, fennel seeds, and pepper. Simmer, covered, for about 1 1/2 hours, stirring occasionally.',
#    'Dotdash Meredith Food Studios',
#    'Bring a large pot of lightly salted water to a boil. Cook lasagna noodles in boiling water for 8 to 10 minutes. Drain noodles, and rinse with cold water.',
#    'Dotdash Meredith Food Studios',
#    'In a mixing bowl, combine ricotta cheese with egg, remaining 2 tablespoons parsley, and 1/2 teaspoon salt.',
#    'Dotdash Meredith Food Studios',
#    'Preheat the oven to 375 degrees F (190 degrees C).',
#    'To assemble, spread 1 1/2 cups of meat sauce in the bottom of a 9x13-inch baking dish. Arrange 6 noodles lengthwise over meat sauce. Spread with 1/2 of the ricotta cheese mixture. Top with 1/3 of the mozzarella cheese slices. Spoon 1 1/2 cups meat sauce over mozzarella, and sprinkle with 1/4 cup Parmesan cheese.',
#    'Dotdash Meredith Food Studios',
#    'Repeat layers, and top with remaining mozzarella and Parmesan cheese. Cover with foil: to prevent sticking, either spray foil with cooking spray or make sure the foil does not touch the cheese.',
#    'Dotdash Meredith Food Studios',
#    'Bake in the preheated oven for 25 minutes. Remove the foil and bake for an additional 25 minutes.',
#    'Dotdash Meredith Food Studios',
#    'Rest lasagna for 15 minutes before serving.',
#    'Dotdash Meredith Food Studios'],
#   'ingredients': [{'amt': '1',
#     'unit': 'pound',
#     'ingred': 'sweet Italian sausage'},
#    {'amt': '¾', 'unit': 'pound', 'ingred': 'lean ground beef'},
#    {'amt': '½', 'unit': 'cup', 'ingred': 'minced onion'},
#    {'amt': '2', 'unit': 'cloves', 'ingred': 'garlic, crushed'},
#    {'amt': '1', 'unit': '(28 ounce) can', 'ingred': 'crushed tomatoes'},
#    {'amt': '2', 'unit': '(6.5 ounce) cans', 'ingred': 'canned tomato sauce'},
#    {'amt': '2', 'unit': '(6 ounce) cans', 'ingred': 'tomato paste'},
#    {'amt': '½', 'unit': 'cup', 'ingred': 'water'},
#    {'amt': '2', 'unit': 'tablespoons', 'ingred': 'white sugar'},
#    {'amt': '4',
#     'unit': 'tablespoons',
#     'ingred': 'chopped fresh parsley, divided'},
#    {'amt': '1 ½', 'unit': 'teaspoons', 'ingred': 'dried basil leaves'},
#    {'amt': '1 ½', 'unit': 'teaspoons', 'ingred': 'salt, divided, or to taste'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'Italian seasoning'},
#    {'amt': '½', 'unit': 'teaspoon', 'ingred': 'fennel seeds'},
#    {'amt': '¼', 'unit': 'teaspoon', 'ingred': 'ground black pepper'},
#    {'amt': '12', 'unit': '', 'ingred': 'lasagna noodles'},
#    {'amt': '16', 'unit': 'ounces', 'ingred': 'ricotta cheese'},
#    {'amt': '1', 'unit': '', 'ingred': 'egg'},
#    {'amt': '¾', 'unit': 'pound', 'ingred': 'mozzarella cheese, sliced'},
#    {'amt': '¾', 'unit': 'cup', 'ingred': 'grated Parmesan cheese'}],
#   'img': 'https://www.allrecipes.com/thmb/vmL8iEleAiQJzU3s6YfEMVcvhwc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/23600-worlds-best-lasagna-armag-4x3-1-b24f9ad518d74090bf197828492c64a6.jpg'},
#  {'name': 'Banana Banana Bread',
#   'steps': ['Preheat the oven to 350 degrees F (175 degrees C). Lightly grease a 9x5-inch loaf pan.',
#    'Combine flour, baking soda, and salt in a large bowl. Beat brown sugar and butter with an electric mixer in a separate large bowl until smooth. Stir in eggs and mashed bananas until well blended. Stir banana mixture into flour mixture until just combined. Pour batter into the prepared loaf pan.',
#    'Bake in the preheated oven until a toothpick inserted into the center comes out clean, about 60 minutes. Let bread cool in pan for 10 minutes, then turn out onto a wire rack to cool completely.'],
#   'ingredients': [{'amt': '2', 'unit': 'cups', 'ingred': 'all-purpose flour'},
#    {'amt': '1', 'unit': 'teaspoon', 'ingred': 'baking soda'},
#    {'amt': '¼', 'unit': 'teaspoon', 'ingred': 'salt'},
#    {'amt': '¾', 'unit': 'cup', 'ingred': 'brown sugar'},
#    {'amt': '½', 'unit': 'cup', 'ingred': 'butter'},
#    {'amt': '2', 'unit': '', 'ingred': 'eggs, beaten'},
#    {'amt': '2 ⅓', 'unit': 'cups', 'ingred': 'mashed overripe bananas'}],
#   'img': 'https://www.allrecipes.com/thmb/7Vn00l3j_zQJtXgYFCu4sU-xOOs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/20144-banana-banana-bread-mfs-57-0bb49d050a6941c4b3715e57b8e6badd.jpg'}]

# %% [markdown]
# ### Reformat For Prisma Schema Format

# %%
def map_to_db(obj):
    new_obj = {}
    new_obj["title"] = obj["name"]
    new_obj["ingredients"] = json.dumps(obj["ingredients"])
    new_obj["instructions"] = json.dumps(obj["steps"])
    if "Prep Time:" in obj:
        new_obj["prep_time"] = obj["Prep Time:"]
    if "Cook Time:" in obj:
        new_obj["cook_time"] = obj["Cook Time:"]
    new_obj["img"] = obj["img"]

    filename = new_obj["title"]
    filename = filename.lower().replace(" ","-")
    img_loc = f"/home/james/hackathon-mvp/prisma/data/avatars/{filename}.png"
    new_obj["img_name"] = filename+".png"
    new_obj["img_loc"] = img_loc
    new_obj["url"] = obj["img"]

    return new_obj

# %%
db_objs = [map_to_db(obj) for obj in recipe_objs]

# %%
with open("../../../../hackathon-mvp/prisma/data/recipes_seed.json","w") as f:
    json.dump({"recipes":db_objs},f)

# %%
db_objs
# Out:
# [{'title': 'These Grilled Ribeye Steaks Are Juicy and Flavorful',
#   'ingredients': '[{"amt": "1/2", "unit": "lime", "ingred": ", juiced"}, {"amt": "2", "unit": "teaspoons", "ingred": "seasoning"}, {"amt": "1", "unit": "tablespoon", "ingred": "olive oil"}, {"amt": "1 (8", "unit": "ounce)", "ingred": "ribeye steak"}]',
#   'instructions': '["Combine lime juice, carne asada seasoning, and oil in a resealable plastic bag. Add ribeye steak, reseal the bag, and marinate in the refrigerator for 30 to 45 minutes.", "Drain marinade and allow steak to come to room temperature, about 30 minutes. Blot any excess moisture off the steak.", "Preheat the grill to 500 degrees F (260 degrees C), and lightly oil the grate.", "Place steak on the grill over direct heat. For rare: cook steaks until browned on the outside and red in the center, about 3 minutes per side. An instant-read thermometer inserted into the center should read 125 degrees F (52 degrees C).", "Remove steak from grill; rest 5 minutes before serving.", "Additional internal temperatures for cooking steak: Rare: 125-130 degrees F (52-54 degrees C); Medium rare: 130-140 degrees F (54-60 degrees C); Medium:\\u00a0 140-150 degrees F (54-65 degrees C); Medium well: 150-160 degrees F (65-70 degrees C);\\u00a0 Well done: 160 degrees F (70 degrees C)."]',
#   'prep_time': '5 mins',
#   'cook_time': '6 mins',
#   'img': 'https://www.allrecipes.com/thmb/2tQKTk9vGg_v9HrdXYVfDd0CH7E=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7552430_Grilled-Ribeye-Steaks_TheDailyGourmet_4x3-62178245a22845b2a4478e815cd8969f.jpg',
#   'img_name': 'these-grilled-ribeye-steaks-are-juicy-and-flavorful.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/these-grilled-ribeye-steaks-are-juicy-and-flavorful.png',
#   'url': 'https://www.allrecipes.com/thmb/2tQKTk9vGg_v9HrdXYVfDd0CH7E=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7552430_Grilled-Ribeye-Steaks_TheDailyGourmet_4x3-62178245a22845b2a4478e815cd8969f.jpg'},
#  {'title': 'Skillet Chicken Breasts with Cherry Tomatoes',
#   'ingredients': '[{"amt": "1 1/2", "unit": "pounds", "ingred": "boneless, skinless chicken breasts"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "smoked paprika"}, {"amt": 1, "unit": "item", "ingred": "salt and freshly ground black pepper to taste"}, {"amt": "2 ", "unit": "tablespoons", "ingred": "herb-infused olive oil"}, {"amt": "1", "unit": "tablespoon", "ingred": "unsalted butter"}, {"amt": "1/2", "unit": "item", "ingred": "red onion, thinly sliced"}, {"amt": "3", "unit": "cloves", "ingred": "garlic, minced"}, {"amt": "1/2", "unit": "cup", "ingred": "white wine"}, {"amt": "3", "unit": "cups", "ingred": "cherry tomatoes, halved"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "red pepper flakes, or to taste"}, {"amt": "1/2", "unit": "cup", "ingred": "cream, or to taste"}, {"amt": "1", "unit": "tablespoon", "ingred": "fresh basil, plus more for garnish (optional)"}, {"amt": "1/4", "unit": "cup", "ingred": "grated Parmesan cheese"}]',
#   'instructions': '["Pat chicken breasts dry with paper towels, and season both sides with smoked paprika, salt, and pepper.", "In a large, non-stick skillet, heat herb-infused olive oil and butter over medium heat. When the butter is foamy, add chicken breasts and cook until browned on both sides, 4 to 5 minutes per side. Remove chicken to a plate and keep warm.", "To the same skillet, add red onion slices and cook until tender, 3 to 4 minutes. If the skillet seems dry, add a bit more olive oil. Stir in garlic; cook until fragrant, about 30 seconds.", "Add white wine; cook and stir for about 1 minute, then add cherry tomatoes and red pepper flakes.", "Stir in cream and cook until sauce is bubble. Return chicken and any accumulated juices to the skillet. Cover, reduce heat to low, and cook until chicken is no longer pink in the center and juices run clear, about 10 minutes. An instant-read thermometer inserted near the center should read at least 165 degrees F (74 degrees C).", "Sprinkle minced fresh basil and grated Parmesan over all. Garnish with additional basil, if desired."]',
#   'prep_time': '10 mins',
#   'cook_time': '25 mins',
#   'img': 'https://www.allrecipes.com/thmb/zGTj_99OYuEcelC0USKg7gUYDVQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7553999_Skillet-Chicken-Breasts-with-Cherry-Tomaotes_Bibi_4x3-4a90ae5c8bfd459d87be2cc5d2ab17ac.jpg',
#   'img_name': 'skillet-chicken-breasts-with-cherry-tomatoes.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/skillet-chicken-breasts-with-cherry-tomatoes.png',
#   'url': 'https://www.allrecipes.com/thmb/zGTj_99OYuEcelC0USKg7gUYDVQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7553999_Skillet-Chicken-Breasts-with-Cherry-Tomaotes_Bibi_4x3-4a90ae5c8bfd459d87be2cc5d2ab17ac.jpg'},
#  {'title': 'These Dill Ranch Chicken Wraps Are Easy to Make With Rotisserie Chicken',
#   'ingredients': '[{"amt": "2", "unit": "tablespoons", "ingred": "mayonnaise"}, {"amt": "2", "unit": "tablespoons", "ingred": "ranch dressing"}, {"amt": "1", "unit": "tablespoon", "ingred": "pickle juice"}, {"amt": "1", "unit": "teaspoon", "ingred": "dried dill"}, {"amt": "2", "unit": "10 inch)", "ingred": "flour tortillas"}, {"amt": "4", "unit": "slices", "ingred": "sharp Cheddar cheese"}, {"amt": "1", "unit": "cup", "ingred": "shredded lettuce"}, {"amt": "4", "unit": "slices", "ingred": " dill pickle sandwich "}, {"amt": "1", "unit": "cup", "ingred": "cooked rotisserie chicken"}]',
#   'instructions': '["Stir mayonnaise, ranch dressing, dill pickle juice, and dill together in a small bowl.", "Warm tortillas in the microwave on High until warm and pliable, about 30 seconds.", "Spread half of the mayonnaise mixture down the center of each tortilla. In each tortilla, place 2 slices of sharp Cheddar cheese, 1/2 cup lettuce, 2 kosher pickle slices, and 1/2 cup of cooked chicken.", "Fold opposing edges of tortilla to overlap the filling. Roll 1 of the opposing edges around the filling into a wrap."]',
#   'prep_time': '10 mins',
#   'cook_time': '1 mins',
#   'img': 'https://www.allrecipes.com/thmb/0pdpT_zle50ltPpLtgf1Do-wJ70=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7552440_Quick-Dill-Ranch-Chicken-Wrap_Chef-Mo_4x3-e9e235101da346a98925edd9e2cab7cc.jpg',
#   'img_name': 'these-dill-ranch-chicken-wraps-are-easy-to-make-with-rotisserie-chicken.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/these-dill-ranch-chicken-wraps-are-easy-to-make-with-rotisserie-chicken.png',
#   'url': 'https://www.allrecipes.com/thmb/0pdpT_zle50ltPpLtgf1Do-wJ70=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7552440_Quick-Dill-Ranch-Chicken-Wrap_Chef-Mo_4x3-e9e235101da346a98925edd9e2cab7cc.jpg'},
#  {'title': 'The Secret to These Crispy Zucchini Fries? Your Air Fryer',
#   'ingredients': '[{"amt": "2 ", "unit": "(8 ounce)", "ingred": "zucchini"}, {"amt": 1, "unit": "item", "ingred": "salt as needed"}, {"amt": "1", "unit": "large", "ingred": "egg, beaten"}, {"amt": "1/2", "unit": "cup", "ingred": "seasoned bread crumbs"}, {"amt": "1/4", "unit": "cup", "ingred": "grated Parmesan cheese"}, {"amt": 1, "unit": "item", "ingred": "nonstick cooking spray"}, {"amt": "1/2", "unit": "cup", "ingred": "marinara sauce for dipping (optional)"}]',
#   'instructions': '["Place zucchini fries in a colander. Sprinkle with salt and let sit for 5 minutes. Blot dry with paper towels.", "Place beaten egg in a shallow bowl. Stir bread crumbs and Parmesan cheese together in a separate shallow bowl.", "Dip each fry in beaten egg, then dip in breadcrumb mixture to coat. Place fries on a plate.", "Preheat the air fryer to 400 degrees F (200 degrees C) for 2 minutes.", "Place fries in the basket of the air fryer in a single layer, working in batches if necessary. Lightly spray the tops with nonstick cooking spray.", "Cook until browned to your taste, about 8 minutes. Transfer to a plate and repeat with remaining fries."]',
#   'prep_time': '12 mins',
#   'cook_time': '8 mins',
#   'img': 'https://www.allrecipes.com/thmb/h7JgF5oJLWi0e_o5rp6IPU6Baro=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7554904_Air-Fryer-Zucchini-Fries_SoupLovingNicole_4x3-bb0c057fd713474cb6cb3b620769610d.jpg',
#   'img_name': 'the-secret-to-these-crispy-zucchini-fries?-your-air-fryer.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/the-secret-to-these-crispy-zucchini-fries?-your-air-fryer.png',
#   'url': 'https://www.allrecipes.com/thmb/h7JgF5oJLWi0e_o5rp6IPU6Baro=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7554904_Air-Fryer-Zucchini-Fries_SoupLovingNicole_4x3-bb0c057fd713474cb6cb3b620769610d.jpg'},
#  {'title': 'Copycat Wendy’s Ranch Sauce',
#   'ingredients': '[{"amt": "1/2", "unit": "cup", "ingred": "mayonnaise"}, {"amt": "1/4", "unit": "cup", "ingred": "whole buttermilk"}, {"amt": "1/4", "unit": "cup", "ingred": "sour cream"}, {"amt": "3/4", "unit": "teaspoon", "ingred": "white vinegar"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "white sugar"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "onion powder"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "dried dill"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "dried parsley"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "ground black pepper"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "kosher salt"}, {"amt": "1/8", "unit": "teaspoon", "ingred": "garlic powder"}]',
#   'instructions': '["Whisk together mayonnaise, buttermilk, sour cream, vinegar, sugar, onion powder, dill,\\u00a0parsley, black pepper, salt, and garlic powder in a bowl until well blended. Chill until ready to serve. Store in an airtight container in the refrigerator for up to 3 days."]',
#   'prep_time': '5 mins',
#   'img': 'https://www.allrecipes.com/thmb/mUGNIIZ8Gx8O1rCgUTtUOvuC-LY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556719CopycatWendysRanchSauce2x1-82042801e6074086b88ff93861c3e22c.jpg',
#   'img_name': 'copycat-wendy’s-ranch-sauce.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/copycat-wendy’s-ranch-sauce.png',
#   'url': 'https://www.allrecipes.com/thmb/mUGNIIZ8Gx8O1rCgUTtUOvuC-LY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556719CopycatWendysRanchSauce2x1-82042801e6074086b88ff93861c3e22c.jpg'},
#  {'title': 'Copycat Chick-Fil-A Honey Mustard',
#   'ingredients': '[{"amt": "1/2", "unit": "cup", "ingred": "yellow mustard"}, {"amt": "1/3", "unit": "cup", "ingred": "honey"}, {"amt": "2", "unit": "tablespoons", "ingred": "corn syrup"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "molasses"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "tamarind"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "kosher salt"}]',
#   'instructions': '["Whisk together mustard, honey, corn syrup, molasses, tamarind paste, and salt\\u00a0 in a bowl until well blended. Chill until ready to serve.\\u00a0 Store in an airtight container in the refrigerator up to 2 weeks."]',
#   'prep_time': '5 mins',
#   'cook_time': '0 mins',
#   'img': 'https://www.allrecipes.com/thmb/loCUASLKESxqCrFrjRzC_0kMIps=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556788CopycatChikFilAHoneyMustard2x1-d4f45edef75947e7857aa199ff82bbc9.jpg',
#   'img_name': 'copycat-chick-fil-a-honey-mustard.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/copycat-chick-fil-a-honey-mustard.png',
#   'url': 'https://www.allrecipes.com/thmb/loCUASLKESxqCrFrjRzC_0kMIps=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556788CopycatChikFilAHoneyMustard2x1-d4f45edef75947e7857aa199ff82bbc9.jpg'},
#  {'title': 'Chipotle-Citrus Marinated Chicken Tacos',
#   'ingredients': '[{"amt": "2", "unit": "item", "ingred": "limes, juiced"}, {"amt": "1", "unit": "item", "ingred": "orange, juiced"}, {"amt": "1/4", "unit": "cup", "ingred": "olive oil"}, {"amt": "1", "unit": "item", "ingred": "chipotle pepper in adobo"}, {"amt": "3", "unit": "cloves", "ingred": "garlic"}, {"amt": "2", "unit": "teaspoons", "ingred": "ground cumin"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "ground coriander"}, {"amt": "1", "unit": "teaspoon", "ingred": "salt"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "ground black pepper"}, {"amt": "1", "unit": "pound", "ingred": "boneless skinless chicken breasts"}, {"amt": "24 ", "unit": "item", "ingred": "corn tortilla"}, {"amt": "1", "unit": "small", "ingred": "onion, diced"}, {"amt": "1/4", "unit": "cup", "ingred": "chopped cilantro"}]',
#   'instructions': '["Combine lime juice, orange juice, olive oil, chipotle pepper, garlic, cumin, coriander, salt, and black pepper in a blender. Blend on high until smooth.", "Pour marinade mixture into a resealable plastic bag. Add chicken breasts to the bag; marinate in the refrigerator for 3 hours.", "Preheat a grill to 375 degrees F (190 degrees C).", "Place marinated chicken breasts on the grill; close the lid. Discard the marinade. Grill, turning once, until chicken is no longer pink in the center and the juices run clear, 6 to 8 minutes per side. An instant-read thermometer inserted into the center should read at least 165 degrees F (74 degrees C).", "Remove chicken from grill. Let stand for 5 minutes; slice into strips.", "Heat tortillas over a griddle on medium heat until tortillas are soft and pliable. Stack tortillas in pairs; divide chicken, onion, and cilantro onto each pair of tortillas."]',
#   'prep_time': '10 mins',
#   'cook_time': '12 mins',
#   'img': 'https://www.allrecipes.com/thmb/HglpDgXpXi9O8LhegA2YBNqX4-A=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7553405_Chicken-Street-Tacos_TheDailyGourmet_4x3-96f0d6026e5945b9a942a677a1e284e0.jpg',
#   'img_name': 'chipotle-citrus-marinated-chicken-tacos.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/chipotle-citrus-marinated-chicken-tacos.png',
#   'url': 'https://www.allrecipes.com/thmb/HglpDgXpXi9O8LhegA2YBNqX4-A=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7553405_Chicken-Street-Tacos_TheDailyGourmet_4x3-96f0d6026e5945b9a942a677a1e284e0.jpg'},
#  {'title': 'Pitmaster Potato Salad',
#   'ingredients': '[{"amt": "2 1/4", "unit": "pounds", "ingred": "ukon gold potatoes"}]',
#   'instructions': '["Nest potatoes directly in hot coals in a charcoal grill. Surround potatoes with coals for even roasting. Roast until charred, 6 to 7 minutes. Turn potatoes and continue to roast until deeply charred outside and tender inside, 6 to 7 minutes more.", "Remove potatoes to a bowl, cover with foil, and let cool to room temperature, about 30 minutes. Refrigerate until chilled, at least 1 hour, or preferably overnight.", "Combine Dijon mustard, cider vinegar, rice wine vinegar, vegetable oil, salt, black pepper, and cayenne pepper in a bowl for the dressing and whisk thoroughly.", "Scrape, peel, or cut off any fully charred surface of potato, leaving some dark brown bits for a deeper flavor. Cut potatoes into 1/4-inch to 1/2-inch size pieces.", "Add potatoes to dressing, along with red onion, celery, dill pickles, and red peppers. Toss well with a spatula until evenly mixed. Cover; refrigerate for at least 3 hours before serving, or up to overnight.", "Add chives, mix well, and season to taste with salt and pepper before serving.", "Chef John"]',
#   'prep_time': '30 mins',
#   'cook_time': '15 mins',
#   'img': 'https://www.allrecipes.com/thmb/HvttjQVnuPN_8N8qSMH_-7Cz2P0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/IMG_1224-4x3-5ad9a674196a41d28b5bbcdd7d14eaca.JPG',
#   'img_name': 'pitmaster-potato-salad.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/pitmaster-potato-salad.png',
#   'url': 'https://www.allrecipes.com/thmb/HvttjQVnuPN_8N8qSMH_-7Cz2P0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/IMG_1224-4x3-5ad9a674196a41d28b5bbcdd7d14eaca.JPG'},
#  {'title': 'Copycat Waffle House Hash Browns',
#   'ingredients': '[{"amt": "1", "unit": "tablespoon", "ingred": "butter"}, {"amt": "1", "unit": "tablespoon", "ingred": "canola oil"}, {"amt": "1 1/2", "unit": "cup", "ingred": "hash browns, partially thawed"}, {"amt": "2", "unit": "tablespoons", "ingred": "onion"}, {"amt": "1/4", "unit": "cup", "ingred": "ham"}, {"amt": "1", "unit": "slice", "ingred": "merican cheese"}]',
#   'instructions': '["Whisk together butter and oil in a small bowl. Reserve 2 teaspoons of butter mixture for later. Heat remaining butter mixture on 1 side of a large nonstick skillet over medium-high heat. Place hash browns on buttered side of skillet in a round shape about 5 inches wide. Cook, undisturbed, until browned and crisp around edges, about 5 minutes.", "Flip hash browns, and cook, undisturbed, until other side is browned and crispy, 4 to 5 more minutes. Meanwhile, add reserved butter mixture to other side of skillet; add onion. Cook, stirring often, for 2 minutes. Add ham to onion, and cook 2 minutes. Add onions and ham to top of cooked hash browns. Top with cheese slice; turn off heat. Let stand until cheese is melted; serve immediately.", "Meredith Food Studios"]',
#   'prep_time': '5 mins',
#   'cook_time': '10 mins',
#   'img': 'https://www.allrecipes.com/thmb/a4jNrKrlv9tBAQyZoaV-o6KWdlM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556710_Copycat-Waffle-House-Hash-Browns_Meredith-Food-Studios_4x3-35c2581092a04b2d9f81b03b2ff865d8.jpg',
#   'img_name': 'copycat-waffle-house-hash-browns.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/copycat-waffle-house-hash-browns.png',
#   'url': 'https://www.allrecipes.com/thmb/a4jNrKrlv9tBAQyZoaV-o6KWdlM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556710_Copycat-Waffle-House-Hash-Browns_Meredith-Food-Studios_4x3-35c2581092a04b2d9f81b03b2ff865d8.jpg'},
#  {'title': 'Mint Oreo Icebox Cake',
#   'ingredients': '[{"amt": "2 1/2", "unit": "cups", "ingred": "heavy cream"}, {"amt": "1", "unit": "cup", "ingred": "confectioners sugar"}, {"amt": "2", "unit": "tablespoons", "ingred": "fresh mint"}, {"amt": "7", "unit": "cookie", "ingred": "OREO"}, {"amt": "18", "unit": "cookie", "ingred": "OREO Thin"}, {"amt": "1/4", "unit": "cup", "ingred": "chocolate syrup"}]',
#   'instructions': '["Beat heavy cream in the bowl of a stand mixer fitted with whisk attachment on medium-high speed for 2 minutes. Add powdered sugar, and beat until stiff peaks form. Place 3/4 cup whipped cream, covered, in the refrigerator to use later for topping. Stir chopped mint into remaining whipped cream.", "Line an 8 1/2 x 4 1/2-inch loaf pan with plastic wrap. Remove tops of the 7 Oreo Cookies, and discard tops. Shingle cookies, green filling side down, along the center of the prepared pan. Spread half of the mint whipped cream in an even layer over the cookies.", "Roughly chop 12 of the Oreo Thins, and sprinkle evenly over whipped cream. Spread remaining mint whipped cream evenly over chopped cookies.", "Cut remaining 6 Oreo Thins in half; place cookie halves on top of mint whipped cream, aligning straight cut edges of cookies with edges of the pan. Fold plastic wrap over cake, and freeze for at least 8 hours.", "To serve, peel plastic wrap from top of cake; invert cake onto a serving plate, remove and discard plastic wrap. Drizzle with chocolate syrup, and top with reserved whipped cream. Garnish with fresh mint, and more cookies if desired.", "Dotdash Meredith Food Studios"]',
#   'prep_time': '15 mins',
#   'img': 'https://www.allrecipes.com/thmb/nGoXpC4l1NeBgHe3kHthVGcfx7c=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7550324_Mint-Oreo-Icebox-Cake_Dotdash-Meredith-Food-Studios_4x3-5665e82e6b5a46719926cbfd4b536aa2.jpg',
#   'img_name': 'mint-oreo-icebox-cake.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/mint-oreo-icebox-cake.png',
#   'url': 'https://www.allrecipes.com/thmb/nGoXpC4l1NeBgHe3kHthVGcfx7c=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7550324_Mint-Oreo-Icebox-Cake_Dotdash-Meredith-Food-Studios_4x3-5665e82e6b5a46719926cbfd4b536aa2.jpg'},
#  {'title': 'Copycat Panda Express Chow Mein',
#   'ingredients': '[{"amt": "3", "unit": "tablespoons", "ingred": "canola oil"}, {"amt": "1", "unit": "tablespoon", "ingred": "sesame oil"}, {"amt": "1/2", "unit": "item", "ingred": "white onion, finely chopped"}, {"amt": "2", "unit": "stalks", "ingred": "celery, sliced"}, {"amt": "1", "unit": "tablespoon", "ingred": "fresh ginger"}, {"amt": "3", "unit": "cups", "ingred": "coleslaw mix"}, {"amt": "5", "unit": "ounces", "ingred": "bean sprouts"}, {"amt": "7.1 ", "unit": "ounce", "ingred": "stir-fry noodles"}, {"amt": "1/4", "unit": "cup", "ingred": "tamari"}, {"amt": "2", "unit": "tablespoons", "ingred": "mirin"}]',
#   'instructions': '["Heat canola oil and sesame oil in a wok over high heat. Add onion, celery, and ginger; cook, stirring often, 1 minute. Add coleslaw mix and sprouts; cook, stirring constantly, 2 minutes. Add noodles, and cook, stirring constantly, 1 minute. Add tamari and mirin; cook, stirring occasionally, 2 minutes.", "Dotdash Meredith Video Studios"]',
#   'prep_time': '5 mins',
#   'cook_time': '6 mins',
#   'img': 'https://www.allrecipes.com/thmb/trt4060Dq1A_yKdi7bk1GH5woyQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556785_Copycat-Panda-Express-Chow-Mein_4x3-b38b7bd9af114fe1ac1c8cccc1ccf4a2.jpg',
#   'img_name': 'copycat-panda-express-chow-mein.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/copycat-panda-express-chow-mein.png',
#   'url': 'https://www.allrecipes.com/thmb/trt4060Dq1A_yKdi7bk1GH5woyQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7556785_Copycat-Panda-Express-Chow-Mein_4x3-b38b7bd9af114fe1ac1c8cccc1ccf4a2.jpg'},
#  {'title': 'Bacon, Egg, and Cheese Sandwich',
#   'ingredients': '[{"amt": "2", "unit": "slices", "ingred": "bacon"}, {"amt": "4", "unit": "teaspoons", "ingred": "butter, divided"}, {"amt": "3", "unit": "large", "ingred": "eggs"}, {"amt": "1", "unit": "pinch", "ingred": "black pepper"}, {"amt": "1", "unit": "pinch", "ingred": "salt"}, {"amt": "1/4", "unit": "cup", "ingred": "shredded Cheddar cheese"}, {"amt": "4", "unit": "slices", "ingred": "bread"}]',
#   'instructions': '["Place bacon in a nonstick skillet and cook over medium-high heat, turning occasionally, until evenly browned, about 7 minutes. Drain bacon slices on paper towels. Remove bacon to a drip line tray. Drain off bacon grease for another use. Wash out the skillet.", "Whisk eggs with salt and pepper in a small bowl until frothy.", "Melt 2 teaspoons butter in the nonstick skillet over medium heat. Pour in beaten eggs; let cook for 30 seconds. Lift the edges of the omelet so that the uncooked egg runs under the cooked edges and comes into contact with the hot skillet. Shake and tilt the skillet to move the uncooked egg. Repeat until the top is set, about 3 minutes; reduce heat to low.", "Meanwhile, chop bacon roughly; sprinkle over omelet. Sprinkle with cheese; allow cheese to melt, 1 to 2 minutes.", "Meanwhile, butter 2 slices of bread with 1/2 teaspoon butter each. Lay bread, buttered side up, side-by-side over omelet, leaving about 1 inch between slices. The melted cheese will help the bread adhere.", "Run a spatula around the entire omelet to loosen from the skillet. Carefully turn the omelet over so buttered side of bread is in contact with the skillet. Cook until bread is toasted and golden, about 2 minutes.", "Using the spatula, fold in edges of omelet to align with sides of the bread. Cut omelet along center with the spatula to form 2 sandwiches. Butter 2 remaining bread slices with remaining butter; place butter side up on each sandwich. Turn sandwiches; cook until golden, about 2 minutes more. Serve and enjoy immediately!"]',
#   'prep_time': '5 mins',
#   'cook_time': '15 mins',
#   'img': 'https://www.allrecipes.com/thmb/GHGcqSRe4ty-qTwYj47DAj31Lf0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7557506_Bacon-Egg-and-Cheese-Sandwich_Thedailygourmet_4x3-96273724754c4b59985d2e5b75355f23.jpg',
#   'img_name': 'bacon,-egg,-and-cheese-sandwich.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/bacon,-egg,-and-cheese-sandwich.png',
#   'url': 'https://www.allrecipes.com/thmb/GHGcqSRe4ty-qTwYj47DAj31Lf0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7557506_Bacon-Egg-and-Cheese-Sandwich_Thedailygourmet_4x3-96273724754c4b59985d2e5b75355f23.jpg'},
#  {'title': 'Puff Pastry Cherry Crostata',
#   'ingredients': '[{"amt": "1/2 (17.3", "unit": "ounce) package", "ingred": "puff pastry sheets, thawed"}, {"amt": "1", "unit": "pound", "ingred": "cherries, pitted and halved"}, {"amt": "2", "unit": "tablespoons", "ingred": "brown sugar"}, {"amt": "1", "unit": "tablespoon", "ingred": "cornstarch"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "cinnamon"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "almond extract"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "salt"}, {"amt": "1", "unit": "large", "ingred": "egg, beaten"}, {"amt": "1", "unit": "tablespoon", "ingred": "water"}, {"amt": "1", "unit": "tablespoon", "ingred": "turbinado sugar, or to taste"}, {"amt": "1", "unit": "tablespoon", "ingred": "orange marmalade (optional)"}]',
#   'instructions': '["Preheat the oven to 400 degrees F (200 degrees C). Line a baking sheet with parchment paper.", "On a lightly floured surface, roll a well-chilled puff pastry sheet into an approximate 11 to 12-inch round. Trim edges into a circle shape, and transfer to the lined baking sheet.", "Stir cherries, brown sugar, cornstarch, cinnamon, almond extract, and salt together in a bowl until cherries are well coated. Spoon cherry mixture into the center of the pastry, leaving a 2-inch border. Lift up edges of the crust, and fold around, overlapping the cherry mixture.", "Whisk egg and water into an egg wash, brush edges of the pastry, and sprinkle with turbinado.", "Bake in the preheated oven until cherries are tender and crust is golden brown, 23 to 30 minutes. Warm marmalade in the microwave until melted, 15 to 20 seconds, and drizzle over the cherries to glaze.", "Allow to cool for about 15 minutes before cutting into wedges to serve."]',
#   'prep_time': '20 mins',
#   'cook_time': '25 mins',
#   'img': 'https://www.allrecipes.com/thmb/xcaCmzheejvXWZNUkUpalonmQAs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7558586_Puff-Pastry-Cherry-Crostata_lutzflcat_4x3-51270368fa904f199d4021ed270a98b6.jpg',
#   'img_name': 'puff-pastry-cherry-crostata.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/puff-pastry-cherry-crostata.png',
#   'url': 'https://www.allrecipes.com/thmb/xcaCmzheejvXWZNUkUpalonmQAs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7558586_Puff-Pastry-Cherry-Crostata_lutzflcat_4x3-51270368fa904f199d4021ed270a98b6.jpg'},
#  {'title': 'Barbecued Butter Chicken',
#   'ingredients': '[{"amt": "1/2", "unit": "cup", "ingred": "water"}, {"amt": "1/2", "unit": "cup", "ingred": "apple cider vinegar"}, {"amt": "2", "unit": "tablespoons", "ingred": "orcestershire sauce"}, {"amt": "2", "unit": "teaspoons", "ingred": "kosher salt, or about 1 teaspoon per pound of chicken"}, {"amt": "2", "unit": "teaspoons", "ingred": "ground black pepper"}, {"amt": "1", "unit": "teaspoon", "ingred": "paprika"}, {"amt": "1", "unit": "teaspoon", "ingred": "garlic powder"}, {"amt": "1", "unit": "teaspoon", "ingred": "poultry seasoning"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "onion powder"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "cayenne pepper"}, {"amt": "1/4", "unit": "cup", "ingred": "unsalted butter"}, {"amt": "1", "unit": "item", "ingred": "whole chicken, halved or quartered"}]',
#   'instructions': '["Add water, vinegar, Worcestershire sauce, salt, pepper, paprika, garlic powder, poultry seasoning, onion powder, cayenne pepper, and butter to a saucepan. Place over medium heat until butter is halfway melted; turn off heat, and whisk until butter disappears. Let marinade cool to room temperature, about 10 minutes.", "Cut chicken into halves or quarters and place in a resealable plastic bag. Whisk cooled marinade thoroughly and pour into the bag. Squeeze out air and seal tightly.", "Marinate in the refrigerator for at least 4 hours and up to overnight, turning the bag occasionally. (At this point, chicken is ready to be roasted or grilled. What follows are instructions for partially baking chicken, then finishing on the grill.)", "Preheat the oven to 325 degrees F (165 degrees C). Place chicken pieces, skin side up, in a baking dish; pour in all of the marinade.", "Bake in the preheated oven for 35 minutes. (At this point, the partially baked chicken can be transferred to a plate and refrigerated until ready to finish cooking on a grill, or you can proceed immediately with grilling.)", "Prepare an outdoor grill with charcoal. Coals should be hot and white, without active flame. Alternately, preheat a gas grill for medium heat.", "Pour marinade into a saucepan, and bring to a boil over medium heat. Set aside to use as a basting sauce and finishing sauce.", "Place the chicken on the grill, skin side down. Cook over hot coals with the cover on, adjusting the vents to keep the heat down, until skin has a little color, about 4 minutes. Turn and continue to cook, turning occasionally, basting with sauce each time, 10 to 20 minutes more. The majority of the cooking takes place with the chicken skin side up.", "For perfectly cooked breasts, pull breasts off the grill when the internal temperature, measured with an instant-read thermometer, reaches at least 150 degrees F (66 degrees C). For perfectly cooked leg sections, pull off the grill at 175 degrees F (80 degrees C). Tent chicken with foil; rest for 5 to 10 minutes. The internal temperature will continue to rise.", "Chef John", "For chicken halves, it will be difficult if not impossible to attain the perfect cooking temperature for breast and leg portions at the same time. You will likely have to pull the chicken off the grill when the breast meat is slightly overcooked, and the leg meat is slightly undercooked. For all the meat to be perfectly cooked, you will need to separate the pieces.", "You can use the same basic vinegar and butter marinade, but change the spices to create different flavor profiles."]',
#   'prep_time': '15 mins',
#   'cook_time': '50 mins',
#   'img': 'https://www.allrecipes.com/thmb/mJNbiYJK_SWUHq1jrKSfMdmPji8=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560707_Barbecued-Butter-Chicken_Chef-John_4x3-80385d63fec64f70a92301e4d7203594.jpg',
#   'img_name': 'barbecued-butter-chicken.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/barbecued-butter-chicken.png',
#   'url': 'https://www.allrecipes.com/thmb/mJNbiYJK_SWUHq1jrKSfMdmPji8=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560707_Barbecued-Butter-Chicken_Chef-John_4x3-80385d63fec64f70a92301e4d7203594.jpg'},
#  {'title': 'Sweeten Your Summer With Homemade Peach Crumble',
#   'ingredients': '[{"amt": "6", "unit": "cups", "ingred": "fresh peaches"}, {"amt": "1/4", "unit": "cup", "ingred": "brown sugar"}, {"amt": "3", "unit": "tablespoons", "ingred": "flour"}, {"amt": "1", "unit": "teaspoon", "ingred": "lemon juice"}, {"amt": "1", "unit": "teaspoon", "ingred": "lemon zest"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "cinnamon"}]',
#   'instructions': '["Preheat the oven to 375 degrees F (190 degrees C). Lightly grease a 2-1/2 quart baking dish.", "Place peaches in the prepared baking dish. Combine brown sugar, 3 tablespoons flour, lemon juice, lemon zest, and cinnamon; sprinkle over peaches.", "Combine 1 cup flour, sugar, baking powder, salt, and nutmeg. Stir in egg and mix until mixture has pea-sized crumbles. Sprinkle mixture over peaches. Pour butter evenly over crumbles.", "Bake in the preheated oven until the top is lightly browned, 37 to 40 minutes."]',
#   'prep_time': '15 mins',
#   'cook_time': '40 mins',
#   'img': 'https://www.allrecipes.com/thmb/0UV0p5llzoQQXWiWLfRHwYMlI58=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559227_Peach-Crumble_Yoly_4x3-7e149ba49cc547208734322a9b588b46.jpg',
#   'img_name': 'sweeten-your-summer-with-homemade-peach-crumble.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/sweeten-your-summer-with-homemade-peach-crumble.png',
#   'url': 'https://www.allrecipes.com/thmb/0UV0p5llzoQQXWiWLfRHwYMlI58=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559227_Peach-Crumble_Yoly_4x3-7e149ba49cc547208734322a9b588b46.jpg'},
#  {'title': 'Sparkling Mango Pineapple Sangria',
#   'ingredients': '[{"amt": "1/2", "unit": "cup", "ingred": "pineapple juice"}, {"amt": "1/2", "unit": "cup", "ingred": "mango juice"}, {"amt": "1/2", "unit": "cup", "ingred": "rum"}, {"amt": "1/2", "unit": "cup", "ingred": "rum"}, {"amt": "1/2", "unit": "item", "ingred": "fresh pineapple - peeled, cored, and cut into chunks"}, {"amt": "2", "unit": "item", "ingred": "mangos - peeled, seeded, and sliced"}, {"amt": "750mL", "unit": "item", "ingred": "Prosecco"}]',
#   'instructions': '["Stir pineapple juice, mango juice, pineapple rum, mango rum, chunked pineapple, and mango slices together in a large pitcher. Chill for 2 to 4 hours.", "Add Prosecco before serving. Stir and serve cold."]',
#   'prep_time': '10 mins',
#   'img': 'https://www.allrecipes.com/thmb/ocxqtbdponuhPnoajOjjRfW7MKs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560880_Sparkling-Mango-Pineapple-Sangria_Chef-Mo_4x3-003cb883544a47cfbf2cee1e2a552935.jpg',
#   'img_name': 'sparkling-mango-pineapple-sangria.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/sparkling-mango-pineapple-sangria.png',
#   'url': 'https://www.allrecipes.com/thmb/ocxqtbdponuhPnoajOjjRfW7MKs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560880_Sparkling-Mango-Pineapple-Sangria_Chef-Mo_4x3-003cb883544a47cfbf2cee1e2a552935.jpg'},
#  {'title': 'Grilled Pizza Bianca',
#   'ingredients': '[{"amt": "1", "unit": "tablespoon", "ingred": "butter"}, {"amt": "1", "unit": "clove", "ingred": "garlic, minced"}, {"amt": "1/3", "unit": "cup", "ingred": "heavy cream"}, {"amt": "1", "unit": "cup", "ingred": "grated Parmesan cheese, divided"}, {"amt": "1", "unit": "pound", "ingred": "pizza dough"}, {"amt": "8", "unit": "slices", "ingred": "mozzarella cheese"}]',
#   'instructions': '["Melt butter in a small saucepan over medium-high heat. Add garlic and cook until fragrant, about 30 seconds; stir in cream. Add 2/3 cup Parmesan cheese, and stir until smooth. Let Alfredo sauce cool to room temperature, about 15 minutes.", "Meanwhile, preheat a gas grill with all burners on High for 10 to 15 minutes.", "Divide pizza dough in half. Shape each portion of the pizza dough into an 8 to 10-inch disc. Reduce the flame on half the grill burners to Low, to create areas of direct and indirect heat.", "Carefully place discs of dough, one at a time, onto the grill over direct heat. Close the cover. Let dough grill until the bottom is just barely cooked and shows char marks, 1 to 3 minutes.", "Turn crust ninety degrees (do not flip dough over). Grill until crust shows light grill marks, 1 to 3 minutes.", "Move pizza dough to indirect heat. Spoon Alfredo sauce over dough. Top each crust with four slices mozzarella cheese. Sprinkle remaining 1/3 cup Parmesan cheese evenly over pizzas.", "Grill until cheese is melted, about 3 minutes. Carefully remove pizza from the grill.", "Preheat the oven\\u2019s broiler. Broil pizza until cheese is golden, about 5 minutes. Allow pizza to rest a few minutes before cutting into wedges."]',
#   'prep_time': '15 mins',
#   'cook_time': '10 mins',
#   'img': 'https://www.allrecipes.com/thmb/6Ow2IAYsBXPOsoMyBA9mW2sKt_o=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559340_Grilled-Pizza-Bianca_TheDailyGourmet_4x3-6bf713dd816848518d21ce59f4303098.jpg',
#   'img_name': 'grilled-pizza-bianca.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/grilled-pizza-bianca.png',
#   'url': 'https://www.allrecipes.com/thmb/6Ow2IAYsBXPOsoMyBA9mW2sKt_o=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559340_Grilled-Pizza-Bianca_TheDailyGourmet_4x3-6bf713dd816848518d21ce59f4303098.jpg'},
#  {'title': 'Agua Fresca de Fresas con Crema (Strawberries and Cream)',
#   'ingredients': '[{"amt": "2 1/2", "unit": "pounds", "ingred": "strawberries, hulled and diced, divided"}, {"amt": "2", "unit": "cups", "ingred": "water"}, {"amt": "1 (14 1/2", "unit": "ounce) can", "ingred": "sweetened condensed milk"}, {"amt": "1 (12", "unit": "ounce) can e", "ingred": "vaporated milk"}, {"amt": "1", "unit": "tablespoon", "ingred": "vanilla"}, {"amt": "1/2", "unit": "cup", "ingred": "sugar, or as needed"}, {"amt": "3", "unit": "cups", "ingred": "ice cubes, or as needed"}]',
#   'instructions': '["Place 2 pounds of the strawberries and water in a blender cup and blend until smooth.", "Pour strawberry puree into a large pitcher. Add sweetened condensed milk, evaporated milk, and vanilla. Stir until well incorporated. Taste; add sugar, a little at a time, as needed.", "Add ice cubes and stir. Gently stir in remaining 1/2 pound diced strawberries. Chill until ready to serve."]',
#   'prep_time': '15 mins',
#   'img': 'https://www.allrecipes.com/thmb/uC3iX9Lmlu5B3Q37w5qFAnbLzhM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560919_Agua-Fresca-de-Fresas-con-Crema-Strawberries-and-Cream_Yoly_4x3-330b05ace24443dd90caa0c426153198.jpg',
#   'img_name': 'agua-fresca-de-fresas-con-crema-(strawberries-and-cream).png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/agua-fresca-de-fresas-con-crema-(strawberries-and-cream).png',
#   'url': 'https://www.allrecipes.com/thmb/uC3iX9Lmlu5B3Q37w5qFAnbLzhM=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560919_Agua-Fresca-de-Fresas-con-Crema-Strawberries-and-Cream_Yoly_4x3-330b05ace24443dd90caa0c426153198.jpg'},
#  {'title': 'Spicy Canned Salmon Salad Rice Bowl',
#   'ingredients': '[{"amt": "1", "unit": "cup", "ingred": "nglish cucumber"}, {"amt": "1", "unit": "tablespoon", "ingred": "low-sodium soy sauce"}, {"amt": "1 (14 3/4", "unit": "ounce) can pink", "ingred": "salmon, skin and bone removed, drained and flaked"}, {"amt": "2 \\u00bd", "unit": " tablespoons", "ingred": "Sriracha"}, {"amt": "1", "unit": "tablespoon", "ingred": "light mayonnaise"}, {"amt": "1", "unit": "tablespoon", "ingred": "rice vinegar"}, {"amt": "1", "unit": "cup", "ingred": "cooked white rice"}, {"amt": "1", "unit": "item", "ingred": "avocado "}, {"amt": "1/2", "unit": "teaspoon", "ingred": "sesame seeds"}, {"amt": "1", "unit": "tablespoon", "ingred": "green onion for garnish (optional)"}]',
#   'instructions': '["Combine chopped cucumbers and soy sauce in a small bowl and set aside.", "In a small bowl, combine the salmon, Sriracha\\u00ae, mayonnaise, and rice vinegar.", "In a bowl place cooked rice and top it with the salmon mixture, sliced avocado, and chopped cucumber mixture. Sprinkle with sesame seeds. Top with extra Sriracha and green onions if desired."]',
#   'prep_time': '15 mins',
#   'img': 'https://www.allrecipes.com/thmb/wwoULX6PkbIKFnwR-Iea2mIhuhc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7558696_Spicy-Canned-Salmon-Salad-Rice-Bowl_Chef-Mo_4x3-6efacad1958d41d892d0b30ec8a7d3a7.jpg',
#   'img_name': 'spicy-canned-salmon-salad-rice-bowl.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/spicy-canned-salmon-salad-rice-bowl.png',
#   'url': 'https://www.allrecipes.com/thmb/wwoULX6PkbIKFnwR-Iea2mIhuhc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7558696_Spicy-Canned-Salmon-Salad-Rice-Bowl_Chef-Mo_4x3-6efacad1958d41d892d0b30ec8a7d3a7.jpg'},
#  {'title': 'Copycat Chick-fil-A Frosted Lemonade',
#   'ingredients': '[{"amt": "4", "unit": "cups", "ingred": "vanilla ice cream"}, {"amt": "12", "unit": "ounces", "ingred": "frozen lemonade concentrate"}, {"amt": "1", "unit": "teaspoon", "ingred": "lemon zest"}]',
#   'instructions': '["Place ice cream, frozen lemonade concentrate, and lemon zest in the jar of a blender, and blend until smooth. Divide into 4 glasses, and serve immediately.", "Dotdash Meredith Video Studios", "Put your own spin on this frosted lemonade by using a different flavor of ice cream\\u2013strawberry would be delicious\\u2013or adding another cooling kick of flavor with fresh mint leaves. You can also give this frozen drink the \\u201cgrown-up\\u201d treatment by adding a splash of vodka."]',
#   'prep_time': '5 mins',
#   'img': 'https://www.allrecipes.com/thmb/Q5XBarWwOV37i5Pniydf-nVWLy4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7550375_Copycat-Chick-Fil-A-Frosted-Lemonade_Dotdash-Meredith-Video-Studios_4x3-aadc1c4be9bd4da68e0981b1d18a9f25.jpg',
#   'img_name': 'copycat-chick-fil-a-frosted-lemonade.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/copycat-chick-fil-a-frosted-lemonade.png',
#   'url': 'https://www.allrecipes.com/thmb/Q5XBarWwOV37i5Pniydf-nVWLy4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7550375_Copycat-Chick-Fil-A-Frosted-Lemonade_Dotdash-Meredith-Video-Studios_4x3-aadc1c4be9bd4da68e0981b1d18a9f25.jpg'},
#  {'title': 'Basic No-Soak Beans',
#   'ingredients': '[{"amt": "6", "unit": "cups", "ingred": "water"}, {"amt": "1", "unit": "pound", "ingred": "dried bean"}, {"amt": "1", "unit": "teaspoon", "ingred": "kosher salt"}]',
#   'instructions': '["Preheat the oven to 300 degrees F (150 degrees C).", "Bring cold water to a boil in a heavy-bottomed Dutch oven over high heat. Add beans and salt, and return to a simmer; cover.", "Bake beans in the preheated oven until tender, about 1 hour and 10 minutes, checking after 30 minutes to ensure beans are still covered with water. If necessary, add just enough water to cover.", "Dotdash Meredith Video Studios"]',
#   'prep_time': '5 mins',
#   'cook_time': ' 1 hr 10 mins',
#   'img': 'https://www.allrecipes.com/thmb/jDpU9g6MczG7PhMbC4ed271gaOs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7555578_Basic-No-Soak-Beans_Dotdash-Meredith-Video-Studios_4x3-1eac7c57575147ffb69e4a2bcd5f19a6.jpg',
#   'img_name': 'basic-no-soak-beans.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/basic-no-soak-beans.png',
#   'url': 'https://www.allrecipes.com/thmb/jDpU9g6MczG7PhMbC4ed271gaOs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7555578_Basic-No-Soak-Beans_Dotdash-Meredith-Video-Studios_4x3-1eac7c57575147ffb69e4a2bcd5f19a6.jpg'},
#  {'title': 'Cornflake Corn Cake',
#   'ingredients': '[{"amt": "1", "unit": "teaspoon", "ingred": "butter to grease pan"}, {"amt": "1", "unit": "large ", "ingred": "egg"}, {"amt": "1/2", "unit": "cup", "ingred": "white sugar"}, {"amt": "6", "unit": "tablespoons", "ingred": "unsalted butter, melted"}, {"amt": "1/2", "unit": "cup", "ingred": "plain yogurt"}, {"amt": "1/2", "unit": "cup", "ingred": "milk"}, {"amt": "1/2", "unit": "cup", "ingred": "cornmeal"}, {"amt": "1", "unit": "cup", "ingred": "all-purpose flour"}, {"amt": "1", "unit": "teaspoon", "ingred": "salt"}, {"amt": "1 1/2", "unit": "teaspoons", "ingred": "baking powder"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "baking soda"}, {"amt": "2 1/2", "unit": "cups", "ingred": "cornflakes, divided"}]',
#   'instructions': '["Preheat the oven to 400 degrees F (200 degrees C). Grease a 9-inch round cake pan generously with 1 teaspoon butter, and place a circle of parchment in the bottom.", "Whisk egg and sugar together in a bowl until light and fluffy, about 1 minute. Whisk in melted butter, yogurt, and milk until combined.", "Add cornmeal, flour, salt, baking powder, and baking soda to egg mixture; whisk until dry ingredients are moistened. Fold in 2 cups of the cornflakes with a spatula. Transfer batter to the prepared pan, and smooth the top.", "Scatter remaining 1/2 cup cornflakes evenly over the top; press in lightly with your fingers.", "Bake in the preheated oven until a skewer inserted near the center comes out clean, about 25 minutes.", "Cool cake in the pan for 15 to 20 minutes before removing to a plate. Cool completely before serving with fresh fruit or a fruit sauce.", "Chef John"]',
#   'prep_time': '10 mins',
#   'cook_time': '25 mins',
#   'img': 'https://www.allrecipes.com/thmb/ir7I-bEPOA_-3NBwqM0tZSEJmDg=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7562367_Cornflake-Corn-Cake_Chef-John_4x3-f5adebd77a2643e4b10ef9b4125966cf.jpg',
#   'img_name': 'cornflake-corn-cake.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/cornflake-corn-cake.png',
#   'url': 'https://www.allrecipes.com/thmb/ir7I-bEPOA_-3NBwqM0tZSEJmDg=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7562367_Cornflake-Corn-Cake_Chef-John_4x3-f5adebd77a2643e4b10ef9b4125966cf.jpg'},
#  {'title': 'Air Fryer Cheesy Bacon Ranch French Fries',
#   'ingredients': '[{"amt": "4", "unit": "cups", "ingred": "frozen French fries"}, {"amt": "1/4", "unit": "cup", "ingred": "olive oil"}, {"amt": "2", "unit": "tablespoons", "ingred": "ranch salad dressing mix"}, {"amt": "2", "unit": "teaspoons", "ingred": "bacon bits"}, {"amt": "1", "unit": "pinch", "ingred": "salt"}, {"amt": "1/4", "unit": "cup", "ingred": "shredded Cheddar cheese"}]',
#   'instructions': '["Preheat an air fryer to 400 degrees Fahrenheit (200 degrees C). Place frozen French fries in a large bowl.", "Whisk olive oil and dry ranch salad mix in a separate small bowl until smooth. Pour olive oil mixture over the fries and toss to coat. Add bacon bits and salt. Toss again.", "Place seasoned fries in the basket of the air fryer. Cook for 7 minutes. Shake the basket and cook 5 minutes more.", "Sprinkle shredded cheese over the fries. Cook 2 minutes. Using a spatula, transfer to a serving platter and serve immediately."]',
#   'prep_time': '5 mins',
#   'cook_time': '15 mins',
#   'img': 'https://www.allrecipes.com/thmb/rRqByx76RLk27s9-YYKfloAp_ng=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560981_Air-Fryer-Cheesy-Bacon-Ranch-Fries-Soup-Loving-Nicole_4x3-3db3470e8a3d4bdb8523989590c2ca52.jpg',
#   'img_name': 'air-fryer-cheesy-bacon-ranch-french-fries.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/air-fryer-cheesy-bacon-ranch-french-fries.png',
#   'url': 'https://www.allrecipes.com/thmb/rRqByx76RLk27s9-YYKfloAp_ng=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7560981_Air-Fryer-Cheesy-Bacon-Ranch-Fries-Soup-Loving-Nicole_4x3-3db3470e8a3d4bdb8523989590c2ca52.jpg'},
#  {'title': 'Sparkling Peach Sangria',
#   'ingredients': '[{"amt": "1 (750", "unit": "ml) bottle", "ingred": "rosecco, well chilled"}, {"amt": "2", "unit": "item", "ingred": "peaches, thinly sliced"}, {"amt": "1", "unit": "cup", "ingred": "ointreau liqueur"}, {"amt": "2", "unit": "limes, thinly sliced, divided", "ingred": "limes, thinly sliced, divided"}, {"amt": "1", "unit": "tablespoon", "ingred": "mint leaves"}, {"amt": "1", "unit": "(1-inch) piece fresh", "ingred": "ginger, finely grated"}, {"amt": "12", "unit": "ounces", "ingred": "sparkling water, or to taste"}, {"amt": "2", "unit": "tablespoons", "ingred": "mint leaves for garnish (optional)"}]',
#   'instructions': '["Early in the day, refrigerate prosecco. Combine peach slices, Cointreau, half of lime slices, mint leaves, and grated ginger in a container with a lid. Refrigerate at least 6 hours, making sure peaches are submerged in liquid.", "When ready to serve, pour peach mixture into a large serving pitcher and add prosecco. Stir briefly to combine.", "Place some of the fruit in each glass, add sangria, and top with 2 ounces sparkling water, or to taste. Garnish with reserved lime slices and additional mint leaves, if desired."]',
#   'prep_time': '10 mins',
#   'img': 'https://www.allrecipes.com/thmb/uCCR_7BRVqGpaIlHLhpHUh2rc8A=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559189_Sparkling-Peach-Sangria_Bibi_4x3-3d110afa6a3042c98a94ea8997aaa64e.jpg',
#   'img_name': 'sparkling-peach-sangria.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/sparkling-peach-sangria.png',
#   'url': 'https://www.allrecipes.com/thmb/uCCR_7BRVqGpaIlHLhpHUh2rc8A=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7559189_Sparkling-Peach-Sangria_Bibi_4x3-3d110afa6a3042c98a94ea8997aaa64e.jpg'},
#  {'title': 'Gold Rush',
# ...
#   'prep_time': '5 mins',
#   'cook_time': '0 mins',
#   'img': 'https://www.allrecipes.com/thmb/gvn7lJddUFx2SE4vJPAqskjqBAE=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568869_Apple-Smoothie_Kim_4x3-c282869bfeff49d8a01b5b82c089805f.jpg',
#   'img_name': 'apple-smoothie.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/apple-smoothie.png',
#   'url': 'https://www.allrecipes.com/thmb/gvn7lJddUFx2SE4vJPAqskjqBAE=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568869_Apple-Smoothie_Kim_4x3-c282869bfeff49d8a01b5b82c089805f.jpg'},
#  {'title': 'Chicken Broccoli Rice Skillet',
#   'ingredients': '[{"amt": "1", "unit": "tablespoon", "ingred": "butter"}, {"amt": "1", "unit": "small", "ingred": "onion, diced"}, {"amt": "1", "unit": "item", "ingred": "boneless skinless chicken breast"}, {"amt": "1/4", "unit": "cup", "ingred": "orzo (optional)"}, {"amt": "1 (6.3", "unit": "ounce) box", "ingred": "garlic and herb rice mix"}, {"amt": "1 3/4", "unit": "cups", "ingred": "chicken broth"}, {"amt": "1/2", "unit": "cup", "ingred": "milk"}, {"amt": "1 (10.5", "unit": "ounce)", "ingred": "cream of chicken soup"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "oregano"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "garlic"}, {"amt": "12", "unit": "ounces", "ingred": "broccoli florets"}, {"amt": "1", "unit": "cup", "ingred": "sharp Cheddar cheese"}]',
#   'instructions': '["Melt butter in a large nonstick skillet over medium heat, and cook and stir onions until softened and translucent, about 5 minutes.", "Meanwhile, cut chicken breast into bite-sized pieces. Add chicken to the skillet; cook and stir until golden, about 5 minutes.", "Add orzo and rice with seasoning packet to skillet. In a medium bowl, stir together chicken broth, milk, cream of chicken soup, oregano, and garlic; pour mixture into skillet. Stir to combine; add broccoli florets", "Reduce heat to low, cover, and cook until rice and orzo are tender with a bite and liquid is absorbed, about 25 minutes", "Turn on the oven\\u2019s broiler and set a rack 6 inches below the heating element. Sprinkle cheese over the skillet, and broil until cheese is golden and melted, about 3 minutes. Serve immediately."]',
#   'prep_time': '15 mins',
#   'cook_time': '38 mins',
#   'img': 'https://www.allrecipes.com/thmb/0y_CZ02WTkpqiV2zjOoRGqCoEaQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568422_Chicken-Broccoli-Rice-Skillet_TheDailyGourmet_4x3-87d917cc76304331a5c5a99fcd9366e9.jpg',
#   'img_name': 'chicken-broccoli-rice-skillet.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/chicken-broccoli-rice-skillet.png',
#   'url': 'https://www.allrecipes.com/thmb/0y_CZ02WTkpqiV2zjOoRGqCoEaQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568422_Chicken-Broccoli-Rice-Skillet_TheDailyGourmet_4x3-87d917cc76304331a5c5a99fcd9366e9.jpg'},
#  {'title': 'Elote Pizza',
#   'ingredients': '[{"amt": "1", "unit": "pound", "ingred": "pizza dough"}, {"amt": "2", "unit": "teaspoons", "ingred": "olive oil, or as needed"}, {"amt": "2", "unit": "tablespoons", "ingred": "sour cream, plus more for drizzling"}, {"amt": "2", "unit": "tablespoons", "ingred": "mayonnaise"}, {"amt": "2", "unit": "teaspoons", "ingred": "chili lime seasoning"}, {"amt": "1/4", "unit": "cup", "ingred": "cotija cheese"}, {"amt": "1/4", "unit": "cup", "ingred": "shredded quesadilla cheese"}, {"amt": "1/2", "unit": "cup", "ingred": "corn kernels"}, {"amt": "1/4", "unit": "item", "ingred": "red onion, very thinly sliced"}, {"amt": "2", "unit": "tablespoons", "ingred": "chopped cilantro"}, {"amt": "1", "unit": "item", "ingred": "jalapeno, very thinly sliced, or more to taste"}, {"amt": "2", "unit": "teaspoons", "ingred": "butter"}]',
#   'instructions': '["Preheat a gas grill with all burners on High for 10 to 15 minutes. Shape pizza dough and brush with olive oil.", "Reduce the flame on half of the grill burners to Low, to create areas of direct and indirect heat.", "Carefully place dough (olive oil side facing down) onto the grill over direct heat Close the cover. Let dough grill until the bottom is just barely cooked and shows char marks, 1 to 3 minutes.", "Use tongs to move dough to the indirect heat; do not flip dough over! Cook 2 to 3 more minutes. Remove dough to a baking sheet.", "Stir together 2 tablespoons sour cream, mayonnaise, and 1 1/2 teaspoons Tajin seasoning. Spread sour cream mixture over dough. Mix remaining Tajin, cotija, quesadilla cheese, corn, and red onions. Distribute topping mixture over dough.", "Return pizza to grill. Grill until cheese is melted, about 3 minutes. Carefully remove pizza from the grill. Scatter cilantro and jalape\\u00f1os over pizza, and drizzle with additional sour cream. Mix melted butter with remaining 1/2 teaspoon Tajin seasoning and brush crust with Tajin butter. Cut into wedges and serve."]',
#   'prep_time': '20 mins',
#   'cook_time': '6 mins',
#   'img': 'https://www.allrecipes.com/thmb/_CoEztIYgUuHw6CoUsJVGivHmBo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568835_Elote-Pizza_TheDailyGourmet_4x3-4f3478a9be554319804f91099b8a3c31.jpg',
#   'img_name': 'elote-pizza.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/elote-pizza.png',
#   'url': 'https://www.allrecipes.com/thmb/_CoEztIYgUuHw6CoUsJVGivHmBo=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7568835_Elote-Pizza_TheDailyGourmet_4x3-4f3478a9be554319804f91099b8a3c31.jpg'},
#  {'title': 'Charcoal-Grilled Ribeye Steak',
#   'ingredients': '[{"amt": "1 (12", "unit": "ounce)", "ingred": "ribeye steak"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "seasoned salt, "}, {"amt": "1/4", "unit": "teaspoon", "ingred": "black pepper, or to taste"}]',
#   'instructions': '["Season steak evenly, using 1/4 teaspoon seasoned salt and 1/8 teaspoon black pepper on each side. Set aside.", "Light charcoal briquettes. Once they are red hot, place steak on the grates. Grill for 4 to 5 minutes. Turn steak over and grill an additional 2 to 3 minutes.", "Tent steak with aluminum foil and let rest 4 to 5 minutes before serving."]',
#   'prep_time': '5 mins',
#   'cook_time': '6 mins',
#   'img': 'https://www.allrecipes.com/thmb/wlDedoifywf-dxApaISbgiaK1Ts=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7567649_Briquette-Grilled-Ribeye-Steak_Yoly_4x3-7c200441d55e4eeda1f90c7902a0e147.jpg',
#   'img_name': 'charcoal-grilled-ribeye-steak.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/charcoal-grilled-ribeye-steak.png',
#   'url': 'https://www.allrecipes.com/thmb/wlDedoifywf-dxApaISbgiaK1Ts=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7567649_Briquette-Grilled-Ribeye-Steak_Yoly_4x3-7c200441d55e4eeda1f90c7902a0e147.jpg'},
#  {'title': 'Good Old-Fashioned Pancakes',
#   'ingredients': '[{"amt": "1 \\u00bd", "unit": "cups", "ingred": "all-purpose flour"}, {"amt": "3 \\u00bd", "unit": "teaspoons", "ingred": "baking powder"}, {"amt": "1", "unit": "tablespoon", "ingred": "white sugar"}, {"amt": "\\u00bc", "unit": "teaspoon", "ingred": "salt, or more to taste "}, {"amt": "1 \\u00bc", "unit": "cups", "ingred": "milk"}, {"amt": "3", "unit": "tablespoons", "ingred": "butter, melted"}, {"amt": "1", "unit": "", "ingred": "egg"}]',
#   'instructions': '["Sift flour, baking powder, sugar, and salt together in a large bowl. Make a well in the center and add milk, melted butter, and egg; mix until smooth.", "Heat a lightly oiled griddle or pan over medium-high heat. Pour or scoop the batter onto the griddle, using approximately 1/4 cup for each pancake; cook until bubbles form and the edges are dry, about 2 to 3 minutes. Flip and cook until browned on the other side. Repeat with remaining batter.", "The salt amount has been reduced based on review feedback. The original recipe called for 1 teaspoon."]',
#   'prep_time': '5 mins',
#   'cook_time': '15 mins',
#   'img': 'https://www.allrecipes.com/thmb/WqWggh6NwG-r8PoeA3OfW908FUY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/21014-Good-old-Fashioned-Pancakes-mfs_001-1fa26bcdedc345f182537d95b6cf92d8.jpg',
#   'img_name': 'good-old-fashioned-pancakes.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/good-old-fashioned-pancakes.png',
#   'url': 'https://www.allrecipes.com/thmb/WqWggh6NwG-r8PoeA3OfW908FUY=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/21014-Good-old-Fashioned-Pancakes-mfs_001-1fa26bcdedc345f182537d95b6cf92d8.jpg'},
#  {'title': 'Super-Delicious Zuppa Toscana',
#   'ingredients': '[{"amt": "1", "unit": "pound", "ingred": "bulk mild Italian sausage"}, {"amt": "1 \\u00bc", "unit": "teaspoons", "ingred": "crushed red pepper flakes"}, {"amt": "4", "unit": "slices", "ingred": "bacon, cut into 1/2 inch pieces"}, {"amt": "1", "unit": "large", "ingred": "onion, diced"}, {"amt": "1", "unit": "tablespoon", "ingred": "minced garlic"}, {"amt": "5", "unit": "(13.75 ounce) cans", "ingred": "chicken broth"}, {"amt": "6", "unit": "medium", "ingred": "potatoes, thinly sliced "}, {"amt": "1", "unit": "cup", "ingred": "heavy cream"}, {"amt": "\\u00bc", "unit": "bunch", "ingred": "fresh spinach, tough stems removed"}]',
#   'instructions': '["Cook Italian sausage and red pepper flakes in a Dutch oven over medium-high heat until crumbly, browned, and no longer pink, 10 to 15 minutes. Drain and set aside.", "Cook bacon in the same Dutch oven over medium heat until crisp, about 10 minutes. Drain, leaving a few tablespoons of drippings with the bacon in the bottom of the Dutch oven. Stir in onions and garlic; cook until onions are soft and translucent, about 5 minutes.", "Stir in chicken broth and bring to a boil over high heat. Add potatoes and simmer until fork tender, about 20 minutes. Reduce heat to medium; stir in cream, cooked sausage, and spinach. Cook and stir until spinach has wilted and sausage is warmed through; serve.", "Please note the differences in serving size and the substitution of lacinato kale for spinach when using the magazine version of this recipe."]',
#   'prep_time': '20 mins',
#   'cook_time': '55 mins',
#   'img': 'https://www.allrecipes.com/thmb/b4ortB6V9Av5yQm9A0xjLCwFpm4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Super-Delicious-Zuppa-Toscana-e0ecd2a124674b84b63570320d20ca9b.jpeg',
#   'img_name': 'super-delicious-zuppa-toscana.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/super-delicious-zuppa-toscana.png',
#   'url': 'https://www.allrecipes.com/thmb/b4ortB6V9Av5yQm9A0xjLCwFpm4=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Super-Delicious-Zuppa-Toscana-e0ecd2a124674b84b63570320d20ca9b.jpeg'},
#  {'title': "World's Best Lasagna",
#   'ingredients': '[{"amt": "1", "unit": "pound", "ingred": "sweet Italian sausage"}, {"amt": "\\u00be", "unit": "pound", "ingred": "lean ground beef"}, {"amt": "\\u00bd", "unit": "cup", "ingred": "minced onion"}, {"amt": "2", "unit": "cloves", "ingred": "garlic, crushed"}, {"amt": "1", "unit": "(28 ounce) can", "ingred": "crushed tomatoes"}, {"amt": "2", "unit": "(6.5 ounce) cans", "ingred": "canned tomato sauce"}, {"amt": "2", "unit": "(6 ounce) cans", "ingred": "tomato paste"}, {"amt": "\\u00bd", "unit": "cup", "ingred": "water"}, {"amt": "2", "unit": "tablespoons", "ingred": "white sugar"}, {"amt": "4", "unit": "tablespoons", "ingred": "chopped fresh parsley, divided"}, {"amt": "1 \\u00bd", "unit": "teaspoons", "ingred": "dried basil leaves"}, {"amt": "1 \\u00bd", "unit": "teaspoons", "ingred": "salt, divided, or to taste"}, {"amt": "1", "unit": "teaspoon", "ingred": "Italian seasoning"}, {"amt": "\\u00bd", "unit": "teaspoon", "ingred": "fennel seeds"}, {"amt": "\\u00bc", "unit": "teaspoon", "ingred": "ground black pepper"}, {"amt": "12", "unit": "", "ingred": "lasagna noodles"}, {"amt": "16", "unit": "ounces", "ingred": "ricotta cheese"}, {"amt": "1", "unit": "", "ingred": "egg"}, {"amt": "\\u00be", "unit": "pound", "ingred": "mozzarella cheese, sliced"}, {"amt": "\\u00be", "unit": "cup", "ingred": "grated Parmesan cheese"}]',
#   'instructions': '["Gather all your ingredients.", "Dotdash Meredith Food Studios", "Cook sausage, ground beef, onion, and garlic in a Dutch oven over medium heat until well browned.", "Dotdash Meredith Food Studios", "Stir in crushed tomatoes, tomato sauce, tomato paste, and water. Season with sugar, 2 tablespoons parsley, basil, 1 teaspoon salt, Italian seasoning, fennel seeds, and pepper. Simmer, covered, for about 1 1/2 hours, stirring occasionally.", "Dotdash Meredith Food Studios", "Bring a large pot of lightly salted water to a boil. Cook lasagna noodles in boiling water for 8 to 10 minutes. Drain noodles, and rinse with cold water.", "Dotdash Meredith Food Studios", "In a mixing bowl, combine ricotta cheese with egg, remaining 2 tablespoons parsley, and 1/2 teaspoon salt.", "Dotdash Meredith Food Studios", "Preheat the oven to 375 degrees F (190 degrees C).", "To assemble, spread 1 1/2 cups of meat sauce in the bottom of a 9x13-inch baking dish. Arrange 6 noodles lengthwise over meat sauce. Spread with 1/2 of the ricotta cheese mixture. Top with 1/3 of the mozzarella cheese slices. Spoon 1 1/2 cups meat sauce over mozzarella, and sprinkle with 1/4 cup Parmesan cheese.", "Dotdash Meredith Food Studios", "Repeat layers, and top with remaining mozzarella and Parmesan cheese. Cover with foil: to prevent sticking, either spray foil with cooking spray or make sure the foil does not touch the cheese.", "Dotdash Meredith Food Studios", "Bake in the preheated oven for 25 minutes. Remove the foil and bake for an additional 25 minutes.", "Dotdash Meredith Food Studios", "Rest lasagna for 15 minutes before serving.", "Dotdash Meredith Food Studios"]',
#   'prep_time': '30 mins',
#   'cook_time': ' 2 hrs 30 mins',
#   'img': 'https://www.allrecipes.com/thmb/vmL8iEleAiQJzU3s6YfEMVcvhwc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/23600-worlds-best-lasagna-armag-4x3-1-b24f9ad518d74090bf197828492c64a6.jpg',
#   'img_name': "world's-best-lasagna.png",
#   'img_loc': "/home/james/hackathon-mvp/prisma/data/avatars/world's-best-lasagna.png",
#   'url': 'https://www.allrecipes.com/thmb/vmL8iEleAiQJzU3s6YfEMVcvhwc=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/23600-worlds-best-lasagna-armag-4x3-1-b24f9ad518d74090bf197828492c64a6.jpg'},
#  {'title': 'Banana Banana Bread',
#   'ingredients': '[{"amt": "2", "unit": "cups", "ingred": "all-purpose flour"}, {"amt": "1", "unit": "teaspoon", "ingred": "baking soda"}, {"amt": "\\u00bc", "unit": "teaspoon", "ingred": "salt"}, {"amt": "\\u00be", "unit": "cup", "ingred": "brown sugar"}, {"amt": "\\u00bd", "unit": "cup", "ingred": "butter"}, {"amt": "2", "unit": "", "ingred": "eggs, beaten"}, {"amt": "2 \\u2153", "unit": "cups", "ingred": "mashed overripe bananas"}]',
#   'instructions': '["Preheat the oven to 350 degrees F (175 degrees C). Lightly grease a 9x5-inch loaf pan.", "Combine flour, baking soda, and salt in a large bowl. Beat brown sugar and butter with an electric mixer in a separate large bowl until smooth. Stir in eggs and mashed bananas until well blended. Stir banana mixture into flour mixture until just combined. Pour batter into the prepared loaf pan.", "Bake in the preheated oven until a toothpick inserted into the center comes out clean, about 60 minutes. Let bread cool in pan for 10 minutes, then turn out onto a wire rack to cool completely."]',
#   'prep_time': '15 mins',
#   'cook_time': ' 1 hr',
#   'img': 'https://www.allrecipes.com/thmb/7Vn00l3j_zQJtXgYFCu4sU-xOOs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/20144-banana-banana-bread-mfs-57-0bb49d050a6941c4b3715e57b8e6badd.jpg',
#   'img_name': 'banana-banana-bread.png',
#   'img_loc': '/home/james/hackathon-mvp/prisma/data/avatars/banana-banana-bread.png',
#   'url': 'https://www.allrecipes.com/thmb/7Vn00l3j_zQJtXgYFCu4sU-xOOs=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/20144-banana-banana-bread-mfs-57-0bb49d050a6941c4b3715e57b8e6badd.jpg'}]

# %%
for obj in db_objs:
    if "prep_time" not in obj:
        print("not prep time")
    if "cook_time" not in obj:
        print("not cook time")
# Out:
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time
# not cook time

# %%
db_objs[0]["title"
# Out:
# 'These Grilled Ribeye Steaks Are Juicy and Flavorful'

# %%
recipe_objs[0]
# Out:
# {'name': 'These Grilled Ribeye Steaks Are Juicy and Flavorful',
#  'steps': ['Combine lime juice, carne asada seasoning, and oil in a resealable plastic bag. Add ribeye steak, reseal the bag, and marinate in the refrigerator for 30 to 45 minutes.',
#   'Drain marinade and allow steak to come to room temperature, about 30 minutes. Blot any excess moisture off the steak.',
#   'Preheat the grill to 500 degrees F (260 degrees C), and lightly oil the grate.',
#   'Place steak on the grill over direct heat. For rare: cook steaks until browned on the outside and red in the center, about 3 minutes per side. An instant-read thermometer inserted into the center should read 125 degrees F (52 degrees C).',
#   'Remove steak from grill; rest 5 minutes before serving.',
#   'Additional internal temperatures for cooking steak: Rare: 125-130 degrees F (52-54 degrees C); Medium rare: 130-140 degrees F (54-60 degrees C); Medium:\xa0 140-150 degrees F (54-65 degrees C); Medium well: 150-160 degrees F (65-70 degrees C);\xa0 Well done: 160 degrees F (70 degrees C).'],
#  'ingredients': [{'amt': '1/2', 'unit': 'lime', 'ingred': ', juiced'},
#   {'amt': '2', 'unit': 'teaspoons', 'ingred': 'seasoning'},
#   {'amt': '1', 'unit': 'tablespoon', 'ingred': 'olive oil'},
#   {'amt': '1 (8', 'unit': 'ounce)', 'ingred': 'ribeye steak'}],
#  'img': 'https://www.allrecipes.com/thmb/2tQKTk9vGg_v9HrdXYVfDd0CH7E=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7552430_Grilled-Ribeye-Steaks_TheDailyGourmet_4x3-62178245a22845b2a4478e815cd8969f.jpg',
#  'Prep Time:': '5 mins',
#  'Cook Time:': '6 mins',
#  'Marinate Time:': '30 mins',
#  'Stand Time:': '30 mins',
#  'Rest Time:': '5 mins',
#  'Total Time:': ' 1 hr 16 mins',
#  'Servings:': '1 '}

# %%
db_objs[1]
# Out:
# {'title': 'Skillet Chicken Breasts with Cherry Tomatoes',
#  'ingredients': '[{"amt": "1 1/2", "unit": "pounds", "ingred": "boneless, skinless chicken breasts"}, {"amt": "1/2", "unit": "teaspoon", "ingred": "smoked paprika"}, {"amt": 1, "unit": "item", "ingred": "salt and freshly ground black pepper to taste"}, {"amt": "2 ", "unit": "tablespoons", "ingred": "herb-infused olive oil"}, {"amt": "1", "unit": "tablespoon", "ingred": "unsalted butter"}, {"amt": "1/2", "unit": "item", "ingred": "red onion, thinly sliced"}, {"amt": "3", "unit": "cloves", "ingred": "garlic, minced"}, {"amt": "1/2", "unit": "cup", "ingred": "white wine"}, {"amt": "3", "unit": "cups", "ingred": "cherry tomatoes, halved"}, {"amt": "1/4", "unit": "teaspoon", "ingred": "red pepper flakes, or to taste"}, {"amt": "1/2", "unit": "cup", "ingred": "cream, or to taste"}, {"amt": "1", "unit": "tablespoon", "ingred": "fresh basil, plus more for garnish (optional)"}, {"amt": "1/4", "unit": "cup", "ingred": "grated Parmesan cheese"}]',
#  'instructions': '["Pat chicken breasts dry with paper towels, and season both sides with smoked paprika, salt, and pepper.", "In a large, non-stick skillet, heat herb-infused olive oil and butter over medium heat. When the butter is foamy, add chicken breasts and cook until browned on both sides, 4 to 5 minutes per side. Remove chicken to a plate and keep warm.", "To the same skillet, add red onion slices and cook until tender, 3 to 4 minutes. If the skillet seems dry, add a bit more olive oil. Stir in garlic; cook until fragrant, about 30 seconds.", "Add white wine; cook and stir for about 1 minute, then add cherry tomatoes and red pepper flakes.", "Stir in cream and cook until sauce is bubble. Return chicken and any accumulated juices to the skillet. Cover, reduce heat to low, and cook until chicken is no longer pink in the center and juices run clear, about 10 minutes. An instant-read thermometer inserted near the center should read at least 165 degrees F (74 degrees C).", "Sprinkle minced fresh basil and grated Parmesan over all. Garnish with additional basil, if desired."]',
#  'prep_time': '10 mins',
#  'cook_time': '25 mins',
#  'img': 'https://www.allrecipes.com/thmb/zGTj_99OYuEcelC0USKg7gUYDVQ=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/7553999_Skillet-Chicken-Breasts-with-Cherry-Tomaotes_Bibi_4x3-4a90ae5c8bfd459d87be2cc5d2ab17ac.jpg'}

# %%
for obj in db_objs:
    filename = obj["title"]
    filename = filename.lower().replace(" ","-")
    urllib.request.urlretrieve(obj["img"], f"../../../../hackathon-mvp/prisma/data/avatars/{filename}.png")
