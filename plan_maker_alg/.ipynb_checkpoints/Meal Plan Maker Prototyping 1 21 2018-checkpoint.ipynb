# %%
import pandas as pd
import numpy as np
from random import randint

# %%
prot_req = 208
fat_req = 44
carb_req = 182

# %%
full_df = pd.read_csv("C:/Users/J/Desktop/Businesses/branded_foods_in_progress.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (140) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
alpha_df = full_df[['ndb_no','desc_only','kilocalories', 'protein_g','fat_g','carb_g','unit_per_item']]
useful_df = alpha_df[alpha_df['kilocalories']>0]

# %%
useful_df.protein_g[useful_df['protein_g'].isnull()] = 0
useful_df.fat_g[useful_df['fat_g'].isnull()] = 0
useful_df.carb_g[useful_df['carb_g'].isnull()] = 0
useful_df.isnull().sum()
useful_df.protein_g = useful_df.protein_g.astype(int)
useful_df.fat_g = useful_df.fat_g.astype(int)
useful_df.carb_g = useful_df.carb_g.astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
temp_df = pd.DataFrame()
temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])

# %%
delta = [int(prot_req), int(fat_req), int(carb_req)]

# %%
delta = np.array([prot_req,fat_req,carb_req])-np.array([sum(temp_df['protein_g']),sum(temp_df['fat_g']),sum(temp_df['carb_g'])])
delta
# Out:
# array([ 202.,   38.,  170.])

# %%
# First Iter
temp_df = pd.DataFrame()
plan_df = pd.DataFrame()
plan_id = 0
# Insert Logic Here
temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])
delta = np.array([prot_req,fat_req,carb_req])-np.array([sum(temp_df['protein_g']),sum(temp_df['fat_g']),sum(temp_df['carb_g'])])
# If at least one of the delta values is over 50% of final target
it=0
if sum((delta<np.array(prot_req*.5,fat_req*.5,carb_req*.5)))>0:
    match_df = useful_df[useful_df['protein_g']==delta[0] and useful_df['fat_g']==delta[1] and useful_df['carb_g']==delta[2]]
    if len(match_df)==0:
        # Add a random item
        it+=1
        temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])
        # Drop a random item
        if it%2 ==0:
            temp_df = temp_df.drop[temp_df.index(randint(0,len(temp_df)))]
    else:
        for(i in range(len(match_df))):
            plan_id+=1
            temp_df = temp_df.append(match_df.iloc[i,:])
            plan_df = plan_df.append([{'ndb_no':temp_df['ndb_no'], 'plan_id':[plan_id]*len(temp_df)}])
# Out:
#   File "<ipython-input-29-7681b33e5839>", line 20
#     for(i in range(len(match_df))):
#                                   ^
# SyntaxError: invalid syntax

# %%
temp_df = pd.DataFrame()
temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])
temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])
temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])
temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])

temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])

temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])

temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])

temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])

# %%
temp_df
# Out:
#        carb_g                                          desc_only  fat_g  \
# 31293    69.0                          CHEESESTEAK PRETZEL MELT,   40.0
# 16349    23.0                                BIG Y, BRAN FLAKES,    0.0
# 35394    31.0                                 CHOCOLATE CANDIES,    8.0
# 17593    32.0  BLACK FOREST ORGANIC, ORGANIC FRUITY CHEWS, LE...    4.0
# 18808     2.0  BLUE DIAMOND ALMONDS, ALMOND BREEZE, ALMOND MI...    3.0
# 39585    13.0       CLOVERLAND FARMS DAIRY, 2% REDUCED FAT MILK,    4.0
# 69836     6.0  FROG HOLLOW FARM, LEGENDARY FRUITS ORGANIC NEC...    0.0
# 43199    37.0        CORABELLA, TRICOLOR FOUR CHEESE TORTELLINI,    4.0
#
#        kilocalories      ndb_no  protein_g        unit_per_item
# 31293         780.0  45220694.0       36.0  b'PACKAGE 269\xa0g'
# 16349         110.0  45172313.0        3.0       b'cup 29\xa0g'
# 35394         200.0  45331293.0        2.0       b'BOX 43\xa0g'
# 17593         160.0  45224078.0        0.0    b'PIECES 40\xa0g'
# 18808          39.0  45209232.0        1.0     b'OZA 325\xa0ml'
# 39585         130.0  45236277.0        8.0     b'cup 240\xa0ml'
# 69836          25.0  45098138.0        1.0      b'Tbsp 20\xa0g'
# 43199         200.0  45036454.0        7.0       b'ONZ 54\xa0g'

# %%
temp_df = temp_df.drop(temp_df.index[[len(temp_df)]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-115-33656965a515> in <module>()
# ----> 1 temp_df = temp_df.drop(temp_df.index[[len(temp_df)]])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\indexes\base.py in __getitem__(self, key)
#    1432
#    1433         key = _values_from_object(key)
# -> 1434         result = getitem(key)
#    1435         if not is_scalar(result):
#    1436             return promote(result)
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
temp_df.index[[1]]
# Out:
# Int64Index([46834], dtype='int64')

# %%
temp_df = temp_df.drop[temp_df.index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-63d26928e95e> in <module>()
# ----> 1 temp_df = temp_df.drop[temp_df.iloc[0,:]]
#
# TypeError: 'method' object is not subscriptable

# %%
np.array([prot_req,fat_req,carb_req])
# Out:
# array([208,  44, 182])

# %%
delta = np.array([prot_req,fat_req,carb_req])-np.array([sum(temp_df['protein_g']),sum(temp_df['fat_g']),sum(temp_df['carb_g'])])

# %%
delta
# Out:
# array([ 150.,  -19.,  -31.])

# %%
sum((delta<np.array([0,0,0])))>0
# Out:
# True

# %%
def find_a_plan(prot_req, fat_req, carb_req):# First Iter
    temp_df = pd.DataFrame()
    plan_df = pd.DataFrame()
    plan_id = 0
    # Insert Logic Here
    # If at least one of the delta values is over 50% of final target
    it=0
    drop_it = 0
    for i in range(30000):
        temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)-1),:])
        delta = np.array([prot_req,fat_req,carb_req])-np.array([sum(temp_df['protein_g']),sum(temp_df['fat_g']),sum(temp_df['carb_g'])])

        while sum((delta<np.array([0,0,0])))>0:
            temp_df = temp_df.drop(temp_df.index[[randint(0,len(temp_df)-1)]])
            delta = np.array([prot_req,fat_req,carb_req])-np.array([sum(temp_df['protein_g']),sum(temp_df['fat_g']),sum(temp_df['carb_g'])])
            drop_it+=1
            print(drop_it)
        print(str(i)+ ' iterations')
        print(str(len(temp_df))+' items considered')
        print(delta)
        if sum((delta<np.array([prot_req*.5,fat_req*.5,carb_req*.5])))>0:
            match_df = useful_df[(useful_df['protein_g']==delta[0])& (useful_df['fat_g']==delta[1]) & (useful_df['fat_g']==delta[2])]
            if len(match_df)==0:
                # Add a random item
                it+=1
                # Drop a random item
                if it%2 ==0:
                    temp_df = temp_df.drop(temp_df.index[[randint(0,len(temp_df)-1)]])
                delta = np.array([prot_req,fat_req,carb_req])-np.array([sum(temp_df['protein_g']),sum(temp_df['fat_g']),sum(temp_df['carb_g'])])
            else:
                for j in range(len(match_df)):
                    plan_id+=1
                    temp_df = temp_df.append(match_df.iloc[j,:])
                    plan_df = plan_df.append([{'ndb_no':temp_df['ndb_no'], 'plan_id':[plan_id]*len(temp_df)}])
                return pd.DataFrame([{'prot_req':prot_req,
                                      'fat_req':fat_req,
                                      'carb_req':carb_req,
                                      'num_items':len(temp_df),
                                      'num_matches':len(match_df),
                                      'mac_proportions':sum([abs(prot_req-fat_req),abs(fat_req-carb_req),abs(prot_req-carb_req)]),
                                      'iterations':i,
                                      'prot_delta': delta[0],
                                      'fat_delta': delta[1],
                                      'carb_delta': delta[2]
                                     }])
    return pd.DataFrame([{'prot_req':prot_req,
                                      'fat_req':fat_req,
                                      'carb_req':carb_req,
                                      'num_items':len(temp_df),
                                      'num_matches':len(match_df),
                                      'mac_proportions':sum([abs(prot_req-fat_req),abs(fat_req-carb_req),abs(prot_req-carb_req)]),
                                      'iterations':i,
                                      'prot_delta': delta[0],
                                      'fat_delta': delta[1],
                                      'carb_delta': delta[2]
                                     }])

# %%
def monte_carlo_maker(iterations):
    mc_df = pd.DataFrame()
    for i in range(iterations):
        req1 = randint(20,220)
        req2 = randint(20,220)
        req3 = randint(20,220)
        result = find_a_plan(req1 , req2, req3)
        mc_df.append(result, ignore_index=True)
    return mc_df

# %%
test = monte_carlo_maker(10)
# Out:
# 0 iterations
# 1 items considered
# [ 114.  124.  161.]
# 1 iterations
# 2 items considered
# [ 114.  124.  156.]
# 2 iterations
# 3 items considered
# [ 113.  119.  135.]
# 3 iterations
# 4 items considered
# [ 110.  119.  127.]
# 4 iterations
# 5 items considered
# [ 102.  117.   95.]
# 5 iterations
# 6 items considered
# [ 100.  111.   91.]
# 6 iterations
# 7 items considered
# [ 100.  111.   76.]
# 7 iterations
# 7 items considered
# [  96.  117.   63.]
# 8 iterations
# 8 items considered
# [  91.  104.   54.]
# 9 iterations
# 8 items considered
# [  97.  104.   42.]
# 10 iterations
# 9 items considered
# [  97.  104.   26.]
# 11 iterations
# 9 items considered
# [ 99.  93.  52.]
# 12 iterations
# 10 items considered
# [ 97.  83.  35.]
# 13 iterations
# 10 items considered
# [ 99.  92.  51.]
# 14 iterations
# 11 items considered
# [ 87.  90.  37.]
# 15 iterations
# 11 items considered
# [ 87.  73.  62.]
# 16 iterations
# 12 items considered
# [ 82.  73.  30.]
# 17 iterations
# 12 items considered
# [ 75.  72.   3.]
# 1
# 18 iterations
# 12 items considered
# [ 66.  69.   8.]
# 19 iterations
# 12 items considered
# [ 71.  61.  35.]
# 20 iterations
# 13 items considered
# [ 68.  61.  16.]
# 21 iterations
# 13 items considered
# [ 67.  61.  24.]
# 22 iterations
# 14 items considered
# [ 66.  61.  23.]
# 23 iterations
# 14 items considered
# [ 60.  60.  14.]
# 2
# 3
# 4
# 5
# 24 iterations
# 11 items considered
# [ 55.  57.   3.]
# 25 iterations
# 11 items considered
# [ 66.  49.   3.]
# 6
# 7
# 26 iterations
# 10 items considered
# [ 74.  68.  10.]
# 8
# 9
# 10
# 27 iterations
# 7 items considered
# [ 86.  77.  10.]
# 11
# 28 iterations
# 7 items considered
# [ 89.  72.   3.]
# 12
# 29 iterations
# 6 items considered
# [ 90.  79.  31.]
# 30 iterations
# 7 items considered
# [ 90.  79.  26.]
# 13
# 31 iterations
# 6 items considered
# [ 102.   11.  110.]
# 32 iterations
# 7 items considered
# [  95.    3.  110.]
# 14
# 33 iterations
# 6 items considered
# [  95.   17.  110.]
# 34 iterations
# 7 items considered
# [ 92.  16.  89.]
# 35 iterations
# 7 items considered
# [ 96.  17.  81.]
# 36 iterations
# 8 items considered
# [ 93.  13.  55.]
# 37 iterations
# 8 items considered
# [  80.  102.   52.]
# 38 iterations
# 9 items considered
# [ 80.  89.  48.]
# 39 iterations
# 9 items considered
# [ 93.  85.  16.]
# 15
# 16
# 40 iterations
# 8 items considered
# [ 93.  85.  21.]
# 41 iterations
# 8 items considered
# [ 93.  98.  21.]
# 42 iterations
# 9 items considered
# [ 87.  92.   5.]
# 43 iterations
# 9 items considered
# [ 89.  96.   9.]
# 44 iterations
# 10 items considered
# [ 89.  96.   9.]
# 17
# 18
# 45 iterations
# 8 items considered
# [ 91.  91.  17.]
# 46 iterations
# 9 items considered
# [ 90.  91.  16.]
# 47 iterations
# 9 items considered
# [ 88.  89.  11.]
# 19
# 48 iterations
# 9 items considered
# [ 86.  95.  12.]
# 49 iterations
# 9 items considered
# [ 84.  95.   8.]
# 20
# 50 iterations
# 9 items considered
# [  72.  104.   25.]
# 51 iterations
# 9 items considered
# [ 74.  93.   3.]
# 21
# 52 iterations
# 9 items considered
# [  77.  106.    6.]
# 53 iterations
# 9 items considered
# [ 83.  98.  24.]
# 54 iterations
# 10 items considered
# [ 83.  98.  23.]
# 55 iterations
# 10 items considered
# [ 80.  95.  13.]
# 22
# 23
# 24
# 25
# 56 iterations
# 7 items considered
# [ 83.  99.  40.]
# 57 iterations
# 7 items considered
# [  85.  102.   46.]
# 58 iterations
# 8 items considered
# [ 80.  95.  46.]
# 59 iterations
# 8 items considered
# [ 79.  95.  33.]
# 26
# 60 iterations
# 8 items considered
# [ 75.  96.   3.]
# 61 iterations
# 8 items considered
# [  81.  102.   11.]
# 27
# 62 iterations
# 8 items considered
# [  83.  104.   21.]
# 63 iterations
# 8 items considered
# [  87.  108.   19.]
# 28
# 64 iterations
# 8 items considered
# [  91.  104.    3.]
# 65 iterations
# 8 items considered
# [ 92.  99.  17.]
# 66 iterations
# 9 items considered
# [ 89.  92.   2.]
# 29
# 67 iterations
# 8 items considered
# [ 77.  74.   1.]
# 30
# 68 iterations
# 8 items considered
# [ 75.  74.  11.]
# 31
# 69 iterations
# 7 items considered
# [  99.  100.   65.]
# 70 iterations
# 8 items considered
# [  98.  100.   64.]
# 71 iterations
# 8 items considered
# [ 89.  94.  77.]
# 72 iterations
# 9 items considered
# [ 89.  94.  75.]
# 73 iterations
# 9 items considered
# [ 83.  98.  82.]
# 74 iterations
# 10 items considered
# [ 51.  73.  54.]
# 75 iterations
# 10 items considered
# [ 50.  72.  47.]
# 76 iterations
# 11 items considered
# [ 48.  65.  29.]
# 77 iterations
# 11 items considered
# [ 78.  83.  39.]
# 78 iterations
# 12 items considered
# [ 68.  74.  16.]
# 79 iterations
# 12 items considered
# [ 78.  83.  15.]
# 32
# 33
# 34
# 80 iterations
# 10 items considered
# [ 86.  96.  19.]
# 81 iterations
# 10 items considered
# [ 81.  96.  27.]
# 82 iterations
# 11 items considered
# [ 75.  78.  14.]
# 83 iterations
# 11 items considered
# [ 72.  75.  25.]
# 84 iterations
# 12 items considered
# [ 71.  73.  14.]
# 85 iterations
# 12 items considered
# [ 70.  77.  24.]
# 86 iterations
# 13 items considered
# [ 68.  69.   8.]
# 87 iterations
# 13 items considered
# [ 69.  71.  11.]
# 88 iterations
# 14 items considered
# [ 57.  65.  10.]
# 89 iterations
# 14 items considered
# [ 55.  61.  23.]
# 35
# 36
# 90 iterations
# 13 items considered
# [ 63.  67.   9.]
# 91 iterations
# 13 items considered
# [ 63.  67.   9.]
# 37
# 38
# 92 iterations
# 12 items considered
# [ 74.  73.  28.]
# 93 iterations
# 12 items considered
# [ 69.  74.  30.]
# 94 iterations
# 13 items considered
# [ 64.  64.  19.]
# 95 iterations
# 13 items considered
# [ 37.  54.  27.]
# 96 iterations
# 14 items considered
# [ 36.  53.  24.]
# 39
# 97 iterations
# 13 items considered
# [ 41.  63.   9.]
# 40
# 98 iterations
# 13 items considered
# [ 42.  64.   0.]
# 41
# 42
# 99 iterations
# 11 items considered
# [ 37.  44.   6.]
# 43
# 100 iterations
# 11 items considered
# [ 42.  62.   2.]
# 101 iterations
# 11 items considered
# [ 41.  62.   0.]
# 44
# 45
# 46
# 102 iterations
# 9 items considered
# [ 64.  75.  19.]
# 103 iterations
# 9 items considered
# [ 66.  74.  20.]
# 104 iterations
# 10 items considered
# [ 64.  73.  10.]
# 105 iterations
# 10 items considered
# [ 62.  64.  17.]
# 106 iterations
# 11 items considered
# [ 62.  53.  17.]
# 107 iterations
# 11 items considered
# [ 61.  76.  80.]
# 108 iterations
# 12 items considered
# [ 59.  71.  57.]
# 109 iterations
# 12 items considered
# [ 51.  72.  36.]
# 110 iterations
# 13 items considered
# [ 28.  61.  36.]
# 111 iterations
# 13 items considered
# [ 34.  53.  19.]
# 112 iterations
# 14 items considered
# [ 34.  53.  11.]
# 113 iterations
# 14 items considered
# [ 57.  63.   8.]
# 47
# 48
# 114 iterations
# 13 items considered
# [ 64.  77.   0.]
# 115 iterations
# 13 items considered
# [ 63.  71.   9.]
# 116 iterations
# 14 items considered
# [ 63.  62.   7.]
# 49
# 117 iterations
# 13 items considered
# [ 65.  54.  12.]
# 118 iterations
# 14 items considered
# [ 46.  44.   5.]
# 50
# 119 iterations
# 13 items considered
# [ 46.  44.   7.]
# 120 iterations
# 14 items considered
# [ 46.  30.   7.]
# 51
# 52
# 53
# 54
# 121 iterations
# 10 items considered
# [ 66.  47.  20.]
# 55
# 56
# 57
# 122 iterations
# 8 items considered
# [ 89.  71.   9.]
# 123 iterations
# 8 items considered
# [ 80.  79.   0.]
# 58
# 124 iterations
# 8 items considered
# [ 84.  56.  41.]
# 125 iterations
# 8 items considered
# [ 84.  77.  56.]
# 126 iterations
# 9 items considered
# [ 77.  63.  52.]
# 127 iterations
# 9 items considered
# [ 78.  92.  49.]
# 128 iterations
# 10 items considered
# [ 75.  90.  40.]
# 129 iterations
# 10 items considered
# [ 77.  92.  49.]
# 130 iterations
# 11 items considered
# [ 76.  92.  47.]
# 131 iterations
# 11 items considered
# [ 73.  88.  31.]
# 132 iterations
# 12 items considered
# [ 68.  82.  30.]
# 133 iterations
# 12 items considered
# [ 65.  82.   8.]
# 59
# 60
# 134 iterations
# 11 items considered
# [ 70.  88.   9.]
# 135 iterations
# 11 items considered
# [ 66.  82.  11.]
# 61
# 62
# 136 iterations
# 10 items considered
# [ 75.  82.  35.]
# 137 iterations
# 10 items considered
# [ 62.  61.  45.]
# 138 iterations
# 11 items considered
# [ 61.  55.  38.]
# 139 iterations
# 11 items considered
# [ 70.  49.  38.]
# 140 iterations
# 12 items considered
# [ 61.  48.  12.]
# 141 iterations
# 12 items considered
# [ 61.  42.  12.]
# 142 iterations
# 13 items considered
# [ 49.  41.   9.]
# 63
# 64
# 65
# 66
# 143 iterations
# 9 items considered
# [ 68.  84.  25.]
# 144 iterations
# 10 items considered
# [ 64.  79.   7.]
# 145 iterations
# 10 items considered
# [ 68.  84.  22.]
# 146 iterations
# 11 items considered
# [ 54.  76.  21.]
# 147 iterations
# 11 items considered
# [ 32.  70.  16.]
# 67
# 148 iterations
# 11 items considered
# [ 32.  77.  17.]
# 149 iterations
# 11 items considered
# [ 40.  80.  43.]
# 150 iterations
# 12 items considered
# [ 38.  80.  33.]
# 151 iterations
# 12 items considered
# [ 33.  85.  19.]
# 152 iterations
# 13 items considered
# [ 32.  85.   6.]
# 68
# 153 iterations
# 12 items considered
# [ 31.  66.   6.]
# 69
# 70
# 154 iterations
# 11 items considered
# [ 31.  66.   9.]
# 155 iterations
# 11 items considered
# [ 32.  68.  22.]
# 156 iterations
# 12 items considered
# [ 30.  67.   9.]
# 157 iterations
# 12 items considered
# [ 34.  62.  34.]
# 158 iterations
# 13 items considered
# [ 33.  62.   9.]
# 71
# 72
# 159 iterations
# 11 items considered
# [ 59.  71.  13.]
# 160 iterations
# 12 items considered
# [ 57.  69.   6.]
# 161 iterations
# 12 items considered
# [ 59.  84.   0.]
# 73
# 74
# 162 iterations
# 11 items considered
# [ 63.  87.   8.]
# 75
# 76
# 163 iterations
# 9 items considered
# [ 54.  73.   6.]
# 77
# 164 iterations
# 9 items considered
# [ 54.  73.   6.]
# 165 iterations
# 9 items considered
# [ 58.  74.  25.]
# 78
# 166 iterations
# 9 items considered
# [ 58.  77.   1.]
# 167 iterations
# 9 items considered
# [ 64.  88.  27.]
# 168 iterations
# 10 items considered
# [ 64.  88.  25.]
# 169 iterations
# 10 items considered
# [ 58.  93.  11.]
# 170 iterations
# 11 items considered
# [ 58.  93.   7.]
# 171 iterations
# 11 items considered
# [ 48.  96.   7.]
# 79
# 80
# 81
# 172 iterations
# 9 items considered
# [ 56.  90.   7.]
# 173 iterations
# 9 items considered
# [ 57.  92.  12.]
# 82
# 174 iterations
# 9 items considered
# [ 66.  93.  14.]
# 175 iterations
# 9 items considered
# [ 64.  98.  36.]
# 176 iterations
# 10 items considered
# [ 64.  98.  35.]
# 177 iterations
# 10 items considered
# [ 62.  95.  26.]
# 178 iterations
# 11 items considered
# [ 55.  88.  13.]
# 179 iterations
# 11 items considered
# [ 52.  72.   8.]
# 83
# 84
# 180 iterations
# 10 items considered
# [ 53.  72.   8.]
# 85
# 86
# 181 iterations
# 8 items considered
# [ 57.  85.  11.]
# 87
# 182 iterations
# 8 items considered
# [  59.  100.   10.]
# 183 iterations
# 8 items considered
# [  79.  109.   21.]
# 184 iterations
# 9 items considered
# [  76.  101.    0.]
# 88
# 185 iterations
# 8 items considered
# [  94.  109.    9.]
# 186 iterations
# 9 items considered
# [  91.  109.    6.]
# 187 iterations
# 9 items considered
# [  91.  113.   39.]
# 89
# 90
# 188 iterations
# 8 items considered
# [  85.  113.    5.]
# 189 iterations
# 8 items considered
# [  86.  105.    9.]
# 91
# 190 iterations
# 8 items considered
# [  86.  113.    4.]
# 191 iterations
# 8 items considered
# [  81.  112.    1.]
# 192 iterations
# 9 items considered
# [ 81.  98.   1.]
# 193 iterations
# 9 items considered
# [ 87.  95.  25.]
# 194 iterations
# 10 items considered
# [ 84.  94.   4.]
# 195 iterations
# 10 items considered
# [ 87.  95.  25.]
# 196 iterations
# 11 items considered
# [ 86.  93.  18.]
# 197 iterations
# 11 items considered
# [ 94.  96.  95.]
# 198 iterations
# 12 items considered
# [ 94.  96.  87.]
# 199 iterations
# 13 items considered
# [ 94.  93.  83.]
# 200 iterations
# 13 items considered
# [ 96.  94.  93.]
# 201 iterations
# 14 items considered
# [ 73.  73.  93.]
# 202 iterations
# 14 items considered
# [ 67.  72.  67.]
# 203 iterations
# 15 items considered
# [ 67.  72.  65.]
# 204 iterations
# 15 items considered
# [ 75.  82.  37.]
# 205 iterations
# 16 items considered
# [ 74.  82.  15.]
# 206 iterations
# 16 items considered
# [ 88.  90.  30.]
# 207 iterations
# 17 items considered
# [ 85.  84.  11.]
# 208 iterations
# 17 items considered
# [ 87.  90.  17.]
# 92
# 93
# 209 iterations
# 16 items considered
# [ 86.  83.   9.]
# 94
# 95
# 210 iterations
# 14 items considered
# [ 97.  76.  19.]
# 211 iterations
# 15 items considered
# [ 96.  71.   1.]
# 212 iterations
# 15 items considered
# [ 77.  52.   8.]
# 96
# 97
# 98
# 99
# 213 iterations
# 12 items considered
# [ 78.  64.  15.]
# 100
# 101
# 214 iterations
# 10 items considered
# [ 98.  99.  15.]
# 215 iterations
# 11 items considered
# [ 98.  99.  15.]
# 216 iterations
# 11 items considered
# [ 93.  86.   7.]
# 217 iterations
# 12 items considered
# [ 70.  84.   7.]
# 218 iterations
# 12 items considered
# [ 74.  84.  36.]
# 219 iterations
# 13 items considered
# [ 70.  84.  21.]
# 220 iterations
# 13 items considered
# [ 83.  85.  20.]
# 102
# 221 iterations
# 13 items considered
# [ 83.  85.  20.]
# 222 iterations
# 13 items considered
# [ 77.  68.  29.]
# 103
# 223 iterations
# 13 items considered
# [ 79.  73.  31.]
# 224 iterations
# 13 items considered
# [ 78.  72.  23.]
# 104
# 105
# 106
# 225 iterations
# 11 items considered
# [ 75.  76.   9.]
# 226 iterations
# 11 items considered
# [ 77.  83.   3.]
# 227 iterations
# 12 items considered
# [ 77.  81.   2.]
# 107
# 228 iterations
# 11 items considered
# [  82.  100.   17.]
# 229 iterations
# 12 items considered
# [  82.  100.    8.]
# 230 iterations
# 12 items considered
# [  81.  103.   34.]
# 231 iterations
# 13 items considered
# [ 67.  92.  33.]
# 232 iterations
# 13 items considered
# [ 66.  83.  23.]
# 233 iterations
# 14 items considered
# [ 64.  78.   3.]
# 234 iterations
# 14 items considered
# [ 78.  83.   1.]
# 235 iterations
# 15 items considered
# [ 78.  69.   1.]
# 108
# 109
# 236 iterations
# 13 items considered
# [ 79.  71.   0.]
# 110
# 237 iterations
# 13 items considered
# [ 79.  73.   1.]
# 238 iterations
# 13 items considered
# [ 74.  59.  25.]
# 239 iterations
# 14 items considered
# [ 73.  52.  10.]
# 240 iterations
# 14 items considered
# [ 71.  40.  21.]
# 241 iterations
# 15 items considered
# [ 71.  38.  20.]
# 111
# 112
# 242 iterations
# 13 items considered
# [ 86.  38.  36.]
# 243 iterations
# 14 items considered
# [ 83.  22.  17.]
# 244 iterations
# 14 items considered
# [ 87.  25.  13.]
# 245 iterations
# 15 items considered
# [ 79.  16.  13.]
# 246 iterations
# 15 items considered
# [ 74.  13.  17.]
# 247 iterations
# 16 items considered
# [ 67.  11.   6.]
# 248 iterations
# 16 items considered
# [ 75.  20.   3.]
# 113
# 114
# 115
# 249 iterations
# 14 items considered
# [ 75.  34.  12.]
# 250 iterations
# 14 items considered
# [ 66.  28.  22.]
# 251 iterations
# 15 items considered
# [ 66.  28.  19.]
# 252 iterations
# 15 items considered
# [ 77.  34.  12.]
# 253 iterations
# 16 items considered
# [ 75.  24.  10.]
# 254 iterations
# 16 items considered
# [ 76.  24.   8.]
# 116
# 117
# 255 iterations
# 15 items considered
# [ 71.  34.  19.]
# 256 iterations
# 15 items considered
# [ 73.  30.  21.]
# 118
# 257 iterations
# 15 items considered
# [ 79.  30.  18.]
# 258 iterations
# 15 items considered
# [ 75.  35.  23.]
# 259 iterations
# 16 items considered
# [ 64.  34.  15.]
# 260 iterations
# 16 items considered
# [ 62.  24.   3.]
# 119
# 120
# 261 iterations
# 15 items considered
# [ 69.  45.   0.]
# 121
# 262 iterations
# 14 items considered
# [ 69.  45.   3.]
# 122
# 123
# 124
# 263 iterations
# 12 items considered
# [ 74.  74.   9.]
# 125
# 264 iterations
# 11 items considered
# [ 84.  81.   9.]
# 126
# 265 iterations
# 11 items considered
# [ 76.  68.   4.]
# 127
# 266 iterations
# 10 items considered
# [ 77.  81.  18.]
# 128
# 267 iterations
# 10 items considered
# [ 79.  82.  14.]
# 268 iterations
# 10 items considered
# [ 80.  82.  14.]
# 269 iterations
# 11 items considered
# [ 80.  82.  14.]
# 129
# 130
# 270 iterations
# 9 items considered
# [ 67.  93.  12.]
# 271 iterations
# 10 items considered
# [ 67.  87.   3.]
# 131
# 132
# 272 iterations
# 8 items considered
# [ 70.  91.  20.]
# 273 iterations
# 9 items considered
# [ 70.  91.   6.]
# 133
# 274 iterations
# 8 items considered
# [ 77.  93.  17.]
# 134
# 135
# 275 iterations
# 7 items considered
# [ 69.  71.  13.]
# 136
# 276 iterations
# 6 items considered
# [ 69.  73.  14.]
# 277 iterations
# 7 items considered
# [ 62.  60.   7.]
# 278 iterations
# 7 items considered
# [ 66.  67.  14.]
# 279 iterations
# 8 items considered
# [ 64.  61.   9.]
# 280 iterations
# 8 items considered
# [ 71.  74.   6.]
# 281 iterations
# 9 items considered
# [ 49.  70.   6.]
# 137
# 282 iterations
# 8 items considered
# [ 71.  74.   6.]
# 138
# 283 iterations
# 8 items considered
# [ 71.  72.   5.]
# 284 iterations
# 8 items considered
# [ 68.  85.  11.]
# 139
# 285 iterations
# 8 items considered
# [ 68.  85.   6.]
# 140
# 286 iterations
# 7 items considered
# [  80.  113.   36.]
# 287 iterations
# 8 items considered
# [  79.  113.    3.]
# 288 iterations
# 8 items considered
# [  95.  104.   19.]
# 141
# 289 iterations
# 8 items considered
# [  95.  104.   12.]
# 290 iterations
# 8 items considered
# [  96.  104.   21.]
# 291 iterations
# 9 items considered
# [  95.  104.   18.]
# 292 iterations
# 9 items considered
# [  92.  117.   45.]
# 293 iterations
# 10 items considered
# [  90.  117.   41.]
# 294 iterations
# 10 items considered
# [  91.  118.   70.]
# 295 iterations
# 11 items considered
# [  89.  110.   39.]
# 296 iterations
# 11 items considered
# [  73.  104.   12.]
# 297 iterations
# 12 items considered
# [  73.  104.    7.]
# 142
# 143
# 144
# 298 iterations
# 9 items considered
# [ 90.  88.  24.]
# 299 iterations
# 10 items considered
# [ 69.  57.  15.]
# 145
# 146
# 300 iterations
# 8 items considered
# [ 88.  81.   5.]
# 147
# 301 iterations
# 8 items considered
# [ 86.  81.  13.]
# 148
# 302 iterations
# 7 items considered
# [ 92.  85.   2.]
# 149
# 303 iterations
# 7 items considered
# [ 96.  89.   7.]
# 304 iterations
# 7 items considered
# [ 86.  71.   9.]
# 150
# 151
# 305 iterations
# 6 items considered
# [ 106.  111.   44.]
# 306 iterations
# 6 items considered
# [ 105.  108.   20.]
# 307 iterations
# 7 items considered
# [ 105.   95.   20.]
# 308 iterations
# 7 items considered
# [ 106.   89.   11.]
# 309 iterations
# 8 items considered
# [ 92.  88.   9.]
# 310 iterations
# 8 items considered
# [ 92.  84.  15.]
# 152
# 311 iterations
# 8 items considered
# [ 76.  67.  12.]
# 312 iterations
# 8 items considered
# [ 71.  70.  41.]
# 313 iterations
# 9 items considered
# [ 71.  68.  40.]
# 314 iterations
# 9 items considered
# [ 86.  82.  61.]
# 315 iterations
# 10 items considered
# [ 79.  74.  42.]
# 316 iterations
# 10 items considered
# [ 78.  63.  49.]
# 317 iterations
# 11 items considered
# [ 78.  62.  18.]
# 318 iterations
# 11 items considered
# [ 81.  59.  19.]
# 319 iterations
# 12 items considered
# [ 79.  59.   0.]
# 320 iterations
# 12 items considered
# [ 80.  73.   6.]
# 321 iterations
# 13 items considered
# [ 79.  73.   0.]
# 153
# 154
# 322 iterations
# 11 items considered
# [ 87.  83.   7.]
# 155
# 323 iterations
# 11 items considered
# [ 90.  85.  10.]
# 324 iterations
# 11 items considered
# [ 84.  77.  40.]
# 325 iterations
# 12 items considered
# [ 80.  77.  28.]
# 326 iterations
# 12 items considered
# [ 74.  75.   5.]
# 156
# 327 iterations
# 12 items considered
# [ 73.  75.   2.]
# 328 iterations
# 12 items considered
# [ 67.  56.  15.]
# 329 iterations
# 13 items considered
# [ 63.  40.  13.]
# 330 iterations
# 13 items considered
# [ 65.  48.  12.]
# 331 iterations
# 14 items considered
# [ 64.  45.   2.]
# 157
# 158
# 159
# 332 iterations
# 11 items considered
# [ 66.  64.  20.]
# 160
# 161
# 333 iterations
# 10 items considered
# [ 80.  65.  22.]
# 334 iterations
# 10 items considered
# [ 89.  63.  45.]
# 335 iterations
# 11 items considered
# [ 60.  46.  45.]
# 336 iterations
# 11 items considered
# [ 53.  39.  17.]
# 162
# 163
# 337 iterations
# 10 items considered
# [ 78.  61.   1.]
# 338 iterations
# 10 items considered
# [ 84.  61.  16.]
# 339 iterations
# 11 items considered
# [ 77.  45.   8.]
# 164
# 165
# 340 iterations
# 9 items considered
# [ 83.  57.   8.]
# 166
# 341 iterations
# 9 items considered
# [ 88.  58.   0.]
# 167
# 342 iterations
# 8 items considered
# [ 95.  82.  12.]
# 343 iterations
# 9 items considered
# [ 89.  68.   4.]
# 344 iterations
# 9 items considered
# [ 95.  74.  11.]
# 345 iterations
# 10 items considered
# [ 89.  61.   6.]
# 346 iterations
# 10 items considered
# [ 74.  25.  31.]
# 347 iterations
# 11 items considered
# [ 59.  25.   9.]
# 168
# 348 iterations
# 10 items considered
# [ 69.  48.   3.]
# 169
# 170
# 349 iterations
# 9 items considered
# [ 68.  53.  33.]
# 350 iterations
# 9 items considered
# [ 66.  66.   2.]
# 171
# 351 iterations
# 9 items considered
# [ 72.  62.  17.]
# 352 iterations
# 9 items considered
# [ 71.  58.   6.]
# 172
# 353 iterations
# 9 items considered
# [ 71.  58.   6.]
# 173
# 174
# 354 iterations
# 7 items considered
# [  95.  102.   19.]
# 175
# 355 iterations
# 7 items considered
# [  95.  105.   20.]
# 356 iterations
# 7 items considered
# [  96.  109.   41.]
# 357 iterations
# 8 items considered
# [ 93.  98.  11.]
# 358 iterations
# 8 items considered
# [ 90.  96.   9.]
# 359 iterations
# 9 items considered
# [ 90.  93.   8.]
# 360 iterations
# 9 items considered
# [  92.  104.   10.]
# 176
# 177
# 178
# 361 iterations
# 7 items considered
# [ 103.   95.   18.]
# 362 iterations
# 7 items considered
# [ 105.  107.   37.]
# 363 iterations
# 8 items considered
# [  92.  105.   36.]
# 364 iterations
# 8 items considered
# [  96.  107.   75.]
# 365 iterations
# 9 items considered
# [  94.  105.   52.]
# 366 iterations
# 9 items considered
# [  95.  111.   59.]
# 367 iterations
# 10 items considered
# [  93.  103.   58.]
# 368 iterations
# 10 items considered
# [  94.  107.   44.]
# 369 iterations
# 11 items considered
# [ 89.  93.  35.]
# 370 iterations
# 11 items considered
# [ 102.   95.    3.]
# 179
# 180
# 371 iterations
# 10 items considered
# [ 104.  102.    7.]
# 181
# 182
# 372 iterations
# 8 items considered
# [ 109.  116.   26.]
# 373 iterations
# 9 items considered
# [  96.  109.   26.]
# 374 iterations
# 9 items considered
# [  96.  112.   24.]
# 375 iterations
# 10 items considered
# [  95.  112.   24.]
# 376 iterations
# 10 items considered
# [  94.  112.   49.]
# 377 iterations
# 11 items considered
# [  92.  110.   27.]
# 378 iterations
# 11 items considered
# [ 90.  99.  26.]
# 379 iterations
# 12 items considered
# [ 84.  99.   5.]
# 380 iterations
# 12 items considered
# [  83.  110.   21.]
# 183
# 184
# 381 iterations
# 11 items considered
# [  84.  110.    0.]
# 382 iterations
# 11 items considered
# [  87.  112.    9.]
# 383 iterations
# 12 items considered
# [  83.  106.    9.]
# 384 iterations
# 12 items considered
# [ 76.  85.   5.]
# 185
# 186
# 385 iterations
# 11 items considered
# [ 77.  85.  26.]
# 386 iterations
# 11 items considered
# [  83.  106.   12.]
# 187
# 387 iterations
# 11 items considered
# [  83.  106.   12.]
# 388 iterations
# 11 items considered
# [  87.  111.    7.]
# 188
# 389 iterations
# 11 items considered
# [ 82.  98.  32.]
# 390 iterations
# 11 items considered
# [ 84.  98.  50.]
# 391 iterations
# 12 items considered
# [ 82.  85.  26.]
# 392 iterations
# 12 items considered
# [ 83.  85.  24.]
# 189
# 190
# 393 iterations
# 11 items considered
# [ 75.  80.  13.]
# 191
# 192
# 394 iterations
# 9 items considered
# [ 82.  90.  20.]
# 193
# 194
# 395 iterations
# 8 items considered
# [ 83.  90.  23.]
# 195
# 196
# 396 iterations
# 6 items considered
# [  86.  103.   19.]
# 397 iterations
# 7 items considered
# [  86.  103.    2.]
# 398 iterations
# 7 items considered
# [ 80.  96.  36.]
# 399 iterations
# 8 items considered
# [ 79.  88.  20.]
# 400 iterations
# 8 items considered
# [  80.   86.  103.]
# 401 iterations
# 9 items considered
# [  80.   86.  103.]
# 402 iterations
# 10 items considered
# [ 77.  85.  90.]
# 403 iterations
# 11 items considered
# [ 76.  85.  86.]
# 404 iterations
# 11 items considered
# [ 78.  84.  88.]
# 405 iterations
# 12 items considered
# [ 77.  76.  76.]
# 406 iterations
# 12 items considered
# [ 80.  89.  50.]
# 407 iterations
# 13 items considered
# [ 62.  89.  44.]
# 408 iterations
# 13 items considered
# [ 70.  90.  43.]
# 409 iterations
# 14 items considered
# [ 69.  86.  22.]
# 197
# 410 iterations
# 13 items considered
# [ 83.  75.   4.]
# 198
# 199
# 411 iterations
# 12 items considered
# [ 78.  77.  11.]
# 412 iterations
# 12 items considered
# [ 77.  77.  16.]
# 200
# 413 iterations
# 12 items considered
# [ 75.  70.  18.]
# 414 iterations
# 12 items considered
# [ 76.  70.  29.]
# 415 iterations
# 13 items considered
# [ 76.  70.  27.]
# 416 iterations
# 13 items considered
# [ 78.  77.  45.]
# 417 iterations
# 14 items considered
# [ 73.  69.  33.]
# 418 iterations
# 14 items considered
# [ 73.  64.  30.]
# 419 iterations
# 15 items considered
# [ 73.  63.  27.]
# 420 iterations
# 15 items considered
# [ 72.  60.  12.]
# 421 iterations
# 16 items considered
# [ 70.  59.   0.]
# 422 iterations
# 16 items considered
# [ 71.  57.   2.]
# 201
# 423 iterations
# 16 items considered
# [ 72.  60.  19.]
# 424 iterations
# 16 items considered
# [ 72.  63.  23.]
# 425 iterations
# 17 items considered
# [ 71.  57.   7.]
# 426 iterations
# 17 items considered
# [ 51.  40.  23.]
# 427 iterations
# 18 items considered
# [ 48.  28.  11.]
# 202
# 428 iterations
# 17 items considered
# [ 49.  37.  10.]
# 429 iterations
# 18 items considered
# [ 47.  37.   6.]
# 203
# 204
# 430 iterations
# 16 items considered
# [ 77.  57.  14.]
# 431 iterations
# 17 items considered
# [ 77.  57.  14.]
# 432 iterations
# 17 items considered
# [ 66.  56.  24.]
# 433 iterations
# 18 items considered
# [ 66.  50.   2.]
# 205
# 434 iterations
# 17 items considered
# [ 72.  54.   0.]
# 206
# 207
# 435 iterations
# 16 items considered
# [ 78.  59.  19.]
# 436 iterations
# 16 items considered
# [ 82.  71.  43.]
# 437 iterations
# 17 items considered
# [ 77.  57.  25.]
# 438 iterations
# 17 items considered
# [ 77.  57.   7.]
# 208
# 209
# 439 iterations
# 16 items considered
# [ 83.  59.   0.]
# 210
# 211
# 440 iterations
# 14 items considered
# [ 76.  48.   3.]
# 212
# 213
# 441 iterations
# 13 items considered
# [ 90.  59.   4.]
# 442 iterations
# 13 items considered
# [ 89.  58.   4.]
# 214
# 443 iterations
# 13 items considered
# [ 81.  58.   3.]
# 215
# 444 iterations
# 12 items considered
# [ 84.  57.  19.]
# 216
# 445 iterations
# 12 items considered
# [ 82.  54.  11.]
# 446 iterations
# 12 items considered
# [ 83.  63.  12.]
# 217
# 447 iterations
# 12 items considered
# [ 79.  69.   8.]
# 448 iterations
# 12 items considered
# [ 80.  81.   2.]
# 218
# 219
# 449 iterations
# 11 items considered
# [ 81.  84.  18.]
# 450 iterations
# 11 items considered
# [ 77.  79.  19.]
# 451 iterations
# 12 items considered
# [ 56.  55.  19.]
# 452 iterations
# 12 items considered
# [ 43.  53.  21.]
# 220
# 453 iterations
# 12 items considered
# [ 47.  49.  15.]
# 454 iterations
# 12 items considered
# [ 49.  31.  16.]
# 455 iterations
# 13 items considered
# [ 47.  31.  13.]
# 221
# 222
# 456 iterations
# 11 items considered
# [ 47.  36.  10.]
# 223
# 224
# 225
# 226
# 457 iterations
# 8 items considered
# [ 60.  70.  21.]
# 458 iterations
# 8 items considered
# [ 62.  71.  46.]
# 459 iterations
# 9 items considered
# [ 62.  71.  45.]
# 460 iterations
# 9 items considered
# [ 62.  71.  29.]
# 461 iterations
# 10 items considered
# [ 37.  66.  29.]
# 462 iterations
# 10 items considered
# [ 29.  66.  41.]
# 463 iterations
# 11 items considered
# [ 26.  52.  18.]
# 464 iterations
# 11 items considered
# [ 49.  57.  13.]
# 465 iterations
# 12 items considered
# [ 49.  57.   2.]
# 466 iterations
# 12 items considered
# [ 53.  51.   8.]
# 467 iterations
# 13 items considered
# [ 46.  36.   0.]
# 468 iterations
# 13 items considered
# [ 45.  34.   5.]
# 469 iterations
# 14 items considered
# [ 36.   7.   3.]
# 470 iterations
# 14 items considered
# [ 38.  11.   6.]
# 227
# 471 iterations
# 14 items considered
# [ 34.  13.   4.]
# 472 iterations
# 14 items considered
# [ 41.  30.  21.]
# 473 iterations
# 15 items considered
# [ 37.  21.   8.]
# 228
# 229
# 474 iterations
# 13 items considered
# [ 54.  47.  11.]
# 230
# 231
# 232
# 475 iterations
# 11 items considered
# [ 56.  31.  23.]
# 476 iterations
# 11 items considered
# [ 50.  33.  60.]
# 477 iterations
# 12 items considered
# [ 45.  22.  28.]
# 478 iterations
# 12 items considered
# [ 47.  10.  10.]
# 479 iterations
# 13 items considered
# [ 47.  10.   7.]
# 233
# 234
# 235
# 236
# 480 iterations
# 9 items considered
# [ 82.  53.  28.]
# 481 iterations
# 10 items considered
# [ 82.  53.  27.]
# 237
# 238
# 482 iterations
# 8 items considered
# [ 90.  67.  41.]
# 483 iterations
# 9 items considered
# [ 90.  67.   1.]
# 484 iterations
# 9 items considered
# [ 83.  58.  22.]
# 485 iterations
# 10 items considered
# [ 83.  58.  20.]
# 486 iterations
# 10 items considered
# [ 82.  52.  20.]
# 239
# 240
# 487 iterations
# 9 items considered
# [ 73.  74.  54.]
# 488 iterations
# 9 items considered
# [ 66.  65.  94.]
# 489 iterations
# 10 items considered
# [ 61.  64.  47.]
# 490 iterations
# 11 items considered
# [ 61.  64.  38.]
# 491 iterations
# 11 items considered
# [ 58.  63.  23.]
# 241
# 242
# 492 iterations
# 10 items considered
# [ 63.  61.   0.]
# 243
# 244
# 493 iterations
# 8 items considered
# [ 53.  50.  46.]
# 494 iterations
# 9 items considered
# [ 41.  50.  46.]
# 495 iterations
# 9 items considered
# [ 42.  44.  58.]
# 496 iterations
# 10 items considered
# [ 41.  43.  53.]
# 497 iterations
# 10 items considered
# [  63.   63.  112.]
# 498 iterations
# 11 items considered
# [ 63.  63.  69.]
# 499 iterations
# 11 items considered
# [ 68.  65.  52.]
# 500 iterations
# 12 items considered
# [ 67.  56.  38.]
# 501 iterations
# 12 items considered
# [ 74.  65.  29.]
# 245
# 246
# 502 iterations
# 11 items considered
# [ 70.  72.  12.]
# 503 iterations
# 11 items considered
# [ 73.  69.  24.]
# 504 iterations
# 12 items considered
# [ 73.  55.  24.]
# 505 iterations
# 12 items considered
# [ 74.  58.  13.]
# 247
# 248
# 506 iterations
# 11 items considered
# [ 74.  72.  13.]
# 249
# 250
# 507 iterations
# 9 items considered
# [ 82.  88.   6.]
# 251
# 252
# 508 iterations
# 8 items considered
# [  86.  103.    5.]
# 509 iterations
# 8 items considered
# [  88.  106.   14.]
# 253
# 510 iterations
# 8 items considered
# [ 74.  99.  16.]
# 511 iterations
# 8 items considered
# [ 74.  99.  48.]
# 512 iterations
# 9 items considered
# [ 67.  99.  36.]
# 513 iterations
# 9 items considered
# [ 74.  96.  92.]
# 514 iterations
# 10 items considered
# [ 74.  96.  46.]
# 515 iterations
# 10 items considered
# [ 81.  95.  57.]
# 516 iterations
# 11 items considered
# [ 81.  95.  53.]
# 517 iterations
# 11 items considered
# [ 80.  93.  52.]
# 518 iterations
# 12 items considered
# [ 77.  87.  32.]
# 519 iterations
# 12 items considered
# [ 78.  75.  40.]
# 520 iterations
# 13 items considered
# [ 71.  73.  28.]
# 521 iterations
# 13 items considered
# [ 70.  71.  19.]
# 254
# 255
# 256
# 522 iterations
# 11 items considered
# [ 77.  97.  10.]
# 523 iterations
# 11 items considered
# [ 76.  91.   2.]
# 257
# 258
# 259
# 524 iterations
# 9 items considered
# [  81.  103.    7.]
# 525 iterations
# 9 items considered
# [  83.  103.    8.]
# 260
# 526 iterations
# 9 items considered
# [  83.  103.    8.]
# 261
# 527 iterations
# 8 items considered
# [  82.  107.   14.]
# 262
# 263
# 528 iterations
# 7 items considered
# [  72.  101.   45.]
# 529 iterations
# 7 items considered
# [ 68.  97.  46.]
# 530 iterations
# 8 items considered
# [ 67.  97.  39.]
# 531 iterations
# 8 items considered
# [  70.  103.   25.]
# 532 iterations
# 9 items considered
# [  70.  103.   10.]
# 533 iterations
# 9 items considered
# [  83.  112.   10.]
# 264
# 534 iterations
# 9 items considered
# [  93.  111.   10.]
# 535 iterations
# 9 items considered
# [  93.  111.   15.]
# 265
# 536 iterations
# 9 items considered
# [ 92.  96.   3.]
# 537 iterations
# 9 items considered
# [ 92.  79.   9.]
# 266
# 538 iterations
# 9 items considered
# [ 90.  71.   9.]
# 539 iterations
# 9 items considered
# [ 92.  79.  36.]
# 540 iterations
# 10 items considered
# [ 90.  72.  15.]
# 541 iterations
# 10 items considered
# [ 91.  73.  18.]
# 267
# 542 iterations
# 10 items considered
# [ 92.  84.  36.]
# 268
# 543 iterations
# 9 items considered
# [ 85.  90.   5.]
# 269
# 544 iterations
# 9 items considered
# [ 84.  80.  24.]
# 545 iterations
# 9 items considered
# [ 83.  75.  45.]
# 546 iterations
# 10 items considered
# [ 73.  75.  44.]
# 547 iterations
# 10 items considered
# [ 75.  78.  38.]
# 548 iterations
# 11 items considered
# [ 68.  78.  37.]
# 549 iterations
# 11 items considered
# [ 57.  80.  34.]
# 550 iterations
# 12 items considered
# [ 47.  80.  27.]
# 551 iterations
# 12 items considered
# [ 53.  72.  74.]
# 552 iterations
# 13 items considered
# [ 53.  72.  54.]
# 553 iterations
# 13 items considered
# [ 58.  84.  48.]
# 554 iterations
# 14 items considered
# [ 56.  84.  43.]
# 555 iterations
# 14 items considered
# [ 52.  66.  76.]
# 556 iterations
# 15 items considered
# [ 52.  66.  56.]
# 557 iterations
# 15 items considered
# [ 65.  61.  74.]
# 558 iterations
# 16 items considered
# [ 63.  61.  57.]
# 559 iterations
# 16 items considered
# [ 63.  65.  37.]
# 560 iterations
# 17 items considered
# [ 60.  52.  10.]
# 561 iterations
# 17 items considered
# [ 57.  46.  11.]
# 270
# 271
# 272
# 273
# 274
# 275
# 562 iterations
# 12 items considered
# [ 80.  33.  15.]
# 563 iterations
# 12 items considered
# [ 78.  34.  17.]
# 564 iterations
# 13 items considered
# [ 76.  28.   1.]
# 276
# 277
# 278
# 565 iterations
# 10 items considered
# [ 75.  20.  11.]
# 279
# 566 iterations
# 10 items considered
# [ 73.  44.  31.]
# 567 iterations
# 10 items considered
# [ 76.  50.  49.]
# 568 iterations
# 11 items considered
# [ 73.  43.  28.]
# 569 iterations
# 11 items considered
# [ 67.  53.   1.]
# 280
# 281
# 570 iterations
# 10 items considered
# [ 80.  69.   7.]
# 282
# 571 iterations
# 9 items considered
# [ 83.  81.  26.]
# 572 iterations
# 10 items considered
# [ 78.  74.  26.]
# 573 iterations
# 10 items considered
# [ 55.  73.  47.]
# 574 iterations
# 11 items considered
# [ 54.  73.  42.]
# 575 iterations
# 11 items considered
# [ 61.  72.  70.]
# 576 iterations
# 12 items considered
# [ 61.  72.  64.]
# 577 iterations
# 12 items considered
# [ 81.  78.  38.]
# 578 iterations
# 13 items considered
# [ 79.  74.   5.]
# 283
# 284
# 285
# 579 iterations
# 10 items considered
# [ 94.  82.   0.]
# 286
# 580 iterations
# 10 items considered
# [ 95.  88.  18.]
# 581 iterations
# 10 items considered
# [ 93.  81.   7.]
# 582 iterations
# 11 items considered
# [ 93.  81.   0.]
# 583 iterations
# 11 items considered
# [ 101.   83.   49.]
# 584 iterations
# 12 items considered
# [ 95.  68.  42.]
# 585 iterations
# 12 items considered
# [ 95.  66.  30.]
# 586 iterations
# 13 items considered
# [ 95.  52.  30.]
# 587 iterations
# 13 items considered
# [ 95.  54.  45.]
# 588 iterations
# 14 items considered
# [ 92.  34.  41.]
# 589 iterations
# 14 items considered
# [ 92.  34.  47.]
# 590 iterations
# 15 items considered
# [ 63.  29.  47.]
# 591 iterations
# 15 items considered
# [ 64.  28.  47.]
# 592 iterations
# 16 items considered
# [ 39.  28.  47.]
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 593 iterations
# 9 items considered
# [ 72.  99.  20.]
# 594 iterations
# 10 items considered
# [ 62.  97.  11.]
# 595 iterations
# 10 items considered
# [ 63.  96.  27.]
# 596 iterations
# 11 items considered
# [ 62.  92.  18.]
# 294
# 597 iterations
# 10 items considered
# [ 64.  75.   2.]
# 295
# 598 iterations
# 10 items considered
# [ 64.  75.   2.]
# 599 iterations
# 10 items considered
# [ 88.  72.   0.]
# 296
# 297
# 298
# 299
# 300
# 600 iterations
# 6 items considered
# [ 89.  87.  11.]
# 601 iterations
# 6 items considered
# [ 93.  80.  19.]
# 301
# 602 iterations
# 6 items considered
# [ 93.  85.  14.]
# 603 iterations
# 6 items considered
# [ 88.  74.  13.]
# 302
# 604 iterations
# 6 items considered
# [ 88.  74.  13.]
# 303
# 304
# 605 iterations
# 4 items considered
# [ 100.   79.   56.]
# 606 iterations
# 5 items considered
# [ 99.  78.  32.]
# 607 iterations
# 5 items considered
# [ 97.  78.  43.]
# 608 iterations
# 6 items considered
# [ 94.  76.  18.]
# 609 iterations
# 6 items considered
# [ 94.  71.  16.]
# 305
# 610 iterations
# 6 items considered
# [ 95.  75.  25.]
# 611 iterations
# 6 items considered
# [ 95.  82.  20.]
# 612 iterations
# 7 items considered
# [ 92.  65.  11.]
# 613 iterations
# 7 items considered
# [ 88.  60.  15.]
# 614 iterations
# 8 items considered
# [ 82.  46.  12.]
# 615 iterations
# 8 items considered
# [ 66.  50.  12.]
# 616 iterations
# 9 items considered
# [ 62.  46.   7.]
# 617 iterations
# 9 items considered
# [ 63.  51.  31.]
# 618 iterations
# 10 items considered
# [ 63.  51.   1.]
# 306
# 619 iterations
# 9 items considered
# [ 67.  60.   1.]
# 620 iterations
# 10 items considered
# [ 67.  52.   0.]
# 621 iterations
# 10 items considered
# [ 49.  53.  28.]
# 622 iterations
# 11 items considered
# [ 48.  53.  25.]
# 623 iterations
# 11 items considered
# [ 46.  46.  38.]
# 624 iterations
# 12 items considered
# [ 43.  26.  14.]
# 307
# 308
# 625 iterations
# 10 items considered
# [ 46.  33.  34.]
# 626 iterations
# 11 items considered
# [ 28.  18.   1.]
# 309
# 627 iterations
# 10 items considered
# [ 20.  59.  37.]
# 628 iterations
# 11 items considered
# [ 17.  54.  18.]
# 629 iterations
# 11 items considered
# [  7.  53.  10.]
# 310
# 311
# 630 iterations
# 10 items considered
# [  7.  64.  19.]
# 631 iterations
# 10 items considered
# [ 25.  65.  39.]
# 632 iterations
# 11 items considered
# [ 21.  48.  11.]
# 633 iterations
# 11 items considered
# [ 26.  52.  18.]
# 312
# 313
# 314
# 634 iterations
# 9 items considered
# [ 33.  62.   9.]
# 635 iterations
# 9 items considered
# [ 32.  62.  10.]
# 315
# 316
# 636 iterations
# 8 items considered
# [ 58.  64.  15.]
# 637 iterations
# 8 items considered
# [ 61.  81.   7.]
# 638 iterations
# 9 items considered
# [ 59.  72.   6.]
# 639 iterations
# 9 items considered
# [ 53.  65.  38.]
# 640 iterations
# 10 items considered
# [ 48.  65.  27.]
# 317
# 641 iterations
# 9 items considered
# [ 46.  72.  30.]
# 642 iterations
# 10 items considered
# [ 45.  63.  25.]
# 643 iterations
# 10 items considered
# [ 44.  61.  22.]
# 644 iterations
# 11 items considered
# [ 43.  49.   7.]
# 645 iterations
# 11 items considered
# [ 37.  39.   4.]
# 646 iterations
# 12 items considered
# [ 32.  33.   4.]
# 318
# 647 iterations
# 11 items considered
# [ 67.  39.  21.]
# 319
# 648 iterations
# 11 items considered
# [ 55.  33.   3.]
# 649 iterations
# 11 items considered
# [ 58.  42.  15.]
# 320
# 650 iterations
# 11 items considered
# [ 71.  63.  23.]
# 321
# 322
# 323
# 651 iterations
# 8 items considered
# [ 65.  85.  16.]
# 324
# 652 iterations
# 8 items considered
# [ 68.  85.   9.]
# 325
# 653 iterations
# 7 items considered
# [ 68.  85.  13.]
# 326
# 654 iterations
# 7 items considered
# [ 73.  84.  76.]
# 655 iterations
# 7 items considered
# [ 77.  86.  62.]
# 656 iterations
# 8 items considered
# [ 71.  85.  40.]
# 657 iterations
# 8 items considered
# [ 73.  84.  53.]
# 658 iterations
# 9 items considered
# [ 72.  84.  50.]
# 659 iterations
# 9 items considered
# [ 73.  91.  65.]
# 660 iterations
# 10 items considered
# [ 72.  91.  52.]
# 661 iterations
# 10 items considered
# [ 74.  90.  52.]
# 662 iterations
# 11 items considered
# [ 72.  82.  33.]
# 327
# 663 iterations
# 10 items considered
# [ 81.  99.   2.]
# 328
# 664 iterations
# 10 items considered
# [  83.  107.    7.]
# 665 iterations
# 10 items considered
# [  82.  108.   18.]
# 329
# 666 iterations
# 10 items considered
# [  89.  109.   50.]
# 667 iterations
# 10 items considered
# [  79.  114.   46.]
# 330
# 331
# 332
# 333
# 668 iterations
# 7 items considered
# [  98.  121.   11.]
# 669 iterations
# 7 items considered
# [  99.  121.    7.]
# 670 iterations
# 8 items considered
# [  89.  115.    1.]
# 671 iterations
# 8 items considered
# [  88.  101.    4.]
# 334
# 672 iterations
# 8 items considered
# [ 86.  91.   1.]
# 335
# 673 iterations
# 7 items considered
# [ 96.  97.   7.]
# 336
# 337
# 338
# 674 iterations
# 5 items considered
# [ 105.  114.    3.]
# 675 iterations
# 5 items considered
# [ 105.  123.   73.]
# 676 iterations
# 6 items considered
# [  98.  117.   73.]
# 677 iterations
# 6 items considered
# [  74.  117.   18.]
# 678 iterations
# 7 items considered
# [  65.  109.   17.]
# 339
# 679 iterations
# 6 items considered
# [  97.  115.   45.]
# 680 iterations
# 7 items considered
# [  95.  108.    7.]
# 681 iterations
# 7 items considered
# [  97.  105.   56.]
# 682 iterations
# 8 items considered
# [ 96.  98.  40.]
# 683 iterations
# 8 items considered
# [  97.  101.   11.]
# 684 iterations
# 9 items considered
# [  97.  101.    1.]
# 340
# 685 iterations
# 8 items considered
# [ 97.  98.  27.]
# 686 iterations
# 9 items considered
# [ 97.  98.  17.]
# 341
# 687 iterations
# 8 items considered
# [  96.  104.   28.]
# 688 iterations
# 9 items considered
# [  96.  104.    9.]
# 689 iterations
# 9 items considered
# [  98.  111.   45.]
# 690 iterations
# 10 items considered
# [  88.  111.   20.]
# 691 iterations
# 10 items considered
# [  98.  113.   25.]
# 692 iterations
# 11 items considered
# [  87.  110.    0.]
# 693 iterations
# 11 items considered
# [  86.  110.    5.]
# 694 iterations
# 12 items considered
# [  86.  110.    2.]
# 695 iterations
# 12 items considered
# [  94.  103.    7.]
# 342
# 343
# 344
# 696 iterations
# 10 items considered
# [  91.  105.    0.]
# 345
# 697 iterations
# 9 items considered
# [  91.  105.   15.]
# 698 iterations
# 10 items considered
# [  88.  101.    5.]
# 699 iterations
# 10 items considered
# [ 86.  92.   0.]
# 346
# 347
# 700 iterations
# 9 items considered
# [ 94.  94.   2.]
# 701 iterations
# 9 items considered
# [ 88.  88.   6.]
# 348
# 702 iterations
# 9 items considered
# [ 88.  88.   6.]
# 703 iterations
# 9 items considered
# [ 93.  88.  48.]
# 704 iterations
# 10 items considered
# [ 92.  88.  20.]
# 705 iterations
# 10 items considered
# [ 92.  72.   7.]
# 349
# 706 iterations
# 10 items considered
# [ 90.  68.   2.]
# 707 iterations
# 10 items considered
# [ 91.  63.   8.]
# 708 iterations
# 11 items considered
# [ 83.  61.   5.]
# 350
# 709 iterations
# 10 items considered
# [ 79.  72.  15.]
# 710 iterations
# 11 items considered
# [ 76.  68.   6.]
# 351
# 711 iterations
# 10 items considered
# [ 64.  73.  15.]
# 352
# 712 iterations
# 10 items considered
# [ 64.  73.  15.]
# 713 iterations
# 10 items considered
# [ 70.  79.  29.]
# 714 iterations
# 11 items considered
# [ 69.  79.  26.]
# 715 iterations
# 11 items considered
# [ 70.  68.  12.]
# 353
# 354
# 355
# 716 iterations
# 9 items considered
# [ 68.  92.  10.]
# 356
# 357
# 717 iterations
# 7 items considered
# [  97.  120.   29.]
# 718 iterations
# 8 items considered
# [  94.  103.   10.]
# 719 iterations
# 8 items considered
# [  87.  113.    9.]
# 720 iterations
# 9 items considered
# [  87.  113.    7.]
# 721 iterations
# 9 items considered
# [  90.  114.   12.]
# 722 iterations
# 10 items considered
# [ 83.  90.   3.]
# 358
# 723 iterations
# 9 items considered
# [ 76.  73.   1.]
# 359
# 724 iterations
# 9 items considered
# [ 71.  61.  12.]
# 360
# 361
# 362
# 725 iterations
# 6 items considered
# [ 58.  91.   0.]
# 363
# 364
# 726 iterations
# 5 items considered
# [ 64.  92.  42.]
# 727 iterations
# 5 items considered
# [ 93.  97.  56.]
# 728 iterations
# 6 items considered
# [ 84.  90.  27.]
# 729 iterations
# 6 items considered
# [ 76.  99.  50.]
# 730 iterations
# 7 items considered
# [ 56.  94.  50.]
# 731 iterations
# 7 items considered
# [ 44.  94.  65.]
# 732 iterations
# 8 items considered
# [ 44.  94.  61.]
# 733 iterations
# 8 items considered
# [  49.  106.   68.]
# 734 iterations
# 9 items considered
# [  49.  104.   54.]
# 735 iterations
# 9 items considered
# [ 61.  90.  75.]
# 736 iterations
# 10 items considered
# [ 61.  90.  70.]
# 737 iterations
# 10 items considered
# [ 66.  85.  74.]
# 738 iterations
# 11 items considered
# [ 60.  84.  44.]
# 739 iterations
# 11 items considered
# [ 78.  80.  17.]
# 740 iterations
# 12 items considered
# [ 66.  80.   9.]
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 741 iterations
# 5 items considered
# [ 87.  93.  14.]
# 372
# 742 iterations
# 5 items considered
# [ 87.  95.   0.]
# 743 iterations
# 5 items considered
# [  83.  103.   10.]
# 373
# 744 iterations
# 5 items considered
# [  83.  103.   10.]
# 745 iterations
# 5 items considered
# [ 84.  97.  32.]
# 746 iterations
# 6 items considered
# [ 82.  90.  15.]
# 747 iterations
# 6 items considered
# [ 65.  96.  40.]
# 748 iterations
# 7 items considered
# [ 56.  95.  40.]
# 749 iterations
# 7 items considered
# [  48.  100.   39.]
# 750 iterations
# 8 items considered
# [ 20.  97.  18.]
# 751 iterations
# 8 items considered
# [  29.  103.   27.]
# 752 iterations
# 9 items considered
# [ 26.  98.  24.]
# 374
# 375
# 376
# 753 iterations
# 6 items considered
# [ 53.  95.   9.]
# 377
# 754 iterations
# 6 items considered
# [ 53.  95.   9.]
# 755 iterations
# 6 items considered
# [ 61.  89.  25.]
# 756 iterations
# 7 items considered
# [ 60.  83.   4.]
# 378
# 379
# 757 iterations
# 5 items considered
# [ 89.  87.  36.]
# 758 iterations
# 6 items considered
# [ 77.  87.  28.]
# 759 iterations
# 6 items considered
# [ 78.  93.  48.]
# 760 iterations
# 7 items considered
# [ 78.  93.  12.]
# 761 iterations
# 7 items considered
# [ 90.  96.  63.]
# 762 iterations
# 8 items considered
# [ 84.  82.  35.]
# 763 iterations
# 8 items considered
# [ 69.  63.  30.]
# 764 iterations
# 9 items considered
# [ 69.  63.  28.]
# 765 iterations
# 9 items considered
# [ 64.  56.  30.]
# 380
# 766 iterations
# 9 items considered
# [ 61.  64.   1.]
# 381
# 767 iterations
# 8 items considered
# [ 71.  86.  30.]
# 768 iterations
# 9 items considered
# [ 70.  86.  26.]
# 382
# 769 iterations
# 8 items considered
# [  83.  101.   31.]
# 770 iterations
# 9 items considered
# [  83.  100.   14.]
# 771 iterations
# 9 items considered
# [  88.  113.   25.]
# 383
# 384
# 385
# 772 iterations
# 7 items considered
# [  82.  115.   45.]
# 773 iterations
# 7 items considered
# [  78.  112.   38.]
# 774 iterations
# 8 items considered
# [  77.  106.   31.]
# 775 iterations
# 8 items considered
# [  89.  106.   13.]
# 776 iterations
# 9 items considered
# [ 67.  78.  13.]
# 777 iterations
# 9 items considered
# [ 77.  81.  46.]
# 778 iterations
# 10 items considered
# [ 69.  80.   7.]
# 779 iterations
# 10 items considered
# [ 70.  69.  41.]
# 780 iterations
# 11 items considered
# [ 67.  68.  23.]
# 781 iterations
# 11 items considered
# [ 73.  75.  39.]
# 782 iterations
# 12 items considered
# [ 73.  64.  17.]
# 386
# 783 iterations
# 11 items considered
# [ 73.  75.  39.]
# 784 iterations
# 12 items considered
# [ 62.  69.  36.]
# 785 iterations
# 12 items considered
# [ 73.  74.  38.]
# 786 iterations
# 13 items considered
# [ 71.  70.  19.]
# 787 iterations
# 13 items considered
# [ 66.  59.  43.]
# 788 iterations
# 14 items considered
# [ 56.  52.  39.]
# 789 iterations
# 14 items considered
# [ 56.  52.  62.]
# 790 iterations
# 15 items considered
# [ 28.  34.  62.]
# 791 iterations
# 15 items considered
# [ 38.  41.  42.]
# 792 iterations
# 16 items considered
# [ 26.  41.  33.]
# 793 iterations
# 16 items considered
# [ 25.  32.  29.]
# 794 iterations
# 17 items considered
# [ 25.  32.   9.]
# 387
# 388
# 389
# 795 iterations
# 14 items considered
# [ 73.  60.  11.]
# 796 iterations
# 15 items considered
# [ 73.  60.   6.]
# 390
# 391
# 392
# 393
# 394
# 797 iterations
# 10 items considered
# [ 97.  99.   1.]
# 395
# 798 iterations
# 10 items considered
# [ 96.  99.  12.]
# 799 iterations
# 10 items considered
# [ 97.  95.  23.]
# 396
# 800 iterations
# 10 items considered
# [ 97.  95.   9.]
# 397
# 801 iterations
# 9 items considered
# [ 97.  91.  26.]
# 802 iterations
# 10 items considered
# [ 97.  91.  13.]
# 398
# 399
# 400
# 803 iterations
# 7 items considered
# [ 93.  67.  34.]
# 804 iterations
# 8 items considered
# [ 88.  60.  34.]
# 805 iterations
# 8 items considered
# [ 97.  88.  81.]
# 806 iterations
# 9 items considered
# [ 97.  88.  81.]
# 807 iterations
# 9 items considered
# [ 98.  94.  87.]
# 808 iterations
# 10 items considered
# [ 98.  94.  78.]
# 809 iterations
# 10 items considered
# [ 101.  101.   70.]
# 810 iterations
# 11 items considered
# [ 100.   95.   51.]
# 811 iterations
# 11 items considered
# [ 94.  85.  75.]
# 812 iterations
# 12 items considered
# [ 87.  85.  56.]
# 813 iterations
# 12 items considered
# [ 87.  81.  62.]
# 814 iterations
# 13 items considered
# [ 83.  77.  48.]
# 815 iterations
# 13 items considered
# [ 82.  69.  42.]
# 816 iterations
# 14 items considered
# [ 81.  63.  28.]
# 817 iterations
# 14 items considered
# [ 82.  57.  44.]
# 818 iterations
# 15 items considered
# [ 61.  54.  44.]
# 819 iterations
# 15 items considered
# [ 64.  62.  44.]
# 820 iterations
# 16 items considered
# [ 47.  47.   8.]
# 821 iterations
# 16 items considered
# [ 51.  50.   8.]
# 822 iterations
# 17 items considered
# [ 49.  50.   4.]
# 401
# 402
# 403
# 823 iterations
# 14 items considered
# [ 65.  71.  29.]
# 404
# 405
# 824 iterations
# 13 items considered
# [ 71.  78.  29.]
# 825 iterations
# 13 items considered
# [ 64.  75.  32.]
# 826 iterations
# 14 items considered
# [ 60.  59.   5.]
# 827 iterations
# 14 items considered
# [ 61.  63.  11.]
# 406
# 407
# 828 iterations
# 13 items considered
# [ 84.  63.   3.]
# 829 iterations
# 13 items considered
# [ 86.  67.  13.]
# 408
# 409
# 410
# 411
# 830 iterations
# 10 items considered
# [ 94.  88.  27.]
# 831 iterations
# 10 items considered
# [ 95.  96.  42.]
# 832 iterations
# 11 items considered
# [ 87.  91.  41.]
# 833 iterations
# 11 items considered
# [ 85.  77.  18.]
# 834 iterations
# 12 items considered
# [ 78.  69.  17.]
# 835 iterations
# 12 items considered
# [ 77.  69.  17.]
# 836 iterations
# 13 items considered
# [ 72.  58.   7.]
# 412
# 413
# 414
# 415
# 837 iterations
# 9 items considered
# [ 80.  61.   0.]
# 416
# 417
# 838 iterations
# 8 items considered
# [ 80.  61.   9.]
# 839 iterations
# 8 items considered
# [ 77.  59.  26.]
# 840 iterations
# 9 items considered
# [ 76.  59.  20.]
# 841 iterations
# 9 items considered
# [ 71.  65.  21.]
# 842 iterations
# 10 items considered
# [ 70.  61.  19.]
# 843 iterations
# 10 items considered
# [ 79.  73.  60.]
# 844 iterations
# 11 items considered
# [ 77.  73.  32.]
# 845 iterations
# 11 items considered
# [ 77.  73.  19.]
# 846 iterations
# 12 items considered
# [ 76.  66.   3.]
# 847 iterations
# 12 items considered
# [ 81.  80.   8.]
# 848 iterations
# 13 items considered
# [ 70.  69.   2.]
# 418
# 419
# 849 iterations
# 11 items considered
# [ 85.  95.  16.]
# 850 iterations
# 12 items considered
# [ 79.  89.  13.]
# 851 iterations
# 12 items considered
# [ 82.  82.  46.]
# 852 iterations
# 13 items considered
# [ 80.  72.  31.]
# 853 iterations
# 13 items considered
# [ 79.  69.  33.]
# 854 iterations
# 14 items considered
# [ 79.  69.   8.]
# 420
# 855 iterations
# 13 items considered
# [ 80.  75.   5.]
# 856 iterations
# 14 items considered
# [ 50.  73.   5.]
# 857 iterations
# 14 items considered
# [ 50.  70.   9.]
# 858 iterations
# 15 items considered
# [ 47.  69.   0.]
# 859 iterations
# 15 items considered
# [ 46.  69.  13.]
# 860 iterations
# 16 items considered
# [ 46.  69.   6.]
# 861 iterations
# 16 items considered
# [ 48.  66.   5.]
# 421
# 422
# 862 iterations
# 15 items considered
# [ 50.  57.  14.]
# 863 iterations
# 15 items considered
# [ 43.  45.  39.]
# 864 iterations
# 16 items considered
# [ 36.  42.  28.]
# 423
# 424
# 865 iterations
# 14 items considered
# [ 50.  58.  14.]
# 866 iterations
# 15 items considered
# [ 49.  44.  12.]
# 425
# 867 iterations
# 14 items considered
# [ 50.  38.   4.]
# 426
# 427
# 428
# 868 iterations
# 12 items considered
# [ 81.  29.  23.]
# 869 iterations
# 12 items considered
# [ 85.  27.   6.]
# 870 iterations
# 13 items considered
# [ 80.  22.   5.]
# 429
# 871 iterations
# 12 items considered
# [ 81.  25.   7.]
# 430
# 872 iterations
# 12 items considered
# [ 81.  25.   7.]
# 873 iterations
# 12 items considered
# [ 80.  20.  25.]
# 874 iterations
# 13 items considered
# [ 50.  18.  25.]
# 875 iterations
# 13 items considered
# [ 43.  18.   0.]
# 431
# 432
# 433
# 876 iterations
# 11 items considered
# [ 75.  30.  15.]
# 434
# 877 iterations
# 10 items considered
# [ 84.  46.   8.]
# 435
# 878 iterations
# 10 items considered
# [ 92.  51.  34.]
# 879 iterations
# 10 items considered
# [ 92.  51.  47.]
# 880 iterations
# 11 items considered
# [ 90.  50.  22.]
# 436
# 437
# 881 iterations
# 9 items considered
# [ 89.  75.  16.]
# 882 iterations
# 10 items considered
# [ 87.  74.  15.]
# 883 iterations
# 10 items considered
# [ 69.  73.   8.]
# 438
# 439
# 884 iterations
# 9 items considered
# [ 79.  69.  27.]
# 885 iterations
# 9 items considered
# [  83.  104.   25.]
# 886 iterations
# 10 items considered
# [ 52.  98.  23.]
# 887 iterations
# 10 items considered
# [ 54.  98.  48.]
# 888 iterations
# 11 items considered
# [ 54.  98.  22.]
# 889 iterations
# 11 items considered
# [ 52.  98.  20.]
# 890 iterations
# 12 items considered
# [ 39.  98.  20.]
# ...
# [ 202.   89.   48.]
# 29748 iterations
# 5 items considered
# [ 194.   80.   34.]
# 29749 iterations
# 5 items considered
# [ 196.   81.   49.]
# 29750 iterations
# 6 items considered
# [ 194.   74.   33.]
# 29751 iterations
# 6 items considered
# [ 194.   77.    8.]
# 15180
# 15181
# 29752 iterations
# 5 items considered
# [ 189.   75.   13.]
# 15182
# 29753 iterations
# 4 items considered
# [ 195.   78.   37.]
# 29754 iterations
# 5 items considered
# [ 189.   65.   30.]
# 29755 iterations
# 5 items considered
# [ 184.   63.   45.]
# 29756 iterations
# 6 items considered
# [ 184.   63.   40.]
# 29757 iterations
# 6 items considered
# [ 172.   63.   60.]
# 29758 iterations
# 7 items considered
# [ 172.   63.   27.]
# 29759 iterations
# 7 items considered
# [ 183.   50.   11.]
# 15183
# 29760 iterations
# 7 items considered
# [ 183.   50.   11.]
# 29761 iterations
# 7 items considered
# [ 185.   57.   23.]
# 29762 iterations
# 8 items considered
# [ 185.   50.   21.]
# 29763 iterations
# 8 items considered
# [ 193.   56.   35.]
# 29764 iterations
# 9 items considered
# [ 180.   41.   22.]
# 29765 iterations
# 9 items considered
# [ 178.   40.    7.]
# 29766 iterations
# 10 items considered
# [ 177.   39.    3.]
# 15184
# 29767 iterations
# 9 items considered
# [ 176.   36.    8.]
# 15185
# 15186
# 29768 iterations
# 8 items considered
# [ 180.   43.    8.]
# 29769 iterations
# 8 items considered
# [ 174.   37.    6.]
# 15187
# 29770 iterations
# 8 items considered
# [ 174.   37.    8.]
# 29771 iterations
# 8 items considered
# [ 175.   42.    7.]
# 15188
# 29772 iterations
# 8 items considered
# [ 176.   45.    3.]
# 15189
# 29773 iterations
# 7 items considered
# [ 176.   45.   25.]
# 29774 iterations
# 8 items considered
# [ 176.   45.   16.]
# 29775 iterations
# 8 items considered
# [ 180.   49.   22.]
# 29776 iterations
# 9 items considered
# [ 177.   41.    4.]
# 29777 iterations
# 9 items considered
# [ 177.   27.    8.]
# 15190
# 15191
# 29778 iterations
# 8 items considered
# [ 196.   51.    0.]
# 29779 iterations
# 8 items considered
# [ 189.   43.   20.]
# 15192
# 29780 iterations
# 8 items considered
# [ 178.   33.    0.]
# 29781 iterations
# 8 items considered
# [ 174.   30.   20.]
# 29782 iterations
# 9 items considered
# [ 172.   26.    3.]
# 29783 iterations
# 9 items considered
# [ 171.   22.    2.]
# 29784 iterations
# 10 items considered
# [ 167.   21.    0.]
# 15193
# 15194
# 29785 iterations
# 8 items considered
# [ 178.   31.   26.]
# 29786 iterations
# 9 items considered
# [ 178.   31.    7.]
# 15195
# 15196
# 29787 iterations
# 7 items considered
# [ 186.   46.   27.]
# 29788 iterations
# 8 items considered
# [ 186.   46.    0.]
# 29789 iterations
# 8 items considered
# [ 160.   47.   12.]
# 15197
# 29790 iterations
# 8 items considered
# [ 161.   49.    3.]
# 29791 iterations
# 8 items considered
# [ 161.   49.    2.]
# 15198
# 29792 iterations
# 8 items considered
# [ 161.   49.    2.]
# 15199
# 29793 iterations
# 7 items considered
# [ 166.   60.   18.]
# 29794 iterations
# 8 items considered
# [ 165.   60.   11.]
# 29795 iterations
# 8 items considered
# [ 170.   75.   24.]
# 15200
# 29796 iterations
# 8 items considered
# [ 170.   75.   24.]
# 29797 iterations
# 8 items considered
# [ 161.   72.   33.]
# 29798 iterations
# 9 items considered
# [ 161.   64.   33.]
# 29799 iterations
# 9 items considered
# [ 187.   64.   25.]
# 15201
# 15202
# 29800 iterations
# 8 items considered
# [ 193.   58.    4.]
# 29801 iterations
# 8 items considered
# [ 190.   62.    1.]
# 15203
# 15204
# 15205
# 15206
# 29802 iterations
# 5 items considered
# [ 204.   77.   27.]
# 29803 iterations
# 5 items considered
# [ 204.   71.   11.]
# 15207
# 29804 iterations
# 5 items considered
# [ 206.   74.   25.]
# 29805 iterations
# 5 items considered
# [ 206.   70.   29.]
# 29806 iterations
# 6 items considered
# [ 178.   60.   28.]
# 29807 iterations
# 6 items considered
# [ 157.   62.   35.]
# 29808 iterations
# 7 items considered
# [ 144.   59.   28.]
# 29809 iterations
# 7 items considered
# [ 146.   55.   27.]
# 29810 iterations
# 8 items considered
# [ 145.   55.   22.]
# 29811 iterations
# 8 items considered
# [ 144.   47.   11.]
# 15208
# 15209
# 29812 iterations
# 7 items considered
# [ 145.   47.   16.]
# 29813 iterations
# 7 items considered
# [ 132.   33.   26.]
# 15210
# 29814 iterations
# 7 items considered
# [ 132.   33.   26.]
# 29815 iterations
# 7 items considered
# [ 122.   25.   25.]
# 29816 iterations
# 8 items considered
# [ 122.   13.   16.]
# 29817 iterations
# 8 items considered
# [ 142.   18.   17.]
# 15211
# 29818 iterations
# 8 items considered
# [ 142.   18.   17.]
# 29819 iterations
# 8 items considered
# [ 150.    7.   25.]
# 29820 iterations
# 9 items considered
# [ 150.    7.   25.]
# 15212
# 29821 iterations
# 8 items considered
# [ 167.   19.    5.]
# 15213
# 29822 iterations
# 8 items considered
# [ 162.   11.    7.]
# 29823 iterations
# 8 items considered
# [ 163.   26.   24.]
# 29824 iterations
# 9 items considered
# [ 163.   26.    6.]
# 29825 iterations
# 9 items considered
# [ 162.   26.    6.]
# 15214
# 29826 iterations
# 9 items considered
# [ 162.   44.    1.]
# 29827 iterations
# 9 items considered
# [ 163.   45.   18.]
# 29828 iterations
# 10 items considered
# [ 158.   31.    1.]
# 29829 iterations
# 10 items considered
# [ 160.   31.   15.]
# 29830 iterations
# 11 items considered
# [ 160.   31.    0.]
# 15215
# 29831 iterations
# 10 items considered
# [ 165.   45.    4.]
# 15216
# 29832 iterations
# 10 items considered
# [ 165.   45.    4.]
# 29833 iterations
# 10 items considered
# [ 163.   37.   12.]
# 15217
# 15218
# 29834 iterations
# 9 items considered
# [ 166.   45.   27.]
# 29835 iterations
# 9 items considered
# [ 188.   46.   22.]
# 29836 iterations
# 10 items considered
# [ 171.   35.   13.]
# 29837 iterations
# 10 items considered
# [ 185.   57.   10.]
# 15219
# 29838 iterations
# 10 items considered
# [ 185.   69.    3.]
# 29839 iterations
# 10 items considered
# [ 185.   69.    7.]
# 15220
# 29840 iterations
# 10 items considered
# [ 175.   56.    8.]
# 29841 iterations
# 10 items considered
# [ 174.   48.    6.]
# 15221
# 29842 iterations
# 10 items considered
# [ 119.   35.   13.]
# 29843 iterations
# 10 items considered
# [ 132.   43.    4.]
# 15222
# 15223
# 29844 iterations
# 9 items considered
# [ 137.   55.    2.]
# 15224
# 15225
# 29845 iterations
# 7 items considered
# [ 192.   67.   15.]
# 15226
# 29846 iterations
# 7 items considered
# [ 196.   69.   12.]
# 29847 iterations
# 7 items considered
# [ 196.   69.   28.]
# 29848 iterations
# 8 items considered
# [ 185.   40.   22.]
# 29849 iterations
# 8 items considered
# [ 186.   45.   17.]
# 15227
# 29850 iterations
# 8 items considered
# [ 185.   39.   31.]
# 29851 iterations
# 8 items considered
# [ 181.   39.   31.]
# 29852 iterations
# 9 items considered
# [ 179.   38.   10.]
# 29853 iterations
# 9 items considered
# [ 189.   51.    4.]
# 15228
# 15229
# 29854 iterations
# 8 items considered
# [ 189.   51.   12.]
# 29855 iterations
# 8 items considered
# [ 188.   52.   32.]
# 29856 iterations
# 9 items considered
# [ 187.   52.   16.]
# 15230
# 29857 iterations
# 8 items considered
# [ 190.   61.   14.]
# 29858 iterations
# 9 items considered
# [ 190.   61.    1.]
# 29859 iterations
# 9 items considered
# [ 189.   61.   37.]
# 29860 iterations
# 10 items considered
# [ 169.   60.   34.]
# 29861 iterations
# 10 items considered
# [ 167.   56.   26.]
# 29862 iterations
# 11 items considered
# [ 158.   52.   25.]
# 29863 iterations
# 11 items considered
# [ 157.   50.   41.]
# 29864 iterations
# 12 items considered
# [ 156.   50.   22.]
# 15231
# 29865 iterations
# 11 items considered
# [ 167.   58.   20.]
# 15232
# 15233
# 15234
# 29866 iterations
# 9 items considered
# [ 172.   58.   44.]
# 29867 iterations
# 9 items considered
# [ 171.   54.   19.]
# 15235
# 29868 iterations
# 9 items considered
# [ 178.   81.    5.]
# 29869 iterations
# 9 items considered
# [ 180.   83.    7.]
# 29870 iterations
# 10 items considered
# [ 175.   77.    7.]
# 15236
# 15237
# 29871 iterations
# 8 items considered
# [ 194.   84.    6.]
# 15238
# 29872 iterations
# 8 items considered
# [ 194.   80.    2.]
# 15239
# 15240
# 29873 iterations
# 6 items considered
# [ 198.   87.   18.]
# 15241
# 29874 iterations
# 6 items considered
# [ 198.   61.   17.]
# 15242
# 29875 iterations
# 5 items considered
# [ 204.   84.   13.]
# 15243
# 29876 iterations
# 5 items considered
# [ 194.   83.   25.]
# 29877 iterations
# 5 items considered
# [ 197.   94.   44.]
# 29878 iterations
# 6 items considered
# [ 190.   93.    0.]
# 15244
# 29879 iterations
# 5 items considered
# [ 190.   93.   19.]
# 29880 iterations
# 6 items considered
# [ 189.   93.    7.]
# 29881 iterations
# 6 items considered
# [ 190.   93.    6.]
# 29882 iterations
# 7 items considered
# [ 189.   89.    5.]
# 15245
# 15246
# 29883 iterations
# 5 items considered
# [ 183.   86.   21.]
# 29884 iterations
# 6 items considered
# [ 176.   69.   16.]
# 29885 iterations
# 6 items considered
# [ 183.   67.   53.]
# 29886 iterations
# 7 items considered
# [ 169.   60.   32.]
# 29887 iterations
# 7 items considered
# [ 170.   58.   36.]
# 29888 iterations
# 8 items considered
# [ 168.   52.   19.]
# 29889 iterations
# 8 items considered
# [ 175.   34.   62.]
# 29890 iterations
# 9 items considered
# [ 174.   34.   57.]
# 29891 iterations
# 9 items considered
# [ 175.   38.   56.]
# 29892 iterations
# 10 items considered
# [ 168.   23.   47.]
# 29893 iterations
# 10 items considered
# [ 164.   19.   29.]
# 29894 iterations
# 11 items considered
# [ 157.   10.   28.]
# 15247
# 29895 iterations
# 10 items considered
# [ 171.   36.   10.]
# 15248
# 15249
# 29896 iterations
# 9 items considered
# [ 179.   51.    8.]
# 29897 iterations
# 9 items considered
# [ 179.   50.   27.]
# 29898 iterations
# 10 items considered
# [ 177.   45.   10.]
# 29899 iterations
# 10 items considered
# [ 184.   46.   24.]
# 29900 iterations
# 11 items considered
# [ 166.   30.   24.]
# 29901 iterations
# 11 items considered
# [ 166.   27.   33.]
# 15250
# 29902 iterations
# 11 items considered
# [ 166.   27.   33.]
# 29903 iterations
# 11 items considered
# [ 161.   33.   21.]
# 29904 iterations
# 12 items considered
# [ 148.   24.   13.]
# 29905 iterations
# 12 items considered
# [ 154.   39.    9.]
# 15251
# 15252
# 29906 iterations
# 11 items considered
# [ 155.   41.   18.]
# 15253
# 15254
# 15255
# 15256
# 29907 iterations
# 7 items considered
# [ 176.   64.   33.]
# 29908 iterations
# 8 items considered
# [ 172.   52.    9.]
# 29909 iterations
# 8 items considered
# [ 169.   50.    7.]
# 15257
# 15258
# 29910 iterations
# 7 items considered
# [ 187.   66.    7.]
# 29911 iterations
# 7 items considered
# [ 185.   55.   26.]
# 15259
# 29912 iterations
# 7 items considered
# [ 185.   56.    3.]
# 29913 iterations
# 7 items considered
# [ 193.   51.    5.]
# 15260
# 29914 iterations
# 7 items considered
# [ 199.   54.   14.]
# 15261
# 29915 iterations
# 6 items considered
# [ 199.   54.   16.]
# 29916 iterations
# 7 items considered
# [ 199.   54.   14.]
# 15262
# 29917 iterations
# 6 items considered
# [ 195.   66.    6.]
# 15263
# 15264
# 29918 iterations
# 5 items considered
# [ 173.   47.   27.]
# 29919 iterations
# 5 items considered
# [ 191.   70.   67.]
# 29920 iterations
# 6 items considered
# [ 173.   70.   67.]
# 29921 iterations
# 7 items considered
# [ 173.   70.   66.]
# 29922 iterations
# 8 items considered
# [ 173.   70.   56.]
# 29923 iterations
# 9 items considered
# [ 173.   70.   48.]
# 29924 iterations
# 9 items considered
# [ 175.   75.   55.]
# 29925 iterations
# 10 items considered
# [ 175.   75.   55.]
# 29926 iterations
# 10 items considered
# [ 175.   75.   38.]
# 29927 iterations
# 11 items considered
# [ 174.   71.   19.]
# 29928 iterations
# 11 items considered
# [ 174.   71.   21.]
# 29929 iterations
# 12 items considered
# [ 174.   57.   21.]
# 15265
# 15266
# 15267
# 29930 iterations
# 9 items considered
# [ 178.   63.    7.]
# 15268
# 15269
# 15270
# 29931 iterations
# 7 items considered
# [ 196.   77.    7.]
# 15271
# 15272
# 29932 iterations
# 5 items considered
# [ 200.   92.    6.]
# 15273
# 15274
# 29933 iterations
# 4 items considered
# [ 192.   93.   30.]
# 29934 iterations
# 4 items considered
# [ 204.   93.   43.]
# 29935 iterations
# 5 items considered
# [ 204.   91.   34.]
# 29936 iterations
# 5 items considered
# [ 203.   88.   67.]
# 29937 iterations
# 6 items considered
# [ 187.   65.   18.]
# 29938 iterations
# 7 items considered
# [ 177.   64.   12.]
# 29939 iterations
# 7 items considered
# [ 177.   65.   29.]
# 29940 iterations
# 8 items considered
# [ 176.   62.   16.]
# 29941 iterations
# 8 items considered
# [ 176.   62.    4.]
# 15275
# 15276
# 29942 iterations
# 7 items considered
# [ 193.   89.   46.]
# 29943 iterations
# 7 items considered
# [ 201.   81.   37.]
# 29944 iterations
# 8 items considered
# [ 197.   76.   20.]
# 29945 iterations
# 8 items considered
# [ 198.   80.   27.]
# 15277
# 29946 iterations
# 8 items considered
# [ 198.   80.   27.]
# 29947 iterations
# 8 items considered
# [ 201.   80.   41.]
# 29948 iterations
# 9 items considered
# [ 201.   80.   32.]
# 29949 iterations
# 9 items considered
# [ 202.   84.    9.]
# 15278
# 15279
# 29950 iterations
# 8 items considered
# [ 201.   82.   13.]
# 29951 iterations
# 8 items considered
# [ 198.   84.   37.]
# 29952 iterations
# 9 items considered
# [ 185.   78.   36.]
# 29953 iterations
# 9 items considered
# [ 190.   83.   35.]
# 29954 iterations
# 10 items considered
# [ 190.   81.   26.]
# 29955 iterations
# 10 items considered
# [ 183.   71.   35.]
# 29956 iterations
# 11 items considered
# [ 183.   71.    8.]
# 29957 iterations
# 11 items considered
# [ 169.   66.   14.]
# 15280
# 15281
# 29958 iterations
# 10 items considered
# [ 179.   76.   11.]
# 29959 iterations
# 10 items considered
# [ 172.   76.    2.]
# 15282
# 29960 iterations
# 10 items considered
# [ 172.   76.    1.]
# 29961 iterations
# 10 items considered
# [ 174.   75.   36.]
# 29962 iterations
# 11 items considered
# [ 174.   72.   33.]
# 29963 iterations
# 11 items considered
# [ 173.   72.   33.]
# 29964 iterations
# 12 items considered
# [ 172.   68.   31.]
# 29965 iterations
# 12 items considered
# [ 168.   62.   33.]
# 29966 iterations
# 13 items considered
# [ 163.   62.   30.]
# 29967 iterations
# 13 items considered
# [ 160.   53.    5.]
# 15283
# 29968 iterations
# 13 items considered
# [ 150.   50.    2.]
# 15284
# 29969 iterations
# 12 items considered
# [ 165.   69.   13.]
# 15285
# 15286
# 29970 iterations
# 11 items considered
# [ 168.   73.   11.]
# 29971 iterations
# 11 items considered
# [ 143.   64.   31.]
# 29972 iterations
# 12 items considered
# [ 140.   61.    8.]
# 29973 iterations
# 12 items considered
# [ 143.   64.   17.]
# 29974 iterations
# 13 items considered
# [ 136.   55.   16.]
# 29975 iterations
# 13 items considered
# [ 143.   63.    0.]
# 15287
# 15288
# 29976 iterations
# 12 items considered
# [ 144.   67.    2.]
# 29977 iterations
# 12 items considered
# [ 149.   58.   28.]
# 29978 iterations
# 13 items considered
# [ 117.   57.   28.]
# 29979 iterations
# 13 items considered
# [ 88.  51.  45.]
# 29980 iterations
# 14 items considered
# [ 87.  46.  43.]
# 29981 iterations
# 14 items considered
# [ 68.  43.  46.]
# 29982 iterations
# 15 items considered
# [ 66.  32.  34.]
# 29983 iterations
# 15 items considered
# [ 68.  42.  42.]
# 29984 iterations
# 16 items considered
# [ 62.  41.   1.]
# 15289
# 15290
# 29985 iterations
# 14 items considered
# [ 94.  51.  28.]
# 29986 iterations
# 15 items considered
# [ 86.  42.  14.]
# 29987 iterations
# 15 items considered
# [ 115.   49.   12.]
# 29988 iterations
# 16 items considered
# [ 112.   45.   11.]
# 29989 iterations
# 16 items considered
# [ 132.   51.   13.]
# 29990 iterations
# 17 items considered
# [ 128.   51.    1.]
# 15291
# 15292
# 15293
# 15294
# 29991 iterations
# 13 items considered
# [ 186.   58.    0.]
# 15295
# 29992 iterations
# 13 items considered
# [ 186.   58.    1.]
# 15296
# 15297
# 29993 iterations
# 11 items considered
# [ 188.   62.   10.]
# 15298
# 29994 iterations
# 11 items considered
# [ 163.   59.   11.]
# 29995 iterations
# 11 items considered
# [ 159.   55.   43.]
# 29996 iterations
# 12 items considered
# [ 158.   51.   42.]
# 29997 iterations
# 12 items considered
# [ 158.   51.   25.]
# 29998 iterations
# 13 items considered
# [ 156.   51.   13.]
# 29999 iterations
# 13 items considered
# [ 153.   43.   24.]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-26-9dbdc8676f06> in <module>()
# ----> 1 test = monte_carlo_maker(10)
#
# <ipython-input-21-82d3735423e9> in monte_carlo_maker(iterations)
#       5         req2 = randint(20,220)
#       6         req3 = randint(20,220)
# ----> 7         result = find_a_plan(req1 , req2, req3)
#       8         mc_df.append(result, ignore_index=True)
#       9     return mc_df
#
# <ipython-input-25-80fa7cdaa9fb> in find_a_plan(prot_req, fat_req, carb_req)
#      50                                       'num_matches':len(match_df),
#      51                                       'mac_proportions':sum([abs(prot_req-fat_req),abs(fat_req-carb_req),abs(prot_req-carb_req)]),
# ---> 52                                       'iterations':j,
#      53                                       'prot_delta': delta[0],
#      54                                       'fat_delta': delta[1],
#
# UnboundLocalError: local variable 'j' referenced before assignment

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d8e8fca2dc0f> in <module>()
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
result
# Out:
#    carb_delta  carb_req  fat_delta  fat_req  iterations  mac_proportions  \
# 0        15.0       100       15.0      100           4                0
#
#    num_items  num_matches  prot_delta  prot_req
# 0         14            5        30.0       100

# %%
result
# Out:
#                                               ndb_no  \
# 0  3340     45198682.0
# 52485    45284476.0
# 56039 ...
# 0  3340     45198682.0
# 52485    45284476.0
# 56039 ...
# 0  3340     45198682.0
# 52485    45284476.0
# 56039 ...
# 0  3340     45198682.0
# 52485    45284476.0
# 56039 ...
# 0  3340     45198682.0
# 52485    45284476.0
# 56039 ...
#
#                        plan_id
# 0              [1, 1, 1, 1, 1]
# 0           [2, 2, 2, 2, 2, 2]
# 0        [3, 3, 3, 3, 3, 3, 3]
# 0     [4, 4, 4, 4, 4, 4, 4, 4]
# 0  [5, 5, 5, 5, 5, 5, 5, 5, 5]

# %%
# First Iter
def try_one_plan():
    temp_df = pd.DataFrame()
    plan_df = pd.DataFrame()

# %%
temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)),:])
delta = np.array([prot_req,fat_req,carb_req])-np.array([sum(temp_df['protein_g']),sum(temp_df['fat_g']),sum(temp_df['carb_g'])])
print(delta)
# Out:
# [ 208.   44.  150.]

# %%
sum((delta>np.array([prot_req*.5,fat_req*.5,carb_req*.5])))>0
# Out:
# True

# %%
print(delta)
print(np.array([prot_req*.5,fat_req*.5,carb_req*.5]))
# Out:
# [ 205.    40.4  160.4]
# [ 104.   22.   91.]

# %%
sum((delta>np.array([prot_req,fat_req,carb_req])))>0
# Out:
# False

# %%
i = 0
while True:
    i+=1
    if i ==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4
