# %%
import pandas as pd
import numpy as np
from random import randint
import math

# %%
df = pd.read_csv('C:/Users/J/Desktop/Git_Repositories/desktop-meal-maker/diet_facts_usda.csv', encoding='ISO-8859-2')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (0,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df[df.brand=='Starbucks']
# Out:
#        food_key                                   food_description      brand  \
# 282358   282743        Cafe Au Lait with Soy Milk (US), Tall-sized  Starbucks
# 282391   282383             Reduced Fat Cinnamon Swirl Coffee Cake  Starbucks
# 282668   282658                                     Focaccia Bread  Starbucks
# 282713   282703                            Almond Filled Croissant  Starbucks
# 282714   282704                              Almond Poppyseed Loaf  Starbucks
# 282715   282705                   Almond Toffee Cookie with Pecans  Starbucks
# 282716   282706                                 Apple Cinnamon Bar  Starbucks
# 282717   282707                     Apple Danish with Mocha Swirls  Starbucks
# 282718   282708                                      Apple Fritter  Starbucks
# 282719   282709                          Apple Juice, Grande-sized  Starbucks
# 282720   282710                            Apple Juice, Tall-sized  Starbucks
# 282721   282711                           Apple Juice, Venti-sized  Starbucks
# 282722   282712                           Apple Walnut Coffee Cake  Starbucks
# 282723   282713                              Apricot Currant Scone  Starbucks
# 282724   282714                                       Bagel, plain  Starbucks
# 282725   282715  Banana Caramel Frappuccino Blended Coffee with...  Starbucks
# 282726   282716  Banana Caramel Frappuccino Blended Coffee, Tal...  Starbucks
# 282727   282717                       Banana Chocolate Chip Muffin  Starbucks
# 282728   282718  Banana Coconut Frappuccino Blended Coffee with...  Starbucks
# 282729   282719  Banana Coconut Frappuccino Blended Coffee, Tal...  Starbucks
# 282730   282720                                        Banana Loaf  Starbucks
# 282731   282721                                  Banana Pound Cake  Starbucks
# 282732   282722                                     Banana Pullman  Starbucks
# 282733   282723                             Black and White Cookie  Starbucks
# 282734   282724  Blackberry Green Tea Frappuccino Blended Creme...  Starbucks
# 282735   282725  Blackberry Green Tea Frappuccino Blended Creme...  Starbucks
# 282736   282726  Blackberry Green Tea Frappuccino Blended Creme...  Starbucks
# 282737   282727  Blackberry Green Tea Frappuccino Blended Creme...  Starbucks
# 282738   282728  Blackberry Green Tea Frappuccino Blended Creme...  Starbucks
# 282739   282729  Blackberry Green Tea Frappuccino Blended Creme...  Starbucks
# ...         ...                                                ...        ...
# 283257   283246             White Hot Chocolate - no whipped cream  Starbucks
# 283258   283247             White Hot Chocolate - no whipped cream  Starbucks
# 283259   283248             White Hot Chocolate - no whipped cream  Starbucks
# 283260   283249           White Hot Chocolate - with whipped cream  Starbucks
# 283261   283250           White Hot Chocolate - with whipped cream  Starbucks
# 283262   283251           White Hot Chocolate - with whipped cream  Starbucks
# 283263   283252           White Hot Chocolate - with whipped cream  Starbucks
# 283264   283253            White Hot Chocolate- with whipped cream  Starbucks
# 283265   283254            White Hot Chocolate- with whipped cream  Starbucks
# 283266   283255            White Hot Chocolate- with whipped cream  Starbucks
# 283267   283256            White Hot Chocolate- with whipped cream  Starbucks
# 283268   283257  Zombie Frappuccino with 2% Milk, Grande 16oz -...  Starbucks
# 283269   283258  Zombie Frappuccino with 2% Milk, Tall 12oz - L...  Starbucks
# 283270   283259  Zombie Frappuccino with 2% Milk, Venti 24oz - ...  Starbucks
# 283271   283260  Zombie Frappuccino with Almond Milk, Grande 16...  Starbucks
# 283272   283261  Zombie Frappuccino with Almond Milk, Tall 12oz...  Starbucks
# 283273   283262  Zombie Frappuccino with Almond Milk, Venti 24o...  Starbucks
# 283274   283263  Zombie Frappuccino with Coconut Milk, Grande 1...  Starbucks
# 283275   283264  Zombie Frappuccino with Coconut Milk, Tall 12o...  Starbucks
# 283276   283265  Zombie Frappuccino with Coconut Milk, Venti 24...  Starbucks
# 283277   283266  Zombie Frappuccino with Nonfat Milk, Grande 16...  Starbucks
# 283278   283267  Zombie Frappuccino with Nonfat Milk, Tall 12oz...  Starbucks
# 283279   283268  Zombie Frappuccino with Nonfat Milk, Venti 24o...  Starbucks
# 283280   283269  Zombie Frappuccino with Soy Milk, Grande 16oz ...  Starbucks
# 283282   283271  Zombie Frappuccino with Soy Milk, Tall 12oz - ...  Starbucks
# 283283   283272  Zombie Frappuccino with Soy Milk, Venti 24oz -...  Starbucks
# 283284   283273  Zombie Frappuccino with Whole Milk, Grande 16o...  Starbucks
# 283285   283274  Zombie Frappuccino with Whole Milk, Tall 12oz ...  Starbucks
# 283286   283275  Zombie Frappuccino with Whole Milk, Venti 24oz...  Starbucks
# 283287   283276                                Zucchini Pound Cake  Starbucks
#
#        food_type_grp                 ingredients_list  \
# 282358       grocery                              NaN
# 282391       grocery                              NaN
# 282668       grocery                              NaN
# 282713       grocery                              NaN
# 282714       grocery                              NaN
# 282715       grocery                              NaN
# 282716       grocery                              NaN
# 282717       grocery                              NaN
# 282718       grocery                              NaN
# 282719       grocery                              NaN
# 282720       grocery                              NaN
# 282721       grocery                              NaN
# 282722       grocery                              NaN
# 282723       grocery                              NaN
# 282724       grocery                              NaN
# 282725       grocery                              NaN
# 282726       grocery                              NaN
# 282727       grocery                              NaN
# 282728       grocery                              NaN
# 282729       grocery                              NaN
# 282730       grocery                              NaN
# 282731       grocery                              NaN
# 282732       grocery                              NaN
# 282733       grocery                              NaN
# 282734       grocery                              NaN
# 282735       grocery                              NaN
# 282736       grocery                              NaN
# 282737       grocery                              NaN
# 282738       grocery                       Tall-sized
# 282739       grocery                              NaN
# ...              ...                              ...
# 283257       grocery    Tall-sized with Soy milk (US)
# 283258       grocery       Tall-sized with Breve milk
# 283259       grocery       Tall-sized with Whole milk
# 283260       grocery       Tall-sized with Whole milk
# 283261       grocery       Tall-sized with Breve milk
# 283262       grocery    Tall-sized with Soy milk (US)
# 283263       grocery      Tall-sized with Nonfat milk
# 283264       grocery  Grande-sized with Soy milk (US)
# 283265       grocery    Grande-sized with Nonfat milk
# 283266       grocery     Grande-sized with Whole milk
# 283267       grocery     Grande-sized with Breve milk
# 283268       grocery        apple and caramel flavors
# 283269       grocery        apple and caramel flavors
# 283270       grocery        apple and caramel flavors
# 283271       grocery        apple and caramel flavors
# 283272       grocery        apple and caramel flavors
# 283273       grocery        apple and caramel flavors
# 283274       grocery        apple and caramel flavors
# 283275       grocery        apple and caramel flavors
# 283276       grocery        apple and caramel flavors
# 283277       grocery        apple and caramel flavors
# 283278       grocery        apple and caramel flavors
# 283279       grocery        apple and caramel flavors
# 283280       grocery        apple and caramel flavors
# 283282       grocery        apple and caramel flavors
# 283283       grocery        apple and caramel flavors
# 283284       grocery        apple and caramel flavors
# 283285       grocery        apple and caramel flavors
# 283286       grocery        apple and caramel flavors
# 283287       grocery                              NaN
#
#                 serving_size_raw serving_size_val serving_size_unit calories  \
# 282358       1 Tall drink  12 oz              NaN               NaN       80
# 282391                   1 slice              NaN               NaN      360
# 282668             1 slice  111g              NaN               NaN      240
# 282713          1 croissant  92g              NaN               NaN      330
# 282714             1 slice  135g              NaN               NaN      530
# 282715             1 cookie  78g              NaN               NaN      350
# 282716               1 bar  136g              NaN               NaN      350
# 282717            1 danish  120g              NaN               NaN      370
# 282718           1 fritter  123g              NaN               NaN      450
# 282719     1 Grande drink  16 oz              NaN               NaN      230
# 282720       1 Tall drink  12 oz              NaN               NaN      180
# 282721   1 Venti drink  24 fl oz              NaN               NaN      300
# 282722              1 slice  88g              NaN               NaN      320
# 282723             1 scone  120g              NaN               NaN      450
# 282724             1 bagel  113g              NaN               NaN      300
# 282725       1 Tall drink  12 oz              NaN               NaN      400
# 282726       1 Tall drink  12 oz              NaN               NaN      310
# 282727            1 muffin  138g              NaN               NaN      470
# 282728       1 Tall drink  12 oz              NaN               NaN      400
# 282729       1 Tall drink  12 oz              NaN               NaN      310
# 282730             1 slice  135g              NaN               NaN      360
# 282731             1 slice  113g              NaN               NaN      360
# 282732             1 piece  120g              NaN               NaN      400
# 282733            1 cookie  113g              NaN               NaN      430
# 282734  1 Grande drink  16 fl oz              NaN               NaN      560
# 282735    1 Tall drink  12 fl oz              NaN               NaN      400
# 282736   1 Venti drink  24 fl oz              NaN               NaN      700
# 282737  1 Grande drink  16 fl oz              NaN               NaN      430
# 282738    1 Tall drink  12 fl oz              NaN               NaN      310
# 282739   1 Venti drink  24 fl oz              NaN               NaN      560
# ...                          ...              ...               ...      ...
# 283257       1 Tall drink  12 oz              NaN               NaN      330
# 283258       1 Tall drink  12 oz              NaN               NaN      590
# 283259       1 Tall drink  12 oz              NaN               NaN      370
# 283260       1 Tall drink  12 oz              NaN               NaN      460
# 283261       1 Tall drink  12 oz              NaN               NaN      670
# 283262       1 Tall drink  12 oz              NaN               NaN      420
# 283263       1 Tall drink  12 oz              NaN               NaN      380
# 283264     1 Grande drink  16 oz              NaN               NaN      530
# 283265     1 Grande drink  16 oz              NaN               NaN      490
# 283266     1 Grande drink  16 oz              NaN               NaN      580
# 283267     1 Grande drink  16 oz              NaN               NaN      840
# 283268  1 Grande drink  16 fl oz              NaN               NaN      280
# 283269    1 Tall drink  12 fl oz              NaN               NaN      180
# 283270   1 Venti drink  24 fl oz              NaN               NaN      360
# 283271  1 Grande drink  16 fl oz              NaN               NaN      240
# 283272    1 Tall drink  12 fl oz              NaN               NaN      160
# 283273   1 Venti drink  24 fl oz              NaN               NaN      310
# 283274  1 Grande drink  16 fl oz              NaN               NaN      260
# 283275    1 Tall drink  12 fl oz              NaN               NaN      170
# 283276   1 Venti drink  24 fl oz              NaN               NaN      330
# 283277  1 Grande drink  16 fl oz              NaN               NaN      260
# 283278    1 Tall drink  12 fl oz              NaN               NaN      170
# 283279   1 Venti drink  24 fl oz              NaN               NaN      330
# 283280  1 Grande drink  16 fl oz              NaN               NaN      280
# 283282    1 Tall drink  12 fl oz              NaN               NaN      180
# 283283   1 Venti drink  24 fl oz              NaN               NaN      370
# 283284  1 Grande drink  16 fl oz              NaN               NaN      290
# 283285    1 Tall drink  12 fl oz              NaN               NaN      190
# 283286   1 Venti drink  24 fl oz              NaN               NaN      390
# 283287             1 piece  113g              NaN               NaN      370
#
#        protein_g     ...       saturated_fat_g  carb_g  fiber_g  sugar_g  \
# 282358         4     ...                   0.0    12.0      0.0      9.0
# 282391         5     ...                   3.0    65.0      NaN      NaN
# 282668         9     ...                   3.0    36.0      1.0      1.0
# 282713         6     ...                   7.0    39.0      2.0     16.0
# 282714         8     ...                   5.0    57.0      2.0     30.0
# 282715         5     ...                   8.0    44.0      2.0     26.0
# 282716         3     ...                   3.0    53.0      4.0     34.0
# 282717         5     ...                   1.5    44.0      2.0     18.0
# 282718         6     ...                   6.0    47.0      1.0      9.0
# 282719         0     ...                   0.0    57.0      0.0     52.0
# 282720         0     ...                   0.0    45.0      0.0     41.0
# 282721         0     ...                   0.0    74.0      0.0     67.0
# 282722         4     ...                   5.0    41.0      1.0     28.0
# 282723         7     ...                   8.0    67.0      3.0     17.0
# 282724        12     ...                   0.0    58.0      3.0      4.0
# 282725         4     ...                   7.0    68.0      0.0     60.0
# 282726         4     ...                   1.5    66.0      0.0     59.0
# 282727         6     ...                   5.0    60.0      3.0     39.0
# 282728         4     ...                   8.0    68.0      0.0     61.0
# 282729         4     ...                   2.0    66.0      0.0     59.0
# 282730         5     ...                   1.0    54.0      2.0     25.0
# 282731         4     ...                  11.0    47.0      1.0     24.0
# 282732         5     ...                   5.0    57.0      2.0     31.0
# 282733         4     ...                   3.0    68.0      2.0     53.0
# 282734        13     ...                   9.0    91.0      1.0     78.0
# 282735         9     ...                   6.0    65.0      1.0     55.0
# 282736        17     ...                   9.0   119.0      2.0    101.0
# 282737        13     ...                   0.0    89.0      1.0     76.0
# 282738         9     ...                   0.0    63.0      1.0     54.0
# 282739        17     ...                   0.5   117.0      2.0     99.0
# ...          ...     ...                   ...     ...      ...      ...
# 283257        11     ...                   4.0    54.0      1.0     50.0
# 283258        12     ...                  25.0    48.0      0.0     34.0
# 283259        13     ...                  10.0    49.0      0.0     48.0
# 283260        13     ...                  15.0    50.0      0.0     49.0
# 283261        12     ...                  30.0    49.0      0.0     35.0
# 283262        11     ...                   9.0    56.0      1.0     51.0
# 283263        15     ...                   8.0    52.0      0.0     50.0
# 283264        13     ...                  11.0    72.0      2.0     66.0
# 283265        18     ...                  11.0    68.0      0.0     65.0
# 283266        17     ...                  19.0    65.0      0.0     64.0
# 283267        16     ...                  38.0    64.0      0.0     46.0
# 283268         5     ...                   2.0    58.0      1.0     54.0
# 283269         4     ...                   1.5    37.0      0.0     35.0
# 283270         7     ...                   3.0    74.0      1.0     70.0
# 283271         1     ...                   0.0    54.0      1.0     50.0
# 283272         1     ...                   0.0    34.0      1.0     32.0
# 283273         2     ...                   0.5    69.0      2.0     63.0
# 283274         1     ...                   3.0    56.0      1.0     52.0
# 283275         0     ...                   2.0    36.0      0.0     35.0
# 283276         1     ...                   4.5    71.0      1.0     67.0
# 283277         5     ...                   0.0    58.0      1.0     55.0
# 283278         4     ...                   0.0    37.0      0.0     35.0
# 283279         7     ...                   0.0    75.0      1.0     70.0
# 283280         4     ...                   0.5    60.0      1.0     55.0
# 283282         3     ...                   0.0    39.0      1.0     35.0
# 283283         6     ...                   0.5    77.0      2.0     71.0
# 283284         5     ...                   3.0    58.0      1.0     54.0
# 283285         3     ...                   2.0    37.0      0.0     35.0
# 283286         7     ...                   4.0    74.0      1.0     70.0
# 283287         5     ...                   2.0    47.0      2.0     27.0
#
#         sodium_mg  cholesterol_mg  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 282358       65.0             0.0          NaN          NaN          NaN
# 282391        NaN             NaN          NaN          NaN          NaN
# 282668      430.0            15.0          NaN          NaN          NaN
# 282713      230.0            30.0          NaN          NaN          NaN
# 282714      360.0            90.0          NaN          NaN          NaN
# 282715      350.0            50.0          NaN          NaN          NaN
# 282716      140.0             0.0          NaN          NaN          NaN
# 282717      330.0            25.0          NaN          NaN          NaN
# 282718      420.0            20.0          NaN          NaN          NaN
# 282719       20.0             0.0          NaN          NaN          NaN
# 282720       15.0             0.0          NaN          NaN          NaN
# 282721       25.0             0.0          NaN          NaN          NaN
# 282722      330.0            55.0          NaN          NaN          NaN
# 282723      360.0            60.0          NaN          NaN          NaN
# 282724      660.0             0.0          NaN          NaN          NaN
# 282725      190.0            45.0          NaN          NaN          NaN
# 282726      190.0            10.0          NaN          NaN          NaN
# 282727      310.0            80.0          NaN          NaN          NaN
# 282728      190.0            45.0          NaN          NaN          NaN
# 282729      190.0            10.0          NaN          NaN          NaN
# 282730      480.0             0.0          NaN          NaN          NaN
# 282731      380.0           100.0          NaN          NaN          NaN
# 282732      320.0            65.0          NaN          NaN          NaN
# 282733      210.0            50.0          NaN          NaN          NaN
# 282734      330.0            60.0          NaN          NaN          NaN
# 282735      240.0            40.0          NaN          NaN          NaN
# 282736      430.0            60.0          NaN          NaN          NaN
# 282737      320.0             5.0          NaN          NaN          NaN
# 282738      240.0             5.0          NaN          NaN          NaN
# 282739      420.0            10.0          NaN          NaN          NaN
# ...           ...             ...          ...          ...          ...
# 283257      210.0             0.0          NaN          NaN          NaN
# 283258      210.0           115.0          NaN          NaN          NaN
# 283259      240.0            45.0          NaN          NaN          NaN
# 283260      250.0            75.0          NaN          NaN          NaN
# 283261      220.0           145.0          NaN          NaN          NaN
# 283262      210.0            35.0          NaN          NaN          NaN
# 283263      260.0            40.0          NaN          NaN          NaN
# 283264      270.0            40.0          NaN          NaN          NaN
# 283265      330.0            50.0          NaN          NaN          NaN
# 283266      310.0            95.0          NaN          NaN          NaN
# 283267      280.0           180.0          NaN          NaN          NaN
# 283268      250.0            10.0          NaN          NaN          NaN
# 283269      170.0            10.0          NaN          NaN          NaN
# 283270      330.0            15.0          NaN          NaN          NaN
# 283271      240.0             0.0          NaN          NaN          NaN
# 283272      160.0             0.0          NaN          NaN          NaN
# 283273      320.0             0.0          NaN          NaN          NaN
# 283274      240.0             0.0          NaN          NaN          NaN
# 283275      160.0             0.0          NaN          NaN          NaN
# 283276      320.0             0.0          NaN          NaN          NaN
# 283277      240.0             5.0          NaN          NaN          NaN
# 283278      160.0             0.0          NaN          NaN          NaN
# 283279      320.0             5.0          NaN          NaN          NaN
# 283280      230.0             0.0          NaN          NaN          NaN
# 283282      160.0             0.0          NaN          NaN          NaN
# 283283      310.0             0.0          NaN          NaN          NaN
# 283284      240.0            15.0          NaN          NaN          NaN
# 283285      160.0            10.0          NaN          NaN          NaN
# 283286      320.0            20.0          NaN          NaN          NaN
# 283287      250.0            55.0          NaN          NaN          NaN
#
#         Unnamed: 20
# 282358          NaN
# 282391          NaN
# 282668          NaN
# 282713          NaN
# 282714          NaN
# 282715          NaN
# 282716          NaN
# 282717          NaN
# 282718          NaN
# 282719          NaN
# 282720          NaN
# 282721          NaN
# 282722          NaN
# 282723          NaN
# 282724          NaN
# 282725          NaN
# 282726          NaN
# 282727          NaN
# 282728          NaN
# 282729          NaN
# 282730          NaN
# 282731          NaN
# 282732          NaN
# 282733          NaN
# 282734          NaN
# 282735          NaN
# 282736          NaN
# 282737          NaN
# 282738          NaN
# 282739          NaN
# ...             ...
# 283257          NaN
# 283258          NaN
# 283259          NaN
# 283260          NaN
# 283261          NaN
# 283262          NaN
# 283263          NaN
# 283264          NaN
# 283265          NaN
# 283266          NaN
# 283267          NaN
# 283268          NaN
# 283269          NaN
# 283270          NaN
# 283271          NaN
# 283272          NaN
# 283273          NaN
# 283274          NaN
# 283275          NaN
# 283276          NaN
# 283277          NaN
# 283278          NaN
# 283279          NaN
# 283280          NaN
# 283282          NaN
# 283283          NaN
# 283284          NaN
# 283285          NaN
# 283286          NaN
# 283287          NaN
#
# [575 rows x 21 columns]

# %%
# Randomly assign groups 1 - 5. 
useful_df['rand_group'] = [randint(0,4) for i in range(len(useful_df))]

# %%
# Rules: Need 1 from each group.
prot_req = 144
fat_req = 64
carb_req = 132

# %%
def add_sorted_item(useful_df, plan_df, delta, proportions):
    delta = np.array([prot_req,fat_req,carb_req])-np.array([sum(plan_df['protein_g']),sum(plan_df['fat_g']),sum(plan_df['carb_g'])])
    proportions = np.array([delta[0]/sum(delta),delta[1]/sum(delta),delta[2]/sum(delta)])
    useful_df['prop_distance'] = np.sqrt((useful_df.prot_prop-proportions[0])**2+(useful_df.fat_prop - proportions[1])**2+(useful_df.carb_prop - proportions[2])**2)# a
    useful_df = useful_df.sort_values(by=['prop_distance'])
# Append closest distance
    plan_df = plan_df.append([useful_df.iloc[0,:]],ignore_index=True)
# Drop used
    useful_df = useful_df.drop(useful_df.index[[0]])

    return plan_df, delta, proportions

# %%
proportions = np.array([prot_req/sum([prot_req,fat_req,carb_req]),fat_req/sum([prot_req,fat_req,carb_req]),carb_req/sum([prot_req,fat_req,carb_req])])
    # Sort full df by distance to initial proportions
useful_df['prop_distance'] = np.sqrt((useful_df.prot_prop-proportions[0])**2+(useful_df.fat_prop - proportions[1])**2+(useful_df.carb_prop - proportions[2])**2)
    #temp_df = temp_df.append(useful_df.iloc[randint(0,len(useful_df)-1),:])
useful_df = useful_df.sort_values(by=['prop_distance'])
plan_df = pd.DataFrame([useful_df.iloc[0,:]])
useful_df = useful_df.drop(useful_df.index[[0]])
delta = np.array([prot_req,fat_req,carb_req])-np.array([sum(plan_df['protein_g']),sum(plan_df['fat_g']),sum(plan_df['carb_g'])])
j = 0
while sum((abs(delta)<np.array([0.05*prot_req,0.05*fat_req,0.05*carb_req])))!=3:
    if sum(delta<0)==3:
        plan_df = plan_df.drop(plan_df.index[[randint(0,len(plan_df)-1)]])
    if j <= 4:
        plan_df, delta, proportions = add_sorted_item(useful_df[useful_df['rand_group']==j], plan_df, delta, proportions)
    else:
        plan_df, delta, proportions = add_sorted_item(useful_df, plan_df, delta, proportions)
    j+=1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
plan_df
# Out:
#      ndb_no                                          desc_only  kilocalories  \
# 0  45119257  HIGH LINER, SEA CUISINE, TORTILLA CRUSTED TILA...         280.0
# 1  45232410  NATIVE AMERICAN NATURAL FOODS, BUFFALO MEAT TA...          70.0
# 2  45206673  HORMEL, REV, #4 SMOKED TURKEY & PEPPERJACK CHE...         200.0
# 3  45120813                BREADED CHICKEN BREAST TENDERLOINS,         170.0
# 4  45205313  CLEAR SPRINGS FOODS, CRUNCHY POTATO CRUSTED MA...         280.0
# 5  45199056                              CRISPY CHICKEN BITES,         180.0
# 6  45314856                             CRISPY CHICKEN STRIPS,         230.0
# 7  45120813                BREADED CHICKEN BREAST TENDERLOINS,         170.0
# 8  45099287                            ORCHIDS, WHOLE OYSTERS,          80.0
# 9  45061168                       HICKORY SMOKED STEAK STRIPS,         100.0
#
#    protein_g  fat_g  carb_g           unit_per_item  prot_prop  fat_prop  \
# 0         24     11      21  b'FILLET 148\xc2\xa0g'   0.428571  0.196429
# 1          7      3       6      b'BAR 28\xc2\xa0g'   0.437500  0.187500
# 2         16      8      15     b'WRAP 77\xc2\xa0g'   0.410256  0.205128
# 3         15      6      14      b'ONZ 84\xc2\xa0g'   0.428571  0.171429
# 4         25     10      22     b'ONZ 170\xc2\xa0g'   0.438596  0.175439
# 5         15      7      15     b'ONZ 112\xc2\xa0g'   0.405405  0.189189
# 6         18      9      17  b'STRIPS 112\xc2\xa0g'   0.409091  0.204545
# 7         15      6      14      b'ONZ 84\xc2\xa0g'   0.428571  0.171429
# 8          7      3       6      b'cup 56\xc2\xa0g'   0.437500  0.187500
# 9          8      4       8      b'ONZ 28\xc2\xa0g'   0.400000  0.200000
#
#    carb_prop  prop_distance  rand_group
# 0   0.375000       0.016362           3
# 1   0.375000       0.021813           0
# 2   0.384615       0.022927           1
# 3   0.400000       0.014737           2
# 4   0.385965       0.019733           3
# 5   0.405405       0.015501           4
# 6   0.386364       0.018542           4
# 7   0.400000       0.010102           2
# 8   0.375000       0.011136           3
# 9   0.400000       0.000000           1

# %%
delta
# Out:
# array([2, 1, 2], dtype=int64)
