# %%
import pandas as pd
import numpy as np
from random import randint
import math

# %%
df = pd.read_csv('C:/Users/J/Desktop/Businesses/branded_foods_in_progress.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (140) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns.values
# Out:
# array(['alanine_g', 'alpha_carotene_mcg', 'alpha_tocopherol_mg',
#        'arginine_g', 'ash_g', 'aspartic_acid_g', 'beta_carotene_mcg',
#        'beta_cryptoxanthin_mcg', 'beta_sitosterol_mg',
#        'beta_tocopherol_mg', 'beta_tocotrienol_mg', 'betaine_mg',
#        'caffeine_mg', 'caffiene_mg', 'calcium_mg', 'campesterol_mg',
#        'carb_g', 'cholesterol_mg', 'choline_mcg', 'choline_mg',
#        'copper_mg', 'cystine_g', 'delta_tocopherol_mg',
#        'delta_tocotrienol_mg', 'desc_only', 'dihydrophylloquinone_mcg',
#        'ethyl_alcohol_g', 'fat_g', 'fiber_g', 'flouride_mcg', 'folate_mcg',
#        'folate_mcg_dfe', 'folic_acid_mcg', 'food_folate_mcg', 'fructose_g',
#        'galactose_g', 'gamma_tocopherol_mg', 'gamma_tocotrienol_mg',
#        'glucose_g', 'glutamic_acid_g', 'glycine_g', 'gm_weight_1',
#        'gm_weight_2', 'gm_weight_desc1', 'gm_weight_desc2', 'histidine_g',
#        'hydroxyproline_g', 'ingredients_list', 'iron_mg', 'isoleucine_g',
# ...

# %%
food_descriptors_df = df[['ndb_no','short_desc','manufac_fd_grp','unit_per_item', 'ingredients_list']]

# %%
food_descriptors_df.iloc[1:100,:]
# Out:
#       ndb_no                                         short_desc  \
# 1   45186303  AARON'S BEST, OVEN ROASTED TURKEY BREAST, UPC:...
# 2   45169417  A&B AMERICAN STYLE, MORE HEAT SMALL BATCH PEPP...
# 3   45169419  A&B AMERICAN STYLE, ORGANIC PEPPER SAUCE, UPC:...
# 4   45253484  A&B AMERICAN STYLE, PEPPER SAUCE, GARLIC, UPC:...
# 5   45169416  A&B AMERICAN STYLE, SMALL BATCH PEPPER SAUCE, ...
# 6   45094214    A. BAUER'S, PREPARED MUSTARD, UPC: 723738002022
# 7   45156252  ABBA-ZABA, SNACK SIZE BITES CANDY, UPC: 070602...
# 8   45147647  ABBA-ZABA'S, TAFFY, WILD STRAWBERRY, SOUR, UPC...
# 9   45093932  ABBEY FARM, RHUBARB & GINGER PRESERVE, UPC: 76...
# 10  45103127  ABBOTSFORD FARMS, CAGE FREE 100% LIQUID EGG WH...
# 11  45332318  ABBOTT, EAS, ADVANTEDGE CARB CONTROL SHAKES, C...
# 12  45248123  ABBOTT, EAS, ADVANT EDGE PURE MILK PROTEIN SHA...
# 13  45258948  ABBOTT, EAS, MYOPLEX 30 BUILD MUSCLE BAR, CHOC...
# 14  45248117  ABBOTT, EAS, PURE WHEY PROTEIN BARS, ALMOND TO...
# ...
